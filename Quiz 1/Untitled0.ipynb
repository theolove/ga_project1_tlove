# %%
import pandas as pd
import numpy as np

ads = pd.read_csv("ads.csv", skiprows=3, header=0, skipfooter=1)
# Out:
# //anaconda/lib/python2.7/site-packages/pandas/io/parsers.py:639: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skip_footer; you can avoid this warning by specifying engine='python'.
#   ParserWarning)

# %%
ads.head()
# Out:
#                   date  ad_id strategy_group  \
# 0  2015-02-16 00:00:00   7779    team_banana
# 1  2015-02-16 00:00:00  10000    team_banana
# 2  2015-02-16 00:00:00   9309    team_banana
# 3  2015-02-16 00:00:00   4585    team_orange
# 4  2015-02-16 00:00:00   8923    team_banana
#
#                                          description   spend  spend_wfees  \
# 0  Did you know there are 100s of bananas? Click ...  903.86       909.05
# 1  Did you know there are 100s of bananas? Click ...  904.82       907.75
# 2  Did you know there are 100s of bananas? Click ...  196.61       199.70
# 3  Did you know there are 100s of bananas? Click ...  703.92       705.28
# 4  Did you know there are 100s of bananas? Click ...  392.88       400.12
#
#    impressions  clicks
# 0         7398    1039
# 1         9128    1989
# 2         9244    1423
# 3         1421     241
# 4         5245     549

# %%
ads.tail()
# Out:
#                     date  ad_id strategy_group  \
# 135  2015-02-22 00:00:00   4887    team_orange
# 136  2015-02-22 00:00:00   8923    team_banana
# 137  2015-02-22 00:00:00   2519    team_orange
# 138  2015-02-22 00:00:00   2703    team_banana
# 139  2015-02-22 00:00:00   4585    team_orange
#
#                                            description   spend  spend_wfees  \
# 135  Did you know there are 100s of bananas? Click ...  894.68       898.83
# 136  Did you know there are 100s of bananas? Click ...  142.38       147.88
# 137  Did you know there are 100s of bananas? Click ...   58.46        62.10
# 138  Did you know there are 100s of bananas? Click ...  884.96       889.63
# 139  Did you know there are 100s of bananas? Click ...  404.33       408.60
#
#      impressions  clicks
# 135         7805    1568
# 136         2044     288
# 137         3968     144
# 138         2474     597
# 139          364      10

# %%
big_ads = ads[(ads["ad_id"] == 200) & (ads["spend"] > 30)]
big_ads.head()
# Out:
# Empty DataFrame
# Columns: [date, ad_id, strategy_group, description, spend, spend_wfees, impressions, clicks]
# Index: []

# %%
ads2 = ads[ads["ad_id"] == 200]

# %%
len(ads2)
# Out:
# 0

# %%
big_ads = ads[ads["spend"] > 30]
big_ads.head()
# Out:
#                   date  ad_id strategy_group  \
# 0  2015-02-16 00:00:00   7779    team_banana
# 1  2015-02-16 00:00:00  10000    team_banana
# 2  2015-02-16 00:00:00   9309    team_banana
# 3  2015-02-16 00:00:00   4585    team_orange
# 4  2015-02-16 00:00:00   8923    team_banana
#
#                                          description   spend  spend_wfees  \
# 0  Did you know there are 100s of bananas? Click ...  903.86       909.05
# 1  Did you know there are 100s of bananas? Click ...  904.82       907.75
# 2  Did you know there are 100s of bananas? Click ...  196.61       199.70
# 3  Did you know there are 100s of bananas? Click ...  703.92       705.28
# 4  Did you know there are 100s of bananas? Click ...  392.88       400.12
#
#    impressions  clicks
# 0         7398    1039
# 1         9128    1989
# 2         9244    1423
# 3         1421     241
# 4         5245     549

# %%
daily_sum = ads.groupby(ads["date"]).sum()

# %%
daily_sum.head()
# Out:
#                       ad_id     spend  spend_wfees  impressions  clicks
# date
# 2015-02-16 00:00:00  123888  11199.81     11282.45       114755   18002
# 2015-02-17 00:00:00  123888   9104.37      9219.35       125398   12984
# 2015-02-18 00:00:00  123888  10366.52     10481.85       112842   15585
# 2015-02-19 00:00:00  123888  10103.20     10203.54        98493   10625
# 2015-02-20 00:00:00  123888   9893.92      9978.50       101103   10834
