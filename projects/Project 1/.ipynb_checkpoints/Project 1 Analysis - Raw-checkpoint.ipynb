# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("Energy_and_Water_Data_Disclosure_for_Local_Law_84__2011_ (1).csv")

# %%
data.head()
# Out:
#           BBL Street Number           Street Name    Borough    Zip  \
# 0  1000050010           115  BROAD STREET          MANHATTAN  10004
# 1  1000090001            34      WHITEHALL STREET  MANHATTAN  10004
# 2  1000090014            17          STATE STREET  MANHATTAN  10004
# 3  1000090029            24      WHITEHALL STREET  MANHATTAN  10004
# 4  1000100014            33  WHITEHALL STREET      MANHATTAN  10004
#
#         Benchmarking Submission  Entry Number  Site EUI  \
# 0  No DOF Record as of 08/01/12           NaN       NaN
# 1                           Yes          1518     157.9
# 2                           Yes           312      91.5
# 3                           Yes            52     137.2
# 4  No DOF Record as of 08/01/12           NaN       NaN
#
#    Weather Normalized Source EUI  Water per Square Foot  ENERGY STAR Score  \
# 0                            NaN                    NaN                NaN
# ...

# %%
data.tail()
# Out:
#              BBL Street Number           Street Name               Borough  \
# 4076  5075770003           200       BOSCOMBE AVENUE         STATEN ISLAND
# 4077  5077020001          6420  AMBOY ROAD            STATEN ISLAND
# 4078  5079710250           236  RICHMOND VALLEY ROAD  STATEN ISLAND
# 4079  5079910100            99          ELLIS STREET         STATEN ISLAND
# 4080  5080080134           250  PAGE AVENUE           STATEN ISLAND
#
#         Zip       Benchmarking Submission  Entry Number  Site EUI  \
# 4076  10309                           Yes          1949      58.7
# 4077  10309  No DOF Record as of 08/01/12           NaN       NaN
# 4078  10309  No DOF Record as of 08/01/12           NaN       NaN
# 4079  10307                           Yes          2027      42.8
# 4080  10307  No DOF Record as of 08/01/12           NaN       NaN
#
#       Weather Normalized Source EUI  Water per Square Foot  ENERGY STAR Score  \
# ...

# %%
data.describe()
# Out:
#                 BBL           Zip  Entry Number       Site EUI  \
# count  4.081000e+03   4081.000000   2546.000000    2319.000000
# mean   2.157780e+09  10438.736339   1265.103692     626.429754
# std    1.331051e+09   1068.672029    738.484610    6994.254488
# min    1.000050e+09      0.000000      1.000000       0.000000
# 25%    1.008600e+09  10017.000000    629.250000      56.750000
# 50%    1.020330e+09  10065.000000   1255.500000      83.700000
# 75%    3.056710e+09  11207.000000   1888.750000     121.050000
# max    5.080080e+09  11695.000000   2650.000000  160180.700000
#
#        Weather Normalized Source EUI  Water per Square Foot  \
# count                    2319.000000             385.000000
# mean                      868.657223             149.246234
# std                      8538.529231            1111.216977
# min                         0.000000               0.000000
# 25%                       124.200000               1.060000
# ...

# %%
data.groupby("Number of Buildings").count()
# Out:
#                       BBL  Street Number  Street Name  Borough   Zip  \
# Number of Buildings
# 0                       7              7            7        7     7
# 1                    2166           2163         2166     2166  2166
# 2                     164            164          164      164   164
# 3                      62             62           62       62    62
# 4                      36             36           36       36    36
# 5                      22             22           22       22    22
# 6                       2              2            2        2     2
# 7                      12             12           12       12    12
# 8                      17             17           17       17    17
# 9                       1              1            1        1     1
# 10                      1              1            1        1     1
# 11                     15             15           15       15    15
# ...

# %%
data.head()
# Out:
#           BBL Street Number           Street Name    Borough    Zip  \
# 0  1000050010           115  BROAD STREET          MANHATTAN  10004
# 1  1000090001            34      WHITEHALL STREET  MANHATTAN  10004
# 2  1000090014            17          STATE STREET  MANHATTAN  10004
# 3  1000090029            24      WHITEHALL STREET  MANHATTAN  10004
# 4  1000100014            33  WHITEHALL STREET      MANHATTAN  10004
#
#         Benchmarking Submission  Entry Number  Site EUI  \
# 0  No DOF Record as of 08/01/12           NaN       NaN
# 1                           Yes          1518     157.9
# 2                           Yes           312      91.5
# 3                           Yes            52     137.2
# 4  No DOF Record as of 08/01/12           NaN       NaN
#
#    Weather Normalized Source EUI  Water per Square Foot  ENERGY STAR Score  \
# 0                            NaN                    NaN                NaN
# ...

# %%
data2 = pd.read_csv('Energy_and_Water_Data_Disclosure_for_Local_Law_84__2012_.csv')

# %%
data.head()
# Out:
#           BBL Street Number           Street Name    Borough    Zip  \
# 0  1000050010           115  BROAD STREET          MANHATTAN  10004
# 1  1000090001            34      WHITEHALL STREET  MANHATTAN  10004
# 2  1000090014            17          STATE STREET  MANHATTAN  10004
# 3  1000090029            24      WHITEHALL STREET  MANHATTAN  10004
# 4  1000100014            33  WHITEHALL STREET      MANHATTAN  10004
#
#         Benchmarking Submission  Entry Number  Site EUI  \
# 0  No DOF Record as of 08/01/12           NaN       NaN
# 1                           Yes          1518     157.9
# 2                           Yes           312      91.5
# 3                           Yes            52     137.2
# 4  No DOF Record as of 08/01/12           NaN       NaN
#
#    Weather Normalized Source EUI  Water per Square Foot  ENERGY STAR Score  \
# 0                            NaN                    NaN                NaN
# ...

# %%
print len(data2.columns.values)
print len(data.columns.values)
# Out:
# 17
# 16
