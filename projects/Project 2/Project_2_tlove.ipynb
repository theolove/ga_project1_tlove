# %%
# %pylab inline
import pandas as pd
import seaborn as sns
from __future__ import division
import datetime
sns.set_style('white')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# #Project 2 - Predicting Large Building Energy Intensity in NYC
#
# *Author:* Theodore Love
#
# *Date:* March 16, 2015
#
# **Contents**
# 1. Overview of Data Collected in Project 1
# 2. Exploring New Data Sets
# 3. Combining Data Sets

# %% [markdown]
# ## 1. Overview of Data Collected in Project 1

# %% [markdown]
# This analysis is primarily based on data relating to [NYC Local Law 84](http://www.nyc.gov/html/gbee/html/plan/ll84.shtml), which requires private sector buildings that are larger than 50,000 square feet, and two or more private sector buildings on a single lot that are larger than 100,000 square feet, to provide annual data on energy and water consumption. Significant analysis has been done on this data set and presented in a [series of reports](http://www.nyc.gov/html/gbee/html/plan/ll84_scores.shtml). This analysis attempts to extend this previous work.
#
# The original data covers five basic categories of information:
# * Building Location (borough/block/lot, address, etc.)
# * Building Info (building type, square footage, id, etc.)
# * Energy Usage (gross kBTUs/ft2, weather normalized kBTUs/ft2, ENERGY STAR score)
# * Water Usage per ft2 (along with source)
# * GHG Emissions (calculated from kBtu/ft2 and a coefficient estimate)
#
# All of this data is sourced from [NYC Open Data](https://nycopendata.socrata.com/), and has both zip code and borough/block/lot information, which makes for a good way to work in other data sets.
#
# **Data Sets Used in Project 1**
#
# |Name | Source |
# |---| --- |
# |Local Law 84 Disclosures (2011) | [Source](https://data.cityofnewyork.us/Environment/Energy-and-Water-Data-Disclosure-for-Local-Law-84-/q39e-7gbs)|
# |Local Law 84 Disclosures (2012 | [Source](https://data.cityofnewyork.us/Environment/Energy-and-Water-Data-Disclosure-for-Local-Law-84-/5gde-fmj3)|
#
# **Data for Project 2**
#
# In order to keep this project's analysis to a more manageable scope, we will **only look at data for 2012**, which was both more comprehensive and had less issues than 2011 data. This also allows us to establish **BBL** as a a unique key (with a little bit of wrangling).

# %% [markdown]
# ## 2. Exploring New Data Sets

# %% [markdown]
# Since the data sets used in this next section were too large to upload to github, I have them saved in a local directory. Source links for each data set are in the descriptions below.
#
# ####*NOTE: The full cleaned and merged data set is stored in this same directory, skip to the beginning of Section 4 to import it without processing other data*

# %%
data_folder = '/Users/Theo/Dropbox (Personal)/ProgrammingProjects/GADSdata'

# %% [markdown]
# ####NYC PLUTO Data
#
# NYC maintains extensive land use and geographic data at the tax lot level in their Primary Land Use Tax Lot Output database ([PLUTO](http://www.nyc.gov/html/dcp/html/bytes/dwn_pluto_mappluto.shtml)). NYC maintains [historical PLUTO data](http://www.nyc.gov/html/dcp/html/bytes/archive_pluto_mappluto.shtml) back to 2002, and for this analysis, the latest 2012 data (v2) is used, in order to align as closely as possible with the timing of the Local Law 84 data from 2012.

# %%
"""
2012 PLUTO data is saved by borough, so each is imported separately and then combined
 - Skip blank line at bottom
 - Skip leading spaces
 - BBL is a unique key
"""

# Manhattan
mn = pd.read_csv(data_folder + '/nyc_pluto_12v2/mn12v2.txt', 
                 skipfooter=1,
                 engine="python",
                 skipinitialspace=True,
                 )

# Bronx
bx = pd.read_csv(data_folder + '/nyc_pluto_12v2/bx12v2.txt',
                 skipfooter=1,
                 engine="python",
                 skipinitialspace=True,
                 )

# Brooklyn
bk = pd.read_csv(data_folder + '/nyc_pluto_12v2/bk12v2.txt',
                 skipfooter=1,
                 engine="python",
                 skipinitialspace=True,
                 )

# Queens
qn = pd.read_csv(data_folder + '/nyc_pluto_12v2/qn12v2.txt',
                 skipfooter=1,
                 engine="python",
                 skipinitialspace=True,
                 )

# Staten Island
si = pd.read_csv(data_folder + '/nyc_pluto_12v2/si12v2.txt',
                 skipfooter=1,
                 engine="python",
                 skipinitialspace=True,
                 )

# Combine and set BBL as the index (already checked for uniqueness)
pluto = pd.concat([mn,bx,bk,qn,si], axis=0)
pluto.describe()
# Out:
#                Block            Lot             CD        Council  \
# count  859324.000000  859324.000000  859324.000000  855398.000000
# mean     5301.815771     125.284543     354.036419      32.030069
# std      3695.489329     712.010049     101.004411      13.215942
# min         0.000000       0.000000     101.000000       0.000000
# 25%      2298.000000      19.000000     306.000000      22.000000
# 50%      4803.000000      38.000000     401.000000      32.000000
# 75%      7456.000000      64.000000     412.000000      44.000000
# max     16350.000000    9978.000000     595.000000      51.000000
#
#           PolicePrct      Easements       LotArea         BldgArea  \
# count  855388.000000  859324.000000  8.593240e+05    859324.000000
# mean       86.806960       0.005074  7.867791e+03      6313.022123
# std        29.413449       0.083615  3.703630e+05     66822.328779
# min         1.000000       0.000000  0.000000e+00         0.000000
# 25%        66.000000       0.000000  2.000000e+03      1440.000000
# 50%       102.000000       0.000000  2.513000e+03      2088.000000
# 75%       111.000000       0.000000  4.000000e+03      3120.000000
# max       123.000000      13.000000  2.147557e+08  27600000.000000
#
#                ComArea          ResArea      ...             BuiltFAR  \
# count    859324.000000    859324.000000      ...        859324.000000
# mean       2228.923938      4082.527828      ...             1.140965
# std       59277.914889     29323.434469      ...            12.595126
# min           0.000000         0.000000      ...             0.000000
# 25%           0.000000      1281.000000      ...             0.480000
# 50%           0.000000      1898.000000      ...             0.780000
# 75%           0.000000      2763.000000      ...             1.280000
# max    27600000.000000  13211398.000000      ...          6088.800000
#
#           MaxAllwFAR       BoroCode           BBL        CondoNo  \
# count  859324.000000  859324.000000  8.593240e+05  859324.000000
# mean        1.446861       3.459120  3.512138e+09       8.970288
# std         1.468102       1.023812  1.031994e+09     127.951807
# min         0.000000       1.000000  1.000010e+09       0.000000
# 25%         0.600000       3.000000  3.030790e+09       0.000000
# 50%         0.900000       4.000000  4.008320e+09       0.000000
# 75%         2.000000       4.000000  4.106040e+09       0.000000
# max        15.000000       5.000000  5.080500e+09    9566.000000
#
#            Tract2010          XCoord         YCoord        APPBBL  \
# count  859324.000000   829419.000000  829419.000000  8.581930e+05
# mean     9232.698645  1006257.479815  191689.518341  3.538946e+08
# std     26256.936042    32217.315934   30463.493201  1.162034e+09
# min         0.000000   913236.000000  120308.000000  0.000000e+00
# 25%       206.000000   989615.500000  168454.000000  0.000000e+00
# 50%       484.000000  1008653.000000  189303.000000  0.000000e+00
# 75%      1116.000000  1028971.000000  211104.000000  0.000000e+00
# max    157903.000000  1067277.000000  272316.000000  5.080480e+09
#
#           PLUTOMapID
# count  859324.000000
# mean        1.004698
# std         0.093883
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         5.000000
#
# [8 rows x 42 columns]

# %% [markdown]
# ####Housing Code Violations
#
# [Housing code violations](https://data.cityofnewyork.us/Housing-Development/Housing-Maintenance-Code-Violations/wvxf-dwi5) may have some predictive power for **Multifamily** buildings, and are available by BBL.
#
# In order to make the data as relevant as possible to 2012, only violations that were observed in 2012 will be used (i.e. **InspectionDate** has the year 2012).
#
# The data is by unique violation, so some aggregation is necessary. Each violation has a text description, which may be interesting to examine later, but for now the pertinant field will be **OrderNumber**, which corresponds to the law which is being violated.
#
# After filtering and aggregating, we have a dataframe that, for each **BBL**, provides a count of violations observed in 2012 for each **OrderNumber**.

# %%
# import the data and create a bbl field
hmcv = pd.read_csv(data_folder + "/housing_maint_violations/Housing_Maintenance_Code_Violations.csv", low_memory=False)
hmcv['bbl'] = hmcv.BoroID.map(str) + \
              hmcv.Block.apply(lambda x: str(x).zfill(5)) + \
              hmcv.Lot.apply(lambda x: str(x).zfill(4))
hmcv.bbl = hmcv.bbl.map(int)

# convert the InspectionDate to a datetime field and extract a new column for year
hmcv.InspectionDate = pd.to_datetime(hmcv.InspectionDate)
hmcv['InspectionYear'] = hmcv.InspectionDate.apply(lambda x: x.year)

# get the count of each OrderNum by BBL in 2012 and make a sum of violations feature
hmcv_2012 = pd.pivot_table(hmcv[hmcv.InspectionYear == 2012][['bbl','OrderNumber']],
                           values=['OrderNumber'],
                           index=['bbl'],
                           columns=['OrderNumber'],
                           aggfunc=len,
                           fill_value=0)
hmcv_2012.columns = 'hmcv_num_' + hmcv_2012.columns.map(str)
hmcv_2012['violations'] = hmcv_2012.sum(axis=1)
hmcv_2012.describe()
# Out:
#         hmcv_num_4   hmcv_num_8  hmcv_num_84  hmcv_num_106  hmcv_num_109  \
# count  2760.000000  2760.000000  2760.000000   2760.000000   2760.000000
# mean      0.002536     0.000362     0.000362      0.009783      0.002536
# std       0.063091     0.019035     0.019035      0.115390      0.073691
# min       0.000000     0.000000     0.000000      0.000000      0.000000
# 25%       0.000000     0.000000     0.000000      0.000000      0.000000
# 50%       0.000000     0.000000     0.000000      0.000000      0.000000
# 75%       0.000000     0.000000     0.000000      0.000000      0.000000
# max       2.000000     1.000000     1.000000      3.000000      3.000000
#
#        hmcv_num_118  hmcv_num_176  hmcv_num_188  hmcv_num_209  hmcv_num_483  \
# count   2760.000000   2760.000000   2760.000000   2760.000000   2760.000000
# mean       0.000362      0.000725      0.002174      0.000725      0.001449
# std        0.019035      0.026914      0.046583      0.026914      0.038049
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#           ...       hmcv_num_1042  hmcv_num_1051  hmcv_num_1061  \
# count     ...         2760.000000    2760.000000    2760.000000
# mean      ...            0.008333       0.000362       0.005072
# std       ...            0.143493       0.019035       0.080612
# min       ...            0.000000       0.000000       0.000000
# 25%       ...            0.000000       0.000000       0.000000
# 50%       ...            0.000000       0.000000       0.000000
# 75%       ...            0.000000       0.000000       0.000000
# max       ...            4.000000       1.000000       2.000000
#
#        hmcv_num_1067  hmcv_num_1492  hmcv_num_1493  hmcv_num_1501  \
# count    2760.000000    2760.000000    2760.000000    2760.000000
# mean        0.002174       0.000362       0.001812       0.007971
# std         0.065914       0.019035       0.042532       0.092926
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         3.000000       1.000000       1.000000       2.000000
#
#        hmcv_num_1502  hmcv_num_1503   violations
# count    2760.000000    2760.000000  2760.000000
# mean        0.307246       0.165580     8.538406
# std         0.827108       0.552214    14.117484
# min         0.000000       0.000000     1.000000
# 25%         0.000000       0.000000     2.000000
# 50%         0.000000       0.000000     4.000000
# 75%         0.000000       0.000000    10.000000
# max        14.000000       6.000000   293.000000
#
# [8 rows x 178 columns]

# %% [markdown]
# ##3. Combining Data Sets
#
# **Local Law 84 Data**
#
# We will only look at 2012 data for this project, and will start by importing the 2012 Local Law 84 data and cleaning it the same way we did in Project 1, but without creating any variables.

# %%
# import and rename columns
buildings = pd.read_csv(data_folder +  '/Energy_and_Water_Data_Disclosure_for_Local_Law_84__2012.csv')
buildings.columns = "bbl st_no st_name borough zip bench_sub entry_no EUI EUIwn water_ft2 \
            water_method energy_star GHG floor_area property_type no_buildings reported_BINS".split()
buildings.ix[buildings['energy_star'] == 'Exempt', 'energy_star'] = np.NaN

# Remove the anomalies the same was as in Project 1
curr = len(buildings)
print "Anomalies"
print "========="
print "Starting observations: %i" % curr

buildings = buildings[pd.notnull(buildings['EUIwn'])]
print "Missing EUIwn: %i" % (curr - len(buildings))
curr = len(buildings)

buildings = buildings[buildings['EUI'] > 0]
print "EUI of 0: %i" % (curr - len(buildings))
curr = len(buildings)

buildings = buildings[buildings['EUIwn'] >= 5]
print "EUIwn < 5: %i" % (curr - len(buildings))
curr = len(buildings)

buildings = buildings[buildings['EUIwn'] <= 1000]
print "EUIwn > 1,000: %i" % (curr - len(buildings))
curr = len(buildings)

buildings = buildings[buildings['floor_area'] >= 25000]
print "floor area < 25k ft2: %i" % (curr - len(buildings))
curr = len(buildings)

buildings = buildings[pd.notnull(buildings['GHG'])]
print "Missing GHG: %i" % (curr - len(buildings))
curr = len(buildings)

print "Water per ft2 > 100: %i (kept observation)" % len(buildings[buildings['water_ft2'] > 100])  
buildings['water_ft2'] = buildings['water_ft2'].apply(lambda x: np.NaN if x > 100 else x)

print "Remaining observations: %i" % len(buildings)
buildings = buildings.set_index('bbl')
# Out:
# Anomalies
# =========
# Starting observations: 14112
# Missing EUIwn: 3041
# EUI of 0: 67
# EUIwn < 5: 52
# EUIwn > 1,000: 110
# floor area < 25k ft2: 273
# Missing GHG: 37
# Water per ft2 > 100: 480 (kept observation)
# Remaining observations: 10532

# %% [markdown]
# **Merge in New Data**
#
# Merge in the *pluto* and *hmcv_2012* data on **bbl**.

# %%
print "Buildings imported: %i features and %i observations." % (len(buildings.columns), len(buildings))

# merge in the housing maintenance code violations
bd = buildings.join(hmcv_2012)
print "Code Violation data merged: %i features and %i observations." % (len(bd.columns), len(bd))

# merge in the PLUTO data
bd = bd.merge(pluto, how='left', left_index=True, right_on=['BBL'])
print "Pluto data merged: %i features and %i observations." % (len(bd.columns), len(bd))

bd = bd.set_index(bd.BBL)
# Out:
# Buildings imported: 16 features and 10532 observations.
# Code Violation data merged: 194 features and 10532 observations.
# Pluto data merged: 274 features and 10532 observations.

# %% [markdown]
# **New Variables and Relevant Feature Lists**
#
# Create some new variables and lists for each different kind of feature that we want to explore in our supervised machine learning. Put the features in to three general categories
#
# > **Targets**: variables to predict
#
# > **Class Dummies**: classification columns that need to be made in to dummy columns (ignored until later)
#
# > **Class**: classification columns that are already True/False
#
# > **Cont**: continuous variables

# %%
"""
ORIGINAL DATA
"""
# original data set features that could be relevent
targets = ['EUIwn', 'EUI']
orig_class_dummies = [u'borough', u'zip', u'property_type',]
orig_class = [u'water_method']
orig_cont = [u'water_ft2', u'energy_star', u'GHG', u'floor_area', u'no_buildings',]

# normalize EUIwn
bd['EUIwn_norm'] = bd.EUIwn.apply(lambda x: (x - bd.EUIwn.min())/ (bd.EUIwn.max() - bd.EUIwn.min()))

"""
PLUTO DATA
"""
# PLUTO data set features that could be relevant. 
pluto_class_dummies = [u'BldgClass', u'LandUse', u'OwnerType', u'AreaSource', u'Ext', \
                       u'ProxCode', u'IrrLotCode', u'LotType', u'BsmtCode']
pluto_class = []
pluto_cont = [u'Easements', u'LotArea', u'BldgArea', u'ComArea', u'ResArea', u'OfficeArea', \
              u'RetailArea', u'GarageArea', u'StrgeArea', u'FactryArea', u'OtherArea', \
              u'NumBldgs', u'NumFloors', u'UnitsRes', u'UnitsTotal', u'LotFront', u'LotDepth', \
              u'BldgFront', u'BldgDepth', u'AssessLand', u'AssessTot', u'ExemptLand', u'ExemptTot', \
              u'BuiltFAR', u'MaxAllwFAR']

# Make a dummy field for if the BBL has a Landmark
bd['Landmarked'] = bd.Landmark.apply(lambda x: 0 if x == (' ' * 35) else 1)
pluto_class.append('Landmarked')

# convert BuiltCode to a dummy of 1 means year built is an estimate
bd.BuiltCode = bd.BuiltCode.apply(lambda x: 1 if x == 'E' else 0)
pluto_class.append('BuiltCode')

# convert the 9 observations with year built of 0 to the mean of year built and make BuiltCode true
bd.ix[bd.YearBuilt == 0, 'BuiltCode'] = 1
bd.ix[bd.YearBuilt == 0, 'YearBuilt'] = bd.YearBuilt.mean()
pluto_cont.append('YearBuilt')

# latest year work was done
bd['YearLastWork'] = bd[['YearBuilt','YearAlter1','YearAlter2']].max(axis=1)
pluto_cont.append('YearLastWork')

# dummy for if alterations ever occured
bd['Altered'] = (bd.YearAlter1 > 0)
pluto_class.append('Altered')

# lot area percentages
bd.ix[bd.BldgArea == 0, ['BldgArea']] = 1
area_types = [u'ComArea', u'ResArea', u'OfficeArea', u'RetailArea', u'GarageArea', u'StrgeArea', u'FactryArea', u'OtherArea',]
for a in area_types:
    col = 'Per'+ a
    bd[col] = bd[a] / bd['BldgArea']
    pluto_cont.append(col)
    
"""
HMCV DATA
"""
hmcv_class_dummies = []
hmcv_class = []
hmcv_cont = ['violations']

# fill in the missing values with 0
bd[list(hmcv_2012.columns)] = bd[list(hmcv_2012.columns)].fillna(0)

"""
COMBINED FEATURES
"""
all_class_dummies = orig_class_dummies + pluto_class_dummies + hmcv_class_dummies
all_class = orig_class + pluto_class + hmcv_class
all_cont = orig_cont + pluto_cont + hmcv_cont

# %% [markdown]
# #4. Predicting High Intensity Users

# %%
# import the custom machine learning helper functions that are in a separate module
import mltl

# import the cleaned data set
#bd = pd.read_csv('buildings_clean.csv', low_memory=False)
#bd = bd.set_index('BBL')

# %% [markdown]
# **Target Variable: Weather-normalized Energy Usage Intensity (EUIwn)**

# %%
plt.figure(figsize=(12,6))
plt.subplot(121)
bd.EUIwn.hist()
plt.subplot(122)
log(bd.EUIwn).hist()

# %% [markdown]
# **Initial selection of Continuous Variables**

# %%
features = pluto_cont + hmcv_cont
X = bd[features]
y = bd[['EUIwn']]

# %%
lm = mltl.Linear()
results = lm.f_test(X, y)
results.sort('r2', ascending=False)
model = lm.smf_linear(X[list(results.features)], y)
print model.summary()
# Out:
# ---------------------------------------------------------------------------
# PatsyError                                Traceback (most recent call last)
# <ipython-input-43-33fe28203206> in <module>()
#       2 results = lm.f_test(X, y)
#       3 results.sort('r2', ascending=False)
# ----> 4 model = lm.smf_linear(X[list(results.features)], y)
#       5 print model.summary()
#
# /Users/Theo/Documents/GA-DataScience/tlove_ga_projects/projects/Project 2/mltl.pyc in smf_linear(self, X, y)
#     189         """
#     190         return smf.ols(formula= ''.join(y.columns) + ' ~ ' + ' + '.join(X.columns),
# --> 191                         data=y.join(X)).fit()
#
# //anaconda/lib/python2.7/site-packages/statsmodels/base/model.pyc in from_formula(cls, formula, data, subset, *args, **kwargs)
#      96         if subset is not None:
#      97             data= data.ix[subset]
# ---> 98         endog, exog = handle_formula_data(data, None, formula)
#      99         mod = cls(endog, exog, *args, **kwargs)
#     100         mod.formula = formula
#
# //anaconda/lib/python2.7/site-packages/statsmodels/formula/formulatools.pyc in handle_formula_data(Y, X, formula, depth)
#      43     else:
#      44         if data_util._is_using_pandas(Y, None):
# ---> 45             return dmatrices(formula, Y, 2, return_type='dataframe')
#      46         else:
#      47             return dmatrices(formula, Y, 2, return_type='dataframe')
#
# //anaconda/lib/python2.7/site-packages/patsy/highlevel.pyc in dmatrices(formula_like, data, eval_env, NA_action, return_type)
#     297                                       NA_action, return_type)
#     298     if lhs.shape[1] == 0:
# --> 299         raise PatsyError("model is missing required outcome variables")
#     300     return (lhs, rhs)
#
# PatsyError: model is missing required outcome variables

# %%
list(y.columns)
# Out:
# ['EUIwn']

# %%
bd.to_csv('newer.csv')

# %%
bd2 = pd.read_csv('newer.csv')
# Out:
# //anaconda/lib/python2.7/site-packages/pandas/io/parsers.py:1159: DtypeWarning: Columns (1,199,200,203,220,269) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %%
bd2.set_index('BBL')
# Out:
#                 st_no             st_name        borough    zip bench_sub  \
# BBL
# 1000047501          1        WATER STREET      MANHATTAN  10004       Yes
# 1000057501        125        BROAD STREET      MANHATTAN  10004       Yes
# 1000087501         39    WHITEHALL STREET      MANHATTAN  10004       Yes
# 1000090001         34    WHITEHALL STREET      MANHATTAN  10004       Yes
# 1000090014         17        STATE STREET      MANHATTAN  10004       Yes
# 1000090029         24    WHITEHALL STREET      MANHATTAN  10004       Yes
# 1000100014         33    WHITEHALL STREET      MANHATTAN  10004       Yes
# 1000100016         90        BROAD STREET      MANHATTAN  10004       Yes
# 1000100023          1    WHITEHALL STREET      MANHATTAN  10004       Yes
# 1000110014         26       BEAVER STREET      MANHATTAN  10004       Yes
# 1000110021         80        BROAD STREET      MANHATTAN  10004       Yes
# 1000130001          1            BROADWAY      MANHATTAN  10004       Yes
# 1000130005         11            BROADWAY      MANHATTAN  10004       Yes
# 1000150022         21         WEST STREET      MANHATTAN  10004       Yes
# 1000157501         17       BATTERY PLACE      MANHATTAN  10004       Yes
# 1000157501         17       BATTERY PLACE      MANHATTAN  10004       Yes
# 1000157502         20         WEST STREET      MANHATTAN  10004       Yes
# 1000160015         50       BATTERY PLACE      MANHATTAN  10280       Yes
# 1000160020         70       BATTERY PLACE      MANHATTAN  10280       Yes
# 1000160100        345    SOUTH END AVENUE      MANHATTAN  10280       Yes
# 1000160120        200      LIBERTY STREET      MANHATTAN  10281       Yes
# 1000160150        250         VESEY PLACE      MANHATTAN  10282       Yes
# 1000160180         20       RIVER TERRACE      MANHATTAN  10007       Yes
# 1000160185        211    NORTH END AVENUE      MANHATTAN  10282       Yes
# 1000160190         22       RIVER TERRACE      MANHATTAN  10282       Yes
# 1000160195        325    NORTH END AVENUE      MANHATTAN  10282       Yes
# 1000160200        400     CHAMBERS STREET      MANHATTAN  10282       Yes
# 1000160210        399     CHAMBERS STREET      MANHATTAN  10282       Yes
# 1000160225          1    NORTH END AVENUE      MANHATTAN  10281       Yes
# 1000160260        200         WEST STREET      MANHATTAN  10282       Yes
# ...               ...                 ...            ...    ...       ...
# 5035437501        175          ZOE STREET  STATEN ISLAND  10305       Yes
# 5035857501        100       COLFAX AVENUE  STATEN ISLAND  10306       Yes
# 5035857502        145      LINCOLN AVENUE  STATEN ISLAND  10306       Yes
# 5039690001       2660     HYLAN BOULEVARD  STATEN ISLAND  10306       Yes
# 5039830001        655         TYSENS LANE  STATEN ISLAND  10306       Yes
# 5039830001        655         TYSENS LANE  STATEN ISLAND  10306       Yes
# 5039830001        655         TYSENS LANE  STATEN ISLAND  10306       Yes
# 5039830013       2712     HYLAN BOULEVARD  STATEN ISLAND  10306       Yes
# 5039830045        245           MILL ROAD  STATEN ISLAND  10306       Yes
# 5039830045        245           MILL ROAD  STATEN ISLAND  10306       Yes
# 5039830045        245           MILL ROAD  STATEN ISLAND  10306       Yes
# 5039830065         26      EBBITTS STREET  STATEN ISLAND  10306       Yes
# 5039830065         26      EBBITTS STREET  STATEN ISLAND  10306       Yes
# 5039830130       2754     HYLAN BOULEVARD  STATEN ISLAND  10306       Yes
# 5039830130       2754     HYLAN BOULEVARD  STATEN ISLAND  10306       Yes
# 5040010001       2838     HYLAN BOULEVARD  STATEN ISLAND  10306       Yes
# 5045007501       3465          AMBOY ROAD  STATEN ISLAND  10306       Yes
# 5052360031       3939     RICHMOND AVENUE  STATEN ISLAND  10312       Yes
# 5054917501        119    CORTELYOU AVENUE  STATEN ISLAND  10312       Yes
# 5054970007       4343          AMBOY ROAD  STATEN ISLAND  10312       Yes
# 5054970007       4343          AMBOY ROAD  STATEN ISLAND  10312       Yes
# 5059650084         7A        ARDEN AVENUE  STATEN ISLAND  10309       Yes
# 5063320006       5371          AMBOY ROAD  STATEN ISLAND  10312       Yes
# 5066700001        375      SEGUINE AVENUE  STATEN ISLAND  10309       Yes
# 5070670117        275  VETERANS ROAD WEST  STATEN ISLAND  10309       Yes
# 5071000028       2730    ARTHUR KILL ROAD  STATEN ISLAND  10309       Yes
# 5071050520       2790    ARTHUR KILL ROAD  STATEN ISLAND  10309       Yes
# 5074810001       2900  VETERANS ROAD WEST  STATEN ISLAND  10309       Yes
# 5075110001  2935-2965  VETERANS ROAD WEST  STATEN ISLAND  10309       Yes
# 5079910100         99        ELLIS STREET  STATEN ISLAND  10307       Yes
#
#             entry_no    EUI  EUIwn  water_ft2 water_method   ...     YCoord  \
# BBL                                                          ...
# 1000047501        41  102.0  287.9      16.37       Manual   ...     195097
# 1000057501      3871  119.6  261.5        NaN       Manual   ...     195131
# 1000087501      5824   59.0  163.2       8.00          ABS   ...     195378
# 1000090001      8575   99.5  302.6        NaN       Manual   ...     195318
# 1000090014       735   79.7  210.0        NaN       Manual   ...     195340
# 1000090029        93  139.4  295.2      11.06       Manual   ...     195523
# 1000100014       641  134.5  432.9        NaN       Manual   ...     195544
# 1000100016      2711   39.8  118.2        NaN       Manual   ...     195691
# 1000100023        90  102.8  244.4      17.90       Manual   ...     195695
# 1000110014      5432   79.8  115.2       0.05          ABS   ...     196059
# 1000110021     12104   52.6  146.3        NaN       Manual   ...     195875
# 1000130001     12928   65.7  183.7        NaN       Manual   ...     196109
# 1000130005       638   80.1  214.0        NaN       Manual   ...     196226
# 1000150022      4431   69.9  154.6      27.66          ABS   ...     196631
# 1000157501      5502   28.7   99.6        NaN       Manual   ...     196348
# 1000157501      9917   50.0  143.8        NaN       Manual   ...     196348
# 1000157502      2843   50.1  141.4        NaN       Manual   ...     196558
# 1000160015      3142   40.1   96.7      43.98          ABS   ...     196739
# 1000160020      2564   49.2  113.4      51.17          ABS   ...     196965
# 1000160100     10515   67.5  194.5        NaN       Manual   ...     198318
# 1000160120        45  111.2  249.7      11.53       Manual   ...     198191
# 1000160150        47   31.4  288.2      26.78       Manual   ...     199420
# 1000160180       203  112.4  197.7      30.54       Manual   ...     200349
# 1000160185       202   96.3  160.3      36.28       Manual   ...     200241
# 1000160190       517   70.3  134.6        NaN       Manual   ...     200601
# 1000160195     10059  100.5  192.0      43.57       Manual   ...     200482
# 1000160200     10060   80.9  149.9      35.49       Manual   ...     200763
# 1000160210       519   72.2  133.8        NaN       Manual   ...     200953
# 1000160225       630  148.3  366.7      25.73       Manual   ...     199607
# 1000160260      1735  111.5  325.8        NaN       Manual   ...     199677
# ...              ...    ...    ...        ...          ...   ...        ...
# 5035437501      6239   83.5  148.5       0.00       Manual   ...     152381
# 5035857501      5776   78.3  133.3        NaN       Manual   ...     150478
# 5035857502      8567  108.0  164.2        NaN       Manual   ...     150229
# 5039690001       246   49.0  147.4      14.48       Manual   ...     145476
# 5039830001       935   86.1  132.4       0.00       Manual   ...     144330
# 5039830001       936   93.8  142.7       0.00       Manual   ...     144330
# 5039830001       952   51.1   88.4       0.00       Manual   ...     144330
# 5039830013      9123  102.0  118.4      10.26          ABS   ...     144702
# 5039830045       934   57.7  104.1       0.00       Manual   ...     144654
# 5039830045       937   56.1   98.2       0.00       Manual   ...     144654
# 5039830045       938   57.6  105.0       0.00       Manual   ...     144654
# 5039830065       939   68.1  113.7       0.00       Manual   ...     144948
# 5039830065       940   72.3  127.2       0.00       Manual   ...     144948
# 5039830130      9124  210.3  602.6       0.59          ABS   ...     144746
# 5039830130        37  164.0  448.6        NaN          ABS   ...     144746
# 5040010001      7184  164.6  289.9      51.00       Manual   ...     144390
# 5045007501     12872   29.1  107.8        NaN       Manual   ...     142408
# 5052360031     12825   72.9  101.3        NaN       Manual   ...     136899
# 5054917501      9443   40.6  150.2      41.13          ABS   ...     142061
# 5054970007     11024  196.5  432.8        NaN       Manual   ...     138126
# 5054970007     11090  237.3  619.9        NaN       Manual   ...     138126
# 5059650084     10425    9.4   32.1        NaN       Manual   ...     143410
# 5063320006     10322   58.7  106.1       0.00       Manual   ...     133726
# 5066700001      6011  420.3  641.9        NaN       Manual   ...     127704
# 5070670117      8559   13.3   36.0        NaN       Manual   ...     141233
# 5071000028     11628  264.8  711.9        NaN       Manual   ...     139141
# 5071050520     12919   70.0  212.1        NaN       Manual   ...     138828
# 5074810001       131   80.8  226.7      11.87       Manual   ...     131973
# 5075110001     11109  113.9  299.3        NaN       Manual   ...     131448
# 5079910100     10557  135.9  341.2       0.00       Manual   ...     127692
#
#             ZoneMap  ZMCode   Sanborn  TaxMap EDesigNum      APPBBL  \
# BBL
# 1000047501      12b          101S001    10101            1000040001
# 1000057501      12b          101S002    10101            1000050001
# 1000087501      12b          101S001    10101            1000080032
# 1000090001      12b          101S001    10101                     0
# 1000090014      12b          101S001    10101            1000090023
# 1000090029      12b          101S001    10101                     0
# 1000100014      12b          101S001    10101                     0
# 1000100016      12b          101S001    10101                     0
# 1000100023      12b          101S001    10101                     0
# 1000110014      12b          101S001    10101                     0
# 1000110021      12b          101S001    10101                     0
# 1000130001      12b          101S003    10101                     0
# 1000130005      12b          101S003    10101                     0
# 1000150022      12b          101S003    10101                     0
# 1000157501      12b          11S 003    10101            1000150001
# 1000157501      12b          11S 003    10101            1000150001
# 1000157502      12b          11S 003    10101            1000150019
# 1000160015      12b          101S088    10101            1000160003
# 1000160020      12b          101S088    10101            1000160003
# 1000160100      12b          101S090    10101                     0
# 1000160120      12b          101S090    10101                     0
# 1000160150      12b          101S092    10101                     0
# 1000160180      12a          101S093    10101            1000160003
# 1000160185      12a          101S093    10101            1000160003
# 1000160190      12a          11S 093    10101            1000160003
# 1000160195      12a          11S 093    10101            1000160003
# 1000160200      12a          101S093    10101            1000160200
# 1000160210      12a          101S094    10101            1000160210
# 1000160225      12b          101S092    10101            1000160003
# 1000160260      12b          101S092    10101            1000160003
# ...             ...     ...       ...     ...       ...         ...
# 5035437501      27a          503 330    51601            5035430001
# 5035857501      27b          503 340    51602            5035850036
# 5035857502      27b          503 340    51602            5035850001
# 5039690001      27b          503 382    51801                     0
# 5039830001      27b          503 383    51801                     0
# 5039830001      27b          503 383    51801                     0
# 5039830001      27b          503 383    51801                     0
# 5039830013      27b          503 383    51801            5039830013
# 5039830045      27b          503 383    51801                     0
# 5039830045      27b          503 383    51801                     0
# 5039830045      27b          503 383    51801                     0
# 5039830065      27b          503 383    51801                     0
# 5039830065      27b          503 383    51801                     0
# 5039830130      27b          503 383    51801            5039830013
# 5039830130      27b          503 383    51801            5039830013
# 5040010001      27b          504 429    51801                     0
# 5045007501      33c          504 449    52001                     0
# 5052360031      33c          504 415    52301            5052360031
# 5054917501      33c          504 456    52401                     0
# 5054970007      33c          504 415    52401                     0
# 5054970007      33c          504 415    52401                     0
# 5059650084      26b       Y  599 999    52501                     0
# 5063320006      33b          505 503    52603                     0
# 5066700001      33b          505 517    52702                     0
# 5070670117      33a          505 540    52901            5070670117
# 5071000028      33a       Y  505 566    52901            5071000028
# 5071050520      32c       Y  505 583    52901            5071050520
# 5074810001      32d          599 999    53001            5074870100
# 5075110001      32d          505 587    53001            5075110001
# 5079910100      32d          505 535    53203                     0
#
#                APPDate  PLUTOMapID  Version
# BBL
# 1000047501  12/03/1993           1   12v2
# 1000057501  05/16/1995           1   12v2
# 1000087501  01/09/2008           1   12v2
# 1000090001                       1   12v2
# 1000090014  12/26/1985           1   12v2
# 1000090029                       1   12v2
# 1000100014                       1   12v2
# 1000100016                       1   12v2
# 1000100023                       1   12v2
# 1000110014                       1   12v2
# 1000110021                       1   12v2
# 1000130001                       1   12v2
# 1000130005                       1   12v2
# 1000150022                       1   12v2
# 1000157501  12/29/1998           1   12v2
# 1000157501  12/29/1998           1   12v2
# 1000157502  05/19/2006           1   12v2
# 1000160015  09/30/1988           1   12v2
# 1000160020  09/30/1988           1   12v2
# 1000160100                       1   12v2
# 1000160120                       1   12v2
# 1000160150                       1   12v2
# 1000160180  12/31/2002           1   12v2
# 1000160185  10/29/2004           1   12v2
# 1000160190  02/08/2000           1   12v2
# 1000160195  12/13/2004           1   12v2
# 1000160200  05/22/1995           1   12v2
# 1000160210  05/22/1995           1   12v2
# 1000160225  02/26/1998           1   12v2
# 1000160260  09/01/1999           1   12v2
# ...                ...         ...      ...
# 5035437501  12/31/1987           1   12v2
# 5035857501  12/08/1988           1   12v2
# 5035857502  10/25/2006           1   12v2
# 5039690001                       1   12v2
# 5039830001                       1   12v2
# 5039830001                       1   12v2
# 5039830001                       1   12v2
# 5039830013  04/24/2007           1   12v2
# 5039830045                       1   12v2
# 5039830045                       1   12v2
# 5039830045                       1   12v2
# 5039830065                       1   12v2
# 5039830065                       1   12v2
# 5039830130  04/24/2007           1   12v2
# 5039830130  04/24/2007           1   12v2
# 5040010001                       1   12v2
# 5045007501                       1   12v2
# 5052360031  05/08/1995           1   12v2
# 5054917501                       1   12v2
# 5054970007                       1   12v2
# 5054970007                       1   12v2
# 5059650084                       1   12v2
# 5063320006                       1   12v2
# 5066700001                       1   12v2
# 5070670117  05/16/2005           1   12v2
# 5071000028  03/30/2010           1   12v2
# 5071050520  05/06/2010           1   12v2
# 5074810001  07/18/2006           1   12v2
# 5075110001  05/05/2009           1   12v2
# 5079910100                       1   12v2
#
# [10532 rows x 274 columns]

# %%
# lot area percentages
area_types = [u'ComArea', u'ResArea', u'OfficeArea', u'RetailArea', u'GarageArea', u'StrgeArea', u'FactryArea', u'OtherArea',]
for a in area_types:
    col = 'Per'+ a
    bd[col] = bd[a] / bd['BldgArea']

# %%
bd[area_types+['BldgArea']].describe()
# Out:
#                ComArea          ResArea      OfficeArea      RetailArea  \
# count     10532.000000     10532.000000    10532.000000    10532.000000
# mean      76604.862134    107834.019559    32907.362704     7402.492784
# std      309473.433883    208111.677422   160613.018428    44043.077561
# min           0.000000         0.000000        0.000000        0.000000
# 25%           0.000000     41688.250000        0.000000        0.000000
# 50%        3471.500000     68491.000000        0.000000        0.000000
# 75%       54007.500000    119352.250000        0.000000     4200.000000
# max    13435076.000000  13211398.000000  5009319.000000  2092088.000000
#
#            GarageArea       StrgeArea     FactryArea        OtherArea  \
# count    10532.000000    10532.000000   10532.000000     10532.000000
# mean      4481.863369     4797.392328    2323.130460     24531.207273
# std      29051.679529    34157.673472   22573.072812    246737.304371
# min          0.000000        0.000000       0.000000         0.000000
# 25%          0.000000        0.000000       0.000000         0.000000
# 50%          0.000000        0.000000       0.000000         0.000000
# 75%          0.000000        0.000000       0.000000         0.000000
# max    1285000.000000  1615634.000000  872500.000000  13435076.000000
#
#               BldgArea
# count     10532.000000
# mean     184468.037979
# std      370087.482813
# min           0.000000
# 25%       65400.000000
# 50%       96000.000000
# 75%      170000.750000
# max    13540113.000000

# %%
bd[bd.BldgArea == 0][area_types].describe()
# Out:
#        ComArea  ResArea  OfficeArea  RetailArea  GarageArea  StrgeArea  \
# count       16       16          16          16          16         16
# mean         0        0           0           0           0          0
# std          0        0           0           0           0          0
# min          0        0           0           0           0          0
# 25%          0        0           0           0           0          0
# 50%          0        0           0           0           0          0
# 75%          0        0           0           0           0          0
# max          0        0           0           0           0          0
#
#        FactryArea  OtherArea
# count          16         16
# mean            0          0
# std             0          0
# min             0          0
# 25%             0          0
# 50%             0          0
# 75%             0          0
# max             0          0

# %%
len(bd.columns)
# Out:
# 286

# %%
bd.max().
# Out:
# st_no                                   999
# st_name                          ZOE STREET
# borough                       STATEN ISLAND
# zip                                   11694
# bench_sub                               Yes
# entry_no                              13040
# EUI                                   808.5
# EUIwn                                 988.7
# water_ft2                             99.97
# water_method                         Manual
# energy_star                              99
# GHG                                82561.06
# floor_area                     1.421712e+07
# property_type    Warehouse (Unrefrigerated)
# no_buildings                            160
# ...
# APPDate          12/31/2007
# PLUTOMapID                2
# Version              12v2
# PerComArea                1
# PerResArea         26.27401
# PerOfficeArea             1
# PerRetailArea             1
# PerGarageArea             1
# PerStrgeArea              1
# PerFactryArea             1
# PerOtherArea              1
# EUIwn_norm                1
# Landmarked                1
# YearLastWork           2012
# Altered                True
# Length: 286, dtype: object
