# %%
# %pylab inline
import pandas as pd
import seaborn as sns
from __future__ import division
import datetime

# import the custom machine learning helper functions that are in a separate module in the same folder
import mltl

sns.set_style('white')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# #Project 2 - Predicting Large Building Energy Intensity in NYC
#
# *Author:* Theodore Love
#
# *Date:* March 18, 2015
#
# Local Law 84 requires large buildings in NYC to disclose energy usage intensity (EUI is a measure of energy usage per square foot). What if we were able to predict these values based on other sources of information? Or, figure out what portion of a buildings energy usage can be explained by it's general characteristics and identify those buildings that have larger than normal unexplained energy intensity?
#
# This project attempts to use basic information avaiable from NYC's large collection of tax lot characteristics to see if it is possible to predict large building usage.
#
# **Contents**
# 1. Overview of Data Collected in Project 1
# 2. Side Exploration of Housing Maintenence Code Violations
# 3. PLUTO
# 3. Combining Data Sets
# 4. Predicting EUI

# %% [markdown]
# > **NOTE:** The data sources for this project were too large for github, but a cleaned and merged version of the data used for the analysis can be found in this folder and the code to import it is located at the beginning of section 4. The code below sets the local directory where the source data is currently stored.

# %%
data_folder = '/Users/Theo/Dropbox (Personal)/ProgrammingProjects/GADSdata'

# %% [markdown]
# ## 1. Overview of Data Collected in Project 1

# %% [markdown]
# This analysis is primarily based on data relating to [NYC Local Law 84](http://www.nyc.gov/html/gbee/html/plan/ll84.shtml), which requires private sector buildings that are larger than 50,000 square feet, and two or more private sector buildings on a single lot that are larger than 100,000 square feet, to provide annual data on energy and water consumption. Significant analysis has been done on this data set and presented in a [series of reports](http://www.nyc.gov/html/gbee/html/plan/ll84_scores.shtml). This analysis attempts to extend this previous work.
#
# The original data covers five basic categories of information:
# * Building Location (borough/block/lot, address, etc.)
# * Building Info (building type, square footage, id, etc.)
# * Energy Usage (gross kBTUs/ft2, weather normalized kBTUs/ft2, ENERGY STAR score)
# * Water Usage per ft2 (along with source)
# * GHG Emissions (calculated from kBtu/ft2 and a coefficient estimate)
#
# All of this data is sourced from [NYC Open Data](https://nycopendata.socrata.com/), and has both zip code and borough/block/lot information, which makes for a good way to work in other data sets.
#
# **Data Sets Used in Project 1**
#
# |Name | Source |
# |---| --- |
# |Local Law 84 Disclosures (2011) | [Source](https://data.cityofnewyork.us/Environment/Energy-and-Water-Data-Disclosure-for-Local-Law-84-/q39e-7gbs)|
# |Local Law 84 Disclosures (2012 | [Source](https://data.cityofnewyork.us/Environment/Energy-and-Water-Data-Disclosure-for-Local-Law-84-/5gde-fmj3)|
#
# **Data Set for Project 2**
#
# In order to keep this project's analysis to a more manageable scope, we will **only look at data for 2012**, which was both more comprehensive and had less issues than 2011 data. This also allows us to establish **BBL** as a a unique key (with a little bit of wrangling).

# %%
# import and rename columns
buildings = pd.read_csv(data_folder +  '/Energy_and_Water_Data_Disclosure_for_Local_Law_84__2012.csv')
buildings.columns = "bbl st_no st_name borough zip bench_sub entry_no EUI EUIwn water_ft2 \
            water_method energy_star GHG floor_area property_type no_buildings reported_BINS".split()
buildings.ix[buildings['energy_star'] == 'Exempt', 'energy_star'] = np.NaN

# Remove the anomalies the same was as in Project 1
curr = len(buildings)
print "Anomalies"
print "========="
print "Starting observations: %i" % curr

buildings = buildings[pd.notnull(buildings['EUIwn'])]
print "Missing EUIwn: %i" % (curr - len(buildings))
curr = len(buildings)

buildings = buildings[buildings['EUI'] > 0]
print "EUI of 0: %i" % (curr - len(buildings))
curr = len(buildings)

buildings = buildings[buildings['EUIwn'] >= 5]
print "EUIwn < 5: %i" % (curr - len(buildings))
curr = len(buildings)

buildings = buildings[buildings['EUIwn'] <= 1000]
print "EUIwn > 1,000: %i" % (curr - len(buildings))
curr = len(buildings)

buildings = buildings[buildings['floor_area'] >= 25000]
print "floor area < 25k ft2: %i" % (curr - len(buildings))
curr = len(buildings)

buildings = buildings[pd.notnull(buildings['GHG'])]
print "Missing GHG: %i" % (curr - len(buildings))
curr = len(buildings)

print "Water per ft2 > 100: %i (kept observation)" % len(buildings[buildings['water_ft2'] > 100])  
buildings['water_ft2'] = buildings['water_ft2'].apply(lambda x: np.NaN if x > 100 else x)

# In order to make a unique list by BBL, ignore any BBLs with more than one entry
bbl_count = buildings.bbl.groupby(buildings.bbl).count()
multi_bbl = list(bbl_count[bbl_count >1].index)
buildings['multi_bbl'] = buildings.bbl.apply(lambda x: x in multi_bbl)
print "Multiple observations in a BBL: %i" % (len(buildings[buildings.multi_bbl]))
buildings = buildings[buildings.multi_bbl == False]

print "Remaining observations: %i" % len(buildings)
buildings = buildings.set_index('bbl')
# Out:
# Anomalies
# =========
# Starting observations: 14112
# Missing EUIwn: 3041
# EUI of 0: 67
# EUIwn < 5: 52
# EUIwn > 1,000: 110
# floor area < 25k ft2: 273
# Missing GHG: 37
# Water per ft2 > 100: 480 (kept observation)
# Multiple observations in a BBL: 801
# Remaining observations: 9731

# %% [markdown]
# ##2. Side Note on Housing Maintence Code Violations
#
# [Housing code violations](https://data.cityofnewyork.us/Housing-Development/Housing-Maintenance-Code-Violations/wvxf-dwi5) may have some predictive power for **Multifamily** buildings, and are available by BBL.
#
# In order to make the data as relevant as possible to 2012, only violations that were observed in 2012 will be used (i.e. **InspectionDate** has the year 2012).
#
# The data is by unique violation, so some aggregation is necessary. Each violation has a text description, which may be interesting to examine later, but for now the pertinant field will be **OrderNumber**, which corresponds to the law which is being violated.
#
# After filtering and aggregating, we have a dataframe that, for each **BBL**, provides a count of violations observed in 2012 for each **OrderNumber**.

# %%
# import the data and create a bbl field
hmcv = pd.read_csv(data_folder + "/housing_maint_violations/Housing_Maintenance_Code_Violations.csv", low_memory=False)
hmcv['bbl'] = hmcv.BoroID.map(str) + \
              hmcv.Block.apply(lambda x: str(x).zfill(5)) + \
              hmcv.Lot.apply(lambda x: str(x).zfill(4))
hmcv.bbl = hmcv.bbl.map(int)

# convert the InspectionDate to a datetime field and extract a new column for year
hmcv.InspectionDate = pd.to_datetime(hmcv.InspectionDate)
hmcv['InspectionYear'] = hmcv.InspectionDate.apply(lambda x: x.year)

# get the count of each OrderNum by BBL in 2012 and make a sum of violations feature
hmcv_2012 = pd.pivot_table(hmcv[hmcv.InspectionYear == 2012][['bbl','OrderNumber']],
                           values=['OrderNumber'],
                           index=['bbl'],
                           columns=['OrderNumber'],
                           aggfunc=len,
                           fill_value=0)
hmcv_2012.columns = 'hmcv_num_' + hmcv_2012.columns.map(str)
hmcv_2012['violations'] = hmcv_2012.sum(axis=1)
hmcv_2012.describe()
# Out:
#         hmcv_num_4   hmcv_num_8  hmcv_num_84  hmcv_num_106  hmcv_num_109  \
# count  2760.000000  2760.000000  2760.000000   2760.000000   2760.000000
# mean      0.002536     0.000362     0.000362      0.009783      0.002536
# std       0.063091     0.019035     0.019035      0.115390      0.073691
# min       0.000000     0.000000     0.000000      0.000000      0.000000
# 25%       0.000000     0.000000     0.000000      0.000000      0.000000
# 50%       0.000000     0.000000     0.000000      0.000000      0.000000
# 75%       0.000000     0.000000     0.000000      0.000000      0.000000
# max       2.000000     1.000000     1.000000      3.000000      3.000000
#
#        hmcv_num_118  hmcv_num_176  hmcv_num_188  hmcv_num_209  hmcv_num_483  \
# count   2760.000000   2760.000000   2760.000000   2760.000000   2760.000000
# mean       0.000362      0.000725      0.002174      0.000725      0.001449
# std        0.019035      0.026914      0.046583      0.026914      0.038049
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#            ...       hmcv_num_1042  hmcv_num_1051  hmcv_num_1061  \
# count      ...         2760.000000    2760.000000    2760.000000
# mean       ...            0.008333       0.000362       0.005072
# std        ...            0.143493       0.019035       0.080612
# min        ...            0.000000       0.000000       0.000000
# 25%        ...            0.000000       0.000000       0.000000
# 50%        ...            0.000000       0.000000       0.000000
# 75%        ...            0.000000       0.000000       0.000000
# max        ...            4.000000       1.000000       2.000000
#
#        hmcv_num_1067  hmcv_num_1492  hmcv_num_1493  hmcv_num_1501  \
# count    2760.000000    2760.000000    2760.000000    2760.000000
# mean        0.002174       0.000362       0.001812       0.007971
# std         0.065914       0.019035       0.042532       0.092926
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         3.000000       1.000000       1.000000       2.000000
#
#        hmcv_num_1502  hmcv_num_1503   violations
# count    2760.000000    2760.000000  2760.000000
# mean        0.307246       0.165580     8.538406
# std         0.827108       0.552214    14.117484
# min         0.000000       0.000000     1.000000
# 25%         0.000000       0.000000     2.000000
# 50%         0.000000       0.000000     4.000000
# 75%         0.000000       0.000000    10.000000
# max        14.000000       6.000000   293.000000
#
# [8 rows x 178 columns]

# %%
# merge in the housing maintenance code violations
bd = buildings.join(hmcv_2012)
print "Code Violation data merged: %i features and %i observations." % (len(bd.columns), len(bd))

# fill in the missing values with 0 and drop any columns that don't have any values
bd[list(hmcv_2012.columns)] = bd[list(hmcv_2012.columns)].fillna(0)
bd_sum = bd[list(hmcv_2012.columns)].sum()
no_violations = list(bd_sum[bd_sum == 0].index)
bd.drop(labels=no_violations, axis=1, inplace=True)

# show the count by property_type
cols = [x for x in list(hmcv_2012.columns) if x not in no_violations] + ['property_type']
group_violations = bd[cols].groupby('property_type').sum()
print "Observations with violations: %i" % len(bd[bd.violations > 0])
group_violations[group_violations.violations > 0]
# Out:
# Code Violation data merged: 195 features and 9731 observations.
# Observations with violations: 449
#                           hmcv_num_106  hmcv_num_484  hmcv_num_491  \
# property_type
# Multifamily Housing                  4             3            24
# Office                               0             0             1
# Public Assembly                      0             0             0
# Residence Hall/Dormitory             0             0             0
# Senior Care Facility                 0             0             0
#
#                           hmcv_num_501  hmcv_num_502  hmcv_num_503  \
# property_type
# Multifamily Housing                383           328             1
# Office                               0             1             0
# Public Assembly                      0             2             0
# Residence Hall/Dormitory             0             0             0
# Senior Care Facility                 1             0             0
#
#                           hmcv_num_504  hmcv_num_505  hmcv_num_506  \
# property_type
# Multifamily Housing                 17           125            53
# Office                               1             2             0
# Public Assembly                      0             0             0
# Residence Hall/Dormitory             0             0             0
# Senior Care Facility                 0             0             0
#
#                           hmcv_num_507      ...       hmcv_num_765  \
# property_type                               ...
# Multifamily Housing                 47      ...                  1
# Office                               0      ...                  0
# Public Assembly                      0      ...                  0
# Residence Hall/Dormitory             0      ...                  0
# Senior Care Facility                 0      ...                  0
#
#                           hmcv_num_778  hmcv_num_790  hmcv_num_791  \
# property_type
# Multifamily Housing                  2            55             1
# Office                               0             1             0
# Public Assembly                      0             0             0
# Residence Hall/Dormitory             0             0             0
# Senior Care Facility                 0             0             0
#
#                           hmcv_num_807  hmcv_num_883  hmcv_num_1501  \
# property_type
# Multifamily Housing                  1             1              1
# Office                               0             0              0
# Public Assembly                      0             0              0
# Residence Hall/Dormitory             0             0              0
# Senior Care Facility                 0             0              0
#
#                           hmcv_num_1502  hmcv_num_1503  violations
# property_type
# Multifamily Housing                 110             57        4146
# Office                                0              0          29
# Public Assembly                       0              0           3
# Residence Hall/Dormitory              1              0           2
# Senior Care Facility                  0              0           6
#
# [5 rows x 81 columns]

# %% [markdown]
# Not many buildings had violations, and almost all of them were for **Multifamily Housing**. Next we will plot the relationship and see if it has any explanatory power.

# %%
# plot the number of violations against the EUIwn
bd_violations = bd[bd.violations > 0 ]
plt.figure(figsize=(10, 8))
plt.subplot(111)
plt.scatter(bd_violations.violations, bd_violations.EUIwn,)
plt.show()

# show a quick regression
lm = mltl.Linear()
print lm.smf_linear(['violations'],'EUIwn', bd_violations).summary()
# Out:
# EUIwn ~ violations
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.7655
# Date:                Wed, 18 Mar 2015   Prob (F-statistic):              0.382
# Time:                        16:13:19   Log-Likelihood:                -2382.5
# No. Observations:                 449   AIC:                             4769.
# Df Residuals:                     447   BIC:                             4777.
# Df Model:                           1
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    130.5719      2.609     50.052      0.000       125.445   135.699
# violations     0.1142      0.131      0.875      0.382        -0.142     0.371
# ==============================================================================
# Omnibus:                       65.853   Durbin-Watson:                   1.800
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              175.429
# Skew:                           0.716   Prob(JB):                     8.05e-39
# Kurtosis:                       5.706   Cond. No.                         22.6
# ==============================================================================

# %% [markdown]
# The graph shows some skew in **EUIwn** as violations increase, but the relaitionship is not significant even when looking just at the subset of buildings with violations. Becuase of this, the focus of the rest of the project will be on PLUTO data.

# %% [markdown]
# ## 3. PLUTO

# %% [markdown]
# NYC maintains extensive land use and geographic data at the tax lot level in their Primary Land Use Tax Lot Output database ([PLUTO](http://www.nyc.gov/html/dcp/html/bytes/dwn_pluto_mappluto.shtml)). NYC maintains [historical PLUTO data](http://www.nyc.gov/html/dcp/html/bytes/archive_pluto_mappluto.shtml) back to 2002, and for this analysis, the 2012 data (v2) is used, in order to align as closely as possible with the timing of the Local Law 84 data from 2012.

# %%
"""
2012 PLUTO data is saved by borough, so each is imported separately and then combined
 - Skip blank line at bottom
 - Skip leading spaces
 - BBL is a unique key
"""

# Manhattan
mn = pd.read_csv(data_folder + '/nyc_pluto_12v2/mn12v2.txt', 
                 skipfooter=1,
                 engine="python",
                 skipinitialspace=True,
                 )

# Bronx
bx = pd.read_csv(data_folder + '/nyc_pluto_12v2/bx12v2.txt',
                 skipfooter=1,
                 engine="python",
                 skipinitialspace=True,
                 )

# Brooklyn
bk = pd.read_csv(data_folder + '/nyc_pluto_12v2/bk12v2.txt',
                 skipfooter=1,
                 engine="python",
                 skipinitialspace=True,
                 )

# Queens
qn = pd.read_csv(data_folder + '/nyc_pluto_12v2/qn12v2.txt',
                 skipfooter=1,
                 engine="python",
                 skipinitialspace=True,
                 )

# Staten Island
si = pd.read_csv(data_folder + '/nyc_pluto_12v2/si12v2.txt',
                 skipfooter=1,
                 engine="python",
                 skipinitialspace=True,
                 )

# Combine and set BBL as the index (already checked for uniqueness)
pluto = pd.concat([mn,bx,bk,qn,si], axis=0)
pluto.describe()
# Out:
#                Block            Lot             CD        Council  \
# count  859324.000000  859324.000000  859324.000000  855398.000000
# mean     5301.815771     125.284543     354.036419      32.030069
# std      3695.489329     712.010049     101.004411      13.215942
# min         0.000000       0.000000     101.000000       0.000000
# 25%      2298.000000      19.000000     306.000000      22.000000
# 50%      4803.000000      38.000000     401.000000      32.000000
# 75%      7456.000000      64.000000     412.000000      44.000000
# max     16350.000000    9978.000000     595.000000      51.000000
#
#           PolicePrct      Easements       LotArea         BldgArea  \
# count  855388.000000  859324.000000  8.593240e+05    859324.000000
# mean       86.806960       0.005074  7.867791e+03      6313.022123
# std        29.413449       0.083615  3.703630e+05     66822.328779
# min         1.000000       0.000000  0.000000e+00         0.000000
# 25%        66.000000       0.000000  2.000000e+03      1440.000000
# 50%       102.000000       0.000000  2.513000e+03      2088.000000
# 75%       111.000000       0.000000  4.000000e+03      3120.000000
# max       123.000000      13.000000  2.147557e+08  27600000.000000
#
#                ComArea          ResArea       ...              BuiltFAR  \
# count    859324.000000    859324.000000       ...         859324.000000
# mean       2228.923938      4082.527828       ...              1.140965
# std       59277.914889     29323.434469       ...             12.595126
# min           0.000000         0.000000       ...              0.000000
# 25%           0.000000      1281.000000       ...              0.480000
# 50%           0.000000      1898.000000       ...              0.780000
# 75%           0.000000      2763.000000       ...              1.280000
# max    27600000.000000  13211398.000000       ...           6088.800000
#
#           MaxAllwFAR       BoroCode           BBL        CondoNo  \
# count  859324.000000  859324.000000  8.593240e+05  859324.000000
# mean        1.446861       3.459120  3.512138e+09       8.970288
# std         1.468102       1.023812  1.031994e+09     127.951807
# min         0.000000       1.000000  1.000010e+09       0.000000
# 25%         0.600000       3.000000  3.030790e+09       0.000000
# 50%         0.900000       4.000000  4.008320e+09       0.000000
# 75%         2.000000       4.000000  4.106040e+09       0.000000
# max        15.000000       5.000000  5.080500e+09    9566.000000
#
#            Tract2010          XCoord         YCoord        APPBBL  \
# count  859324.000000   829419.000000  829419.000000  8.581930e+05
# mean     9232.698645  1006257.479815  191689.518341  3.538946e+08
# std     26256.936042    32217.315934   30463.493201  1.162034e+09
# min         0.000000   913236.000000  120308.000000  0.000000e+00
# 25%       206.000000   989615.500000  168454.000000  0.000000e+00
# 50%       484.000000  1008653.000000  189303.000000  0.000000e+00
# 75%      1116.000000  1028971.000000  211104.000000  0.000000e+00
# max    157903.000000  1067277.000000  272316.000000  5.080480e+09
#
#           PLUTOMapID
# count  859324.000000
# mean        1.004698
# std         0.093883
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         5.000000
#
# [8 rows x 42 columns]

# %% [markdown]
# ##3. Combining Data Sets
#
# **Merge in New Data**
#
# Merge in the *PLUTO* data on **bbl**.

# %%
print "Buildings data: %i features and %i observations." % (len(buildings.columns), len(buildings))

# merge in the PLUTO data
bd = bd.merge(pluto, how='left', left_index=True, right_on=['BBL'])
print "PLUTO data merged: %i features and %i observations." % (len(bd.columns), len(bd))

bd = bd.set_index(bd.BBL)
# Out:
# Buildings data: 17 features and 9731 observations.
# PLUTO data merged: 178 features and 9731 observations.

# %% [markdown]
# **New Variables and Relevant Feature Lists**
#
# Create some new variables and lists for each different kind of feature that we want to explore in our supervised machine learning. Put the features in to three general categories
#
# > **Targets**: variables to predict
#
# > **Class Dummies**: classification columns that need to be made in to dummy columns (ignored until later)
#
# > **Class**: classification columns that are already True/False
#
# > **Cont**: continuous variables

# %%
"""
ORIGINAL DATA
"""
# original data set features that could be relevent
targets = ['EUIwn', 'EUI']
orig_class_dummies = [u'borough', u'zip', u'property_type',]
orig_class = [u'water_method']
orig_cont = [u'water_ft2', u'energy_star', u'GHG', u'floor_area', u'no_buildings',]

# normalize EUIwn
bd['EUIwn_norm'] = bd.EUIwn.apply(lambda x: (x - bd.EUIwn.min())/ (bd.EUIwn.max() - bd.EUIwn.min()))
targets.append('EUIwn_norm')

"""
PLUTO DATA
"""
# PLUTO data set features that could be relevant. 
pluto_class_dummies = [u'BldgClass', u'LandUse', u'OwnerType', u'AreaSource', u'Ext', \
                       u'ProxCode', u'IrrLotCode', u'LotType', u'BsmtCode']
pluto_class = []
pluto_cont = [u'Easements', u'LotArea', u'BldgArea', u'ComArea', u'ResArea', u'OfficeArea', \
              u'RetailArea', u'GarageArea', u'StrgeArea', u'FactryArea', u'OtherArea', \
              u'NumBldgs', u'NumFloors', u'UnitsRes', u'UnitsTotal', u'LotFront', u'LotDepth', \
              u'BldgFront', u'BldgDepth', u'AssessLand', u'AssessTot', u'ExemptLand', u'ExemptTot', \
              u'BuiltFAR', u'MaxAllwFAR']

# Make a dummy field for if the BBL has a Landmark
bd['Landmarked'] = bd.Landmark.apply(lambda x: 0 if x == (' ' * 35) else 1)
pluto_class.append('Landmarked')

# convert BuiltCode to a dummy of 1 means year built is an estimate
bd.BuiltCode = bd.BuiltCode.apply(lambda x: 1 if x == 'E' else 0)
pluto_class.append('BuiltCode')

# convert the 9 observations with year built of 0 to the mean of year built and make BuiltCode true
bd.ix[bd.YearBuilt == 0, 'BuiltCode'] = 1
bd.ix[bd.YearBuilt == 0, 'YearBuilt'] = bd.YearBuilt.mean()
pluto_cont.append('YearBuilt')

# latest year work was done
bd['YearLastWork'] = bd[['YearBuilt','YearAlter1','YearAlter2']].max(axis=1)
pluto_cont.append('YearLastWork')

# dummy for if alterations ever occured
bd['Altered'] = (bd.YearAlter1 > 0)
pluto_class.append('Altered')

# lot area percentages
bd.ix[bd.BldgArea == 0, ['BldgArea']] = 1 # Six BBLs have an area of 0, so change to 1 for purposes of division
area_types = [u'ComArea', u'ResArea', u'OfficeArea', u'RetailArea', u'GarageArea', u'StrgeArea', u'FactryArea', u'OtherArea',]
for a in area_types:
    col = 'Per'+ a
    bd[col] = bd[a] / bd['BldgArea']
    pluto_cont.append(col)
    
print "Current dataset: %i features and %i observatsion." % (len(bd.columns), len(bd))
# Out:
# Current dataset: 190 features and 9731 observatsion.

# %% [markdown]
# #4. Predicting EUI

# %% [markdown]
# Let's see if we can predict the EUIwn based on the separate *PLUTO* data.
#
# > **NOTE:** The code in the next cell is for importing the cleaned data set and setting the current list of features

# %%
# import the merged and cleaned data set from its csv
bd = pd.read_csv('buildings_clean.csv', low_memory=False)
bd = bd.set_index('BBL')

# set the various feature sets as well
targets = ['EUIwn', 'EUI', 'EUIwn_norm']
orig_class_dummies = [u'borough', u'zip', u'property_type']
orig_class = [u'water_method']
orig_cont = [u'water_ft2', u'energy_star', u'GHG', u'floor_area', u'no_buildings']
pluto_class_dummies = [u'BldgClass', u'LandUse', u'OwnerType', u'AreaSource', u'Ext', u'ProxCode', \
                       u'IrrLotCode', u'LotType', u'BsmtCode']
pluto_class = ['Landmarked', 'BuiltCode', 'Altered']
pluto_cont = [u'Easements', u'LotArea', u'BldgArea', u'ComArea', u'ResArea', u'OfficeArea', \
              u'RetailArea', u'GarageArea', u'StrgeArea', u'FactryArea', u'OtherArea', \
              u'NumBldgs', u'NumFloors', u'UnitsRes', u'UnitsTotal', u'LotFront', u'LotDepth', \
              u'BldgFront', u'BldgDepth', u'AssessLand', u'AssessTot', u'ExemptLand', u'ExemptTot', \
              u'BuiltFAR', u'MaxAllwFAR', 'YearBuilt', 'YearLastWork', u'PerComArea', u'PerResArea', \
              u'PerOfficeArea', u'PerRetailArea', u'PerGarageArea', u'PerStrgeArea', u'PerFactryArea',\
              u'PerOtherArea']

# %% [markdown]
# ### Target Variable: Weather-normalized Energy Usage Intensity (EUIwn)
#
# It looks like it has some sort of log-normal distribution, but we will wait to explore that transformation until later.

# %%
plt.figure(figsize=(12,6))
plt.subplot(121)
bd.EUIwn.hist()
plt.xlabel('EUIwn')
plt.subplot(122)
log(bd.EUIwn).hist()
plt.xlabel('Log Transform of EUIwn')

# %% [markdown]
# ###Initial selection of Continuous Variables
#
# Let's test out the continuous variables in a linear regression to see if anything sticks out

# %%
# create the X and the y
features = pluto_cont
X = bd[features]
y = bd[['EUIwn']]

# use the f_test from our linear regression helper class to see what was significant at the 95% confidence interval
lm = mltl.Linear()
linear_results = lm.f_test(X, y, ci=0.95)
print "%i of %i features passed (%0.1f percent)" % (len(linear_results), len(features), 100*len(linear_results)/len(features))
linear_results.sort('r2', ascending=False)
# Out:
# 33 of 35 features passed (94.3 percent)
#         F score        feature        p-value        r2
# 25  1447.930408     PerComArea  1.754402e-295  0.129546
# 27  1026.606002  PerOfficeArea  3.072322e-214  0.095448
# 26   977.448562     PerResArea  1.495496e-204  0.091295
# 19   869.720653      AssessTot  3.653612e-183  0.082059
# 18   689.249410     AssessLand  7.801710e-147  0.066158
# 32   635.075351   PerOtherArea  8.373825e-136  0.061277
# 3    634.407243        ComArea  1.146384e-135  0.061216
# 5    624.479377     OfficeArea  1.222770e-133  0.060316
# 21   459.106045      ExemptTot   1.469601e-99  0.045063
# 28   381.069192  PerRetailArea   2.818113e-83  0.037692
# 12   375.752199      NumFloors   3.666265e-82  0.037186
# 22   365.530914     MaxAllwFAR   5.105423e-80  0.036211
# 24   307.837834   YearLastWork   7.124478e-68  0.030671
# 20   262.845600     ExemptLand   2.384670e-58  0.026306
# 23   243.104502      YearBuilt   3.731713e-54  0.024378
# 2    218.975182       BldgArea   5.151867e-49  0.022012
# 16   144.048531       LotDepth   5.921968e-33  0.014590
# 6    125.808637     RetailArea   5.100431e-29  0.012766
# 1     88.952232        LotArea   4.972916e-21  0.009060
# 10    86.863151      OtherArea   1.416414e-20  0.008849
# 15    79.616935       LotFront   5.366147e-19  0.008117
# 30    67.240625   PerStrgeArea   2.706976e-16  0.006864
# 4     54.967273        ResArea   1.327796e-13  0.005618
# 7     53.216957     GarageArea   3.220000e-13  0.005440
# 29    35.321986  PerGarageArea   2.890589e-09  0.003617
# 31    33.228205  PerFactryArea   8.444827e-09  0.003404
# 17    29.121844      BldgDepth   6.956320e-08  0.002984
# 0     28.631566      Easements   8.953307e-08  0.002934
# 13    21.641245       UnitsRes   3.330444e-06  0.002219
# 8     15.353127      StrgeArea   8.978368e-05  0.001576
# 14    13.058557     UnitsTotal   3.034252e-04  0.001340
# 9     11.020272     FactryArea   9.045218e-04  0.001131
# 11    10.201879       NumBldgs   1.407449e-03  0.001048

# %% [markdown]
# Generally we see that:
# * Looks like the data on usage area by type is doing well, and taking it as a percent of the total is the best. This makes sense given that industry type should be one of the best indicators of EUI. It seems the best split is between the commercial versus residential.
# * Assessed value does well, and so does exempt tax amount
# * YearLastWork does better than YearBuilt (which is good)
# * None of the violation data passed
#
# Let's see where we get with a linear model looking at a selection of these values

# %% [markdown]
# ###Make Train/Test Split
#
# To do our supervised learning we will need a to separate the data in to a training set and testing set

# %%
from sklearn import cross_validation

# create one train/test split
sp = cross_validation.ShuffleSplit(len(bd), n_iter=3, test_size=0.3, random_state=3482)
for train_index, test_index in sp:
    bd_train = bd.iloc[train_index]
    bd_test = bd.iloc[test_index]

# %% [markdown]
# ###Building Area Usage
#
# The initial f-test results show that, as expected, it matters what the building is used for. We also see that looking at usage type as a percentage of total type seemed to have much more better effect, which frees us up to use the total **BldgArea** as a measure of amplitude.
#
# The main split to be expected is the one between residential and commercial, and since they are both the highest explanatory variables on their own, it probably won't help that much to add them together. The difference will probably come from looking at values that effect the extremes (perhaps storage or industrial work).
#
# Let's play the various building area percentage fields and the total area to see what we can come up with.

# %%
# start with building age data
print lm.smf_linear(['PerComArea'],
                    'EUIwn', bd_train).summary()
# Out:
# EUIwn ~ PerComArea
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.126
# Model:                            OLS   Adj. R-squared:                  0.126
# Method:                 Least Squares   F-statistic:                     986.1
# Date:                Wed, 18 Mar 2015   Prob (F-statistic):          2.94e-202
# Time:                        17:26:04   Log-Likelihood:                -39934.
# No. Observations:                6811   AIC:                         7.987e+04
# Df Residuals:                    6809   BIC:                         7.989e+04
# Df Model:                           1
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    124.9941      1.231    101.554      0.000       122.581   127.407
# PerComArea    79.4452      2.530     31.401      0.000        74.486    84.405
# ==============================================================================
# Omnibus:                     4718.919   Durbin-Watson:                   2.012
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           117573.109
# Skew:                           2.990   Prob(JB):                         0.00
# Kurtosis:                      22.456   Cond. No.                         2.66
# ==============================================================================

# %%
# check to see if building total area helps (it will probably cause multicolinearity issues)
print lm.smf_linear(['PerComArea', 'BldgArea'],
                    'EUIwn', bd_train).summary()
# Out:
# EUIwn ~ PerComArea + BldgArea
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.138
# Model:                            OLS   Adj. R-squared:                  0.138
# Method:                 Least Squares   F-statistic:                     779.1
# Date:                Wed, 18 Mar 2015   Prob (F-statistic):          1.47e-314
# Time:                        16:31:09   Log-Likelihood:                -56612.
# No. Observations:                9731   AIC:                         1.132e+05
# Df Residuals:                    9728   BIC:                         1.133e+05
# Df Model:                           2
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    120.9767      1.055    114.715      0.000       118.910   123.044
# PerComArea    73.6500      2.035     36.190      0.000        69.661    77.639
# BldgArea     2.82e-05   2.88e-06      9.801      0.000      2.26e-05  3.38e-05
# ==============================================================================
# Omnibus:                     6400.338   Durbin-Watson:                   1.806
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           154791.208
# Skew:                           2.786   Prob(JB):                         0.00
# Kurtosis:                      21.727   Cond. No.                     8.46e+05
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 8.46e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# test if residential adds any value
print lm.smf_linear(['PerComArea', 'PerResArea'],
                    'EUIwn', bd_train).summary()
# Out:
# EUIwn ~ PerComArea + PerResArea
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.130
# Model:                            OLS   Adj. R-squared:                  0.129
# Method:                 Least Squares   F-statistic:                     724.5
# Date:                Wed, 18 Mar 2015   Prob (F-statistic):          4.83e-294
# Time:                        16:31:10   Log-Likelihood:                -56659.
# No. Observations:                9731   AIC:                         1.133e+05
# Df Residuals:                    9728   BIC:                         1.133e+05
# Df Model:                           2
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    127.7698      3.138     40.716      0.000       121.618   133.921
# PerComArea    73.7451      3.562     20.703      0.000        66.763    80.727
# PerResArea    -3.1343      2.987     -1.049      0.294        -8.989     2.720
# ==============================================================================
# Omnibus:                     6398.419   Durbin-Watson:                   1.794
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           149233.271
# Skew:                           2.799   Prob(JB):                         0.00
# Kurtosis:                      21.350   Cond. No.                         8.38
# ==============================================================================

# %%
# Since residential doesn't, test office
print lm.smf_linear(['PerComArea', 'PerOfficeArea'],
                    'EUIwn', bd_train).summary()
# Out:
# EUIwn ~ PerComArea + PerOfficeArea
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.142
# Model:                            OLS   Adj. R-squared:                  0.142
# Method:                 Least Squares   F-statistic:                     804.1
# Date:                Wed, 18 Mar 2015   Prob (F-statistic):          4.94e-324
# Time:                        16:31:10   Log-Likelihood:                -56590.
# No. Observations:                9731   AIC:                         1.132e+05
# Df Residuals:                    9728   BIC:                         1.132e+05
# Df Model:                           2
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       125.0719      0.984    127.052      0.000       123.142   127.002
# PerComArea       58.3351      2.543     22.938      0.000        53.350    63.320
# PerOfficeArea    44.5918      3.774     11.815      0.000        37.194    51.990
# ==============================================================================
# Omnibus:                     6574.847   Durbin-Watson:                   1.804
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           154577.675
# Skew:                           2.911   Prob(JB):                         0.00
# Kurtosis:                      21.637   Cond. No.                         5.33
# ==============================================================================

# %%
# See if office and res are a better fit
print lm.smf_linear(['PerResArea', 'PerOfficeArea'],
                    'EUIwn', bd_train).summary()
# Out:
# EUIwn ~ PerResArea + PerOfficeArea
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.123
# Model:                            OLS   Adj. R-squared:                  0.123
# Method:                 Least Squares   F-statistic:                     682.9
# Date:                Wed, 18 Mar 2015   Prob (F-statistic):          2.94e-278
# Time:                        16:31:11   Log-Likelihood:                -56695.
# No. Observations:                9731   AIC:                         1.134e+05
# Df Residuals:                    9728   BIC:                         1.134e+05
# Df Model:                           2
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       164.0615      1.864     88.000      0.000       160.407   167.716
# PerResArea      -34.7834      1.985    -17.520      0.000       -38.675   -30.892
# PerOfficeArea    66.0214      3.514     18.789      0.000        59.134    72.909
# ==============================================================================
# Omnibus:                     7043.036   Durbin-Watson:                   1.805
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           181387.796
# Skew:                           3.192   Prob(JB):                         0.00
# Kurtosis:                      23.165   Cond. No.                         6.07
# ==============================================================================

# %%
# Res didn't work, so let's try adding more to commercial, first with Other
print lm.smf_linear(['PerComArea', 'PerOfficeArea', 'PerOtherArea'],
                    'EUIwn', bd_train).summary()
# Out:
# EUIwn ~ PerComArea + PerOfficeArea + PerOtherArea
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.173
# Model:                            OLS   Adj. R-squared:                  0.173
# Method:                 Least Squares   F-statistic:                     678.5
# Date:                Wed, 18 Mar 2015   Prob (F-statistic):               0.00
# Time:                        16:31:11   Log-Likelihood:                -56410.
# No. Observations:                9731   AIC:                         1.128e+05
# Df Residuals:                    9727   BIC:                         1.129e+05
# Df Model:                           3
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       125.9840      0.968    130.205      0.000       124.087   127.881
# PerComArea       18.8883      3.237      5.836      0.000        12.544    25.233
# PerOfficeArea    86.4743      4.302     20.099      0.000        78.041    94.908
# PerOtherArea     88.3973      4.615     19.153      0.000        79.350    97.444
# ==============================================================================
# Omnibus:                     6809.513   Durbin-Watson:                   1.828
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           173916.505
# Skew:                           3.036   Prob(JB):                         0.00
# Kurtosis:                      22.801   Cond. No.                         7.95
# ==============================================================================

# %%
# Now retail
print lm.smf_linear(['PerComArea', 'PerOfficeArea', 'PerOtherArea', 'PerRetailArea'],
                    'EUIwn', bd_train).summary()
# Out:
# EUIwn ~ PerComArea + PerOfficeArea + PerOtherArea + PerRetailArea
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.206
# Model:                            OLS   Adj. R-squared:                  0.205
# Method:                 Least Squares   F-statistic:                     629.2
# Date:                Wed, 18 Mar 2015   Prob (F-statistic):               0.00
# Time:                        16:31:12   Log-Likelihood:                -56215.
# No. Observations:                9731   AIC:                         1.124e+05
# Df Residuals:                    9726   BIC:                         1.125e+05
# Df Model:                           4
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       124.2967      0.952    130.541      0.000       122.430   126.163
# PerComArea      -14.3643      3.583     -4.009      0.000       -21.388    -7.340
# PerOfficeArea   114.8922      4.451     25.813      0.000       106.167   123.617
# PerOtherArea    121.4002      4.817     25.204      0.000       111.958   130.842
# PerRetailArea   150.7587      7.554     19.956      0.000       135.950   165.567
# ==============================================================================
# Omnibus:                     6890.099   Durbin-Watson:                   1.847
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           190758.408
# Skew:                           3.058   Prob(JB):                         0.00
# Kurtosis:                      23.810   Cond. No.                         11.3
# ==============================================================================

# %%
# Storage (starting to gain less explanitory power)
print lm.smf_linear(['PerComArea', 'PerOfficeArea', 'PerOtherArea', 'PerRetailArea', 'PerStrgeArea ',],
                    'EUIwn', bd_train).summary()
# Out:
# EUIwn ~ PerComArea + PerOfficeArea + PerOtherArea + PerRetailArea + PerStrgeArea
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.207
# Model:                            OLS   Adj. R-squared:                  0.207
# Method:                 Least Squares   F-statistic:                     508.2
# Date:                Wed, 18 Mar 2015   Prob (F-statistic):               0.00
# Time:                        16:31:13   Log-Likelihood:                -56205.
# No. Observations:                9731   AIC:                         1.124e+05
# Df Residuals:                    9725   BIC:                         1.125e+05
# Df Model:                           5
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       124.1175      0.952    130.357      0.000       122.251   125.984
# PerComArea        4.9797      5.660      0.880      0.379        -6.116    16.075
# PerOfficeArea    95.5558      6.244     15.305      0.000        83.317   107.794
# PerOtherArea    102.1460      6.496     15.724      0.000        89.412   114.880
# PerRetailArea   131.6742      8.699     15.137      0.000       114.623   148.726
# PerStrgeArea    -31.4622      7.131     -4.412      0.000       -45.440   -17.484
# ==============================================================================
# Omnibus:                     6838.056   Durbin-Watson:                   1.847
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           186658.278
# Skew:                           3.029   Prob(JB):                         0.00
# Kurtosis:                      23.583   Cond. No.                         17.6
# ==============================================================================

# %%
# Garage (starting to gain less explanitory power)
print lm.smf_linear(['PerComArea', 'PerOfficeArea', 'PerOtherArea', 'PerRetailArea', 'PerStrgeArea ', 'PerGarageArea',],
                    'EUIwn', bd_train).summary()
# Out:
# EUIwn ~ PerComArea + PerOfficeArea + PerOtherArea + PerRetailArea + PerStrgeArea  + PerGarageArea
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.213
# Model:                            OLS   Adj. R-squared:                  0.212
# Method:                 Least Squares   F-statistic:                     438.2
# Date:                Wed, 18 Mar 2015   Prob (F-statistic):               0.00
# Time:                        16:31:13   Log-Likelihood:                -56170.
# No. Observations:                9731   AIC:                         1.124e+05
# Df Residuals:                    9724   BIC:                         1.124e+05
# Df Model:                           6
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       123.3970      0.953    129.528      0.000       121.530   125.264
# PerComArea      -20.9427      6.435     -3.255      0.001       -33.556    -8.330
# PerOfficeArea   121.8458      6.969     17.483      0.000       108.184   135.507
# PerOtherArea    128.5011      7.198     17.851      0.000       114.391   142.611
# PerRetailArea   154.8022      9.098     17.015      0.000       136.968   172.636
# PerStrgeArea     -4.5623      7.799     -0.585      0.559       -19.849    10.725
# PerGarageArea   107.8709     12.887      8.370      0.000        82.610   133.132
# ==============================================================================
# Omnibus:                     6889.103   Durbin-Watson:                   1.849
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           194145.543
# Skew:                           3.051   Prob(JB):                         0.00
# Kurtosis:                      24.014   Cond. No.                         22.6
# ==============================================================================

# %%
# Garage throws off storage, so let's test with garage and no storage
print lm.smf_linear(['PerComArea', 'PerOfficeArea', 'PerOtherArea', 'PerRetailArea', 'PerGarageArea',],
                    'EUIwn', bd_train).summary()
# Out:
# EUIwn ~ PerComArea + PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.213
# Model:                            OLS   Adj. R-squared:                  0.212
# Method:                 Least Squares   F-statistic:                     525.8
# Date:                Wed, 18 Mar 2015   Prob (F-statistic):               0.00
# Time:                        16:31:14   Log-Likelihood:                -56170.
# No. Observations:                9731   AIC:                         1.124e+05
# Df Residuals:                    9725   BIC:                         1.124e+05
# Df Model:                           5
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       123.3978      0.953    129.533      0.000       121.530   125.265
# PerComArea      -24.0180      3.711     -6.473      0.000       -31.291   -16.745
# PerOfficeArea   124.9307      4.556     27.419      0.000       115.999   133.862
# PerOtherArea    131.5781      4.914     26.774      0.000       121.945   141.211
# PerRetailArea   157.7658      7.557     20.877      0.000       142.953   172.579
# PerGarageArea   110.9776     11.742      9.452      0.000        87.962   133.994
# ==============================================================================
# Omnibus:                     6896.444   Durbin-Watson:                   1.849
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           194876.927
# Skew:                           3.055   Prob(JB):                         0.00
# Kurtosis:                      24.055   Cond. No.                         16.1
# ==============================================================================

# %%
# That fixed it with a better R2
# Only one left to add, factory
print lm.smf_linear(['PerComArea', 'PerOfficeArea', 'PerOtherArea', 'PerRetailArea', 'PerGarageArea', 'PerFactryArea'],
                    'EUIwn', bd_train).summary()
# Out:
# EUIwn ~ PerComArea + PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + PerFactryArea
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.213
# Model:                            OLS   Adj. R-squared:                  0.212
# Method:                 Least Squares   F-statistic:                     438.1
# Date:                Wed, 18 Mar 2015   Prob (F-statistic):               0.00
# Time:                        16:31:15   Log-Likelihood:                -56170.
# No. Observations:                9731   AIC:                         1.124e+05
# Df Residuals:                    9724   BIC:                         1.124e+05
# Df Model:                           6
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       123.3978      0.953    129.527      0.000       121.530   125.265
# PerComArea      -23.9044      4.454     -5.366      0.000       -32.636   -15.173
# PerOfficeArea   124.8181      5.171     24.139      0.000       114.682   134.954
# PerOtherArea    131.4643      5.499     23.907      0.000       120.685   142.243
# PerRetailArea   157.6436      8.008     19.685      0.000       141.946   173.342
# PerGarageArea   110.8667     11.986      9.250      0.000        87.372   134.361
# PerFactryArea    -0.3646      7.909     -0.046      0.963       -15.868    15.139
# ==============================================================================
# Omnibus:                     6897.047   Durbin-Watson:                   1.849
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           194938.815
# Skew:                           3.055   Prob(JB):                         0.00
# Kurtosis:                      24.058   Cond. No.                         17.6
# ==============================================================================

# %% [markdown]
# **Conclusion**
#
# Best combination of usage by area is:
# * PerComArea
# * PerOfficeArea
# * PerOtherArea
# * PerRetailArea
# * PerGarageArea
#
# Decent explanitory power with an R^2 of 0.227 and no red flags regarding multicolinearity.

# %% [markdown]
# ### Building Age
#
# We had two variables that looked good, so let's see how they do

# %%
# Start with comparing the two
print lm.smf_linear(['YearBuilt',],
                    'EUIwn', bd_train).summary()
print lm.smf_linear(['YearLastWork',],
                    'EUIwn', bd_train).summary()
print lm.smf_linear(['YearLastWork', 'YearBuilt'],
                    'EUIwn', bd_train).summary()
# Out:
# EUIwn ~ YearBuilt
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.024
# Model:                            OLS   Adj. R-squared:                  0.024
# Method:                 Least Squares   F-statistic:                     243.1
# Date:                Wed, 18 Mar 2015   Prob (F-statistic):           3.73e-54
# Time:                        16:31:20   Log-Likelihood:                -57215.
# No. Observations:                9731   AIC:                         1.144e+05
# Df Residuals:                    9729   BIC:                         1.144e+05
# Df Model:                           1
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept   -793.2300     60.200    -13.177      0.000      -911.235  -675.225
# YearBuilt      0.4820      0.031     15.592      0.000         0.421     0.543
# ==============================================================================
# Omnibus:                     7148.312   Durbin-Watson:                   1.717
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           163588.803
# Skew:                           3.314   Prob(JB):                         0.00
# Kurtosis:                      21.961   Cond. No.                     1.34e+05
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 1.34e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# EUIwn ~ YearLastWork
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.031
# Model:                            OLS   Adj. R-squared:                  0.031
# Method:                 Least Squares   F-statistic:                     307.8
# Date:                Wed, 18 Mar 2015   Prob (F-statistic):           7.12e-68
# Time:                        16:31:20   Log-Likelihood:                -57183.
# No. Observations:                9731   AIC:                         1.144e+05
# Df Residuals:                    9729   BIC:                         1.144e+05
# Df Model:                           1
# ================================================================================
#                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# Intercept     -882.8553     58.607    -15.064      0.000      -997.736  -767.974
# YearLastWork     0.5228      0.030     17.545      0.000         0.464     0.581
# ==============================================================================
# Omnibus:                     7114.837   Durbin-Watson:                   1.731
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           165071.312
# Skew:                           3.285   Prob(JB):                         0.00
# Kurtosis:                      22.078   Cond. No.                     1.32e+05
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 1.32e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# EUIwn ~ YearLastWork + YearBuilt
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.038
# Model:                            OLS   Adj. R-squared:                  0.038
# Method:                 Least Squares   F-statistic:                     192.6
# Date:                Wed, 18 Mar 2015   Prob (F-statistic):           9.52e-83
# Time:                        16:31:20   Log-Likelihood:                -57146.
# No. Observations:                9731   AIC:                         1.143e+05
# Df Residuals:                    9728   BIC:                         1.143e+05
# Df Model:                           2
# ================================================================================
#                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# Intercept    -1206.4222     69.320    -17.404      0.000     -1342.303 -1070.541
# YearLastWork     0.3921      0.033     11.773      0.000         0.327     0.457
# YearBuilt        0.2982      0.034      8.659      0.000         0.231     0.366
# ==============================================================================
# Omnibus:                     7115.892   Durbin-Watson:                   1.729
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           164585.857
# Skew:                           3.287   Prob(JB):                         0.00
# Kurtosis:                      22.045   Cond. No.                     2.20e+05
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 2.2e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# **Conclusion**
#
# Stick to YearLastWork since it has better explanatory power and combining the two would give multicolinearity issues.

# %% [markdown]
# ### Lot Value
#
# We have a few variables to look at regarding lot values, including:
# * AssessTot
# * AssessLand
# * ExemptTot
# * ExemptLand
#
# Let's work through the combos that make sense to avoid multi-colinearity

# %%
# Start with comparing four
print lm.smf_linear(['AssessTot',],
                    'EUIwn', bd_train).summary()
print lm.smf_linear(['AssessLand',],
                    'EUIwn', bd_train).summary()
print lm.smf_linear(['ExemptTot',],
                    'EUIwn', bd_train).summary()
print lm.smf_linear(['ExemptLand',],
                    'EUIwn', bd_train).summary()
# Out:
# EUIwn ~ AssessTot
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.082
# Model:                            OLS   Adj. R-squared:                  0.082
# Method:                 Least Squares   F-statistic:                     869.7
# Date:                Wed, 18 Mar 2015   Prob (F-statistic):          3.65e-183
# Time:                        16:31:21   Log-Likelihood:                -56918.
# No. Observations:                9731   AIC:                         1.138e+05
# Df Residuals:                    9729   BIC:                         1.139e+05
# Df Model:                           1
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    135.4459      0.914    148.135      0.000       133.654   137.238
# AssessTot    9.27e-07   3.14e-08     29.491      0.000      8.65e-07  9.89e-07
# ==============================================================================
# Omnibus:                     7376.498   Durbin-Watson:                   1.807
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           192255.855
# Skew:                           3.422   Prob(JB):                         0.00
# Kurtosis:                      23.672   Cond. No.                     3.13e+07
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 3.13e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# EUIwn ~ AssessLand
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.066
# Model:                            OLS   Adj. R-squared:                  0.066
# Method:                 Least Squares   F-statistic:                     689.2
# Date:                Wed, 18 Mar 2015   Prob (F-statistic):          7.80e-147
# Time:                        16:31:21   Log-Likelihood:                -57002.
# No. Observations:                9731   AIC:                         1.140e+05
# Df Residuals:                    9729   BIC:                         1.140e+05
# Df Model:                           1
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    137.5854      0.907    151.636      0.000       135.807   139.364
# AssessLand   2.95e-06   1.12e-07     26.254      0.000      2.73e-06  3.17e-06
# ==============================================================================
# Omnibus:                     7333.008   Durbin-Watson:                   1.786
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           190777.597
# Skew:                           3.392   Prob(JB):                         0.00
# Kurtosis:                      23.604   Cond. No.                     8.53e+06
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 8.53e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# EUIwn ~ ExemptTot
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.045
# Model:                            OLS   Adj. R-squared:                  0.045
# Method:                 Least Squares   F-statistic:                     459.1
# Date:                Wed, 18 Mar 2015   Prob (F-statistic):           1.47e-99
# Time:                        16:31:21   Log-Likelihood:                -57110.
# No. Observations:                9731   AIC:                         1.142e+05
# Df Residuals:                    9729   BIC:                         1.142e+05
# Df Model:                           1
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    141.5454      0.886    159.832      0.000       139.809   143.281
# ExemptTot   1.515e-06   7.07e-08     21.427      0.000      1.38e-06  1.65e-06
# ==============================================================================
# Omnibus:                     6981.656   Durbin-Watson:                   1.762
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           160789.277
# Skew:                           3.195   Prob(JB):                         0.00
# Kurtosis:                      21.861   Cond. No.                     1.28e+07
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 1.28e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# EUIwn ~ ExemptLand
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.026
# Model:                            OLS   Adj. R-squared:                  0.026
# Method:                 Least Squares   F-statistic:                     262.8
# Date:                Wed, 18 Mar 2015   Prob (F-statistic):           2.38e-58
# Time:                        16:31:21   Log-Likelihood:                -57205.
# No. Observations:                9731   AIC:                         1.144e+05
# Df Residuals:                    9729   BIC:                         1.144e+05
# Df Model:                           1
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    142.8741      0.889    160.669      0.000       141.131   144.617
# ExemptLand  5.346e-06    3.3e-07     16.213      0.000       4.7e-06  5.99e-06
# ==============================================================================
# Omnibus:                     7039.679   Durbin-Watson:                   1.746
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           160309.864
# Skew:                           3.240   Prob(JB):                         0.00
# Kurtosis:                      21.799   Cond. No.                     2.74e+06
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 2.74e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# we don't expect the assesed total and assessed land combined to help much
print "ASSESS"
print lm.smf_linear(['AssessTot', 'AssessLand',],
                    'EUIwn', bd_train).summary()

print "\nEXEMPT"
# and same with exempt
print lm.smf_linear(['AssessTot', 'AssessLand',],
                    'EUIwn', bd_train).summary()
# Out:
# ASSESS
# EUIwn ~ AssessTot + AssessLand
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.082
# Model:                            OLS   Adj. R-squared:                  0.082
# Method:                 Least Squares   F-statistic:                     435.8
# Date:                Wed, 18 Mar 2015   Prob (F-statistic):          5.37e-182
# Time:                        16:31:22   Log-Likelihood:                -56917.
# No. Observations:                9731   AIC:                         1.138e+05
# Df Residuals:                    9728   BIC:                         1.139e+05
# Df Model:                           2
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    135.4494      0.914    148.144      0.000       133.657   137.242
# AssessTot   8.495e-07   6.51e-08     13.054      0.000      7.22e-07  9.77e-07
# AssessLand  3.136e-07   2.31e-07      1.360      0.174     -1.39e-07  7.66e-07
# ==============================================================================
# Omnibus:                     7378.364   Durbin-Watson:                   1.807
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           192447.293
# Skew:                           3.423   Prob(JB):                         0.00
# Kurtosis:                      23.683   Cond. No.                     3.22e+07
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 3.22e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# EXEMPT
# EUIwn ~ AssessTot + AssessLand
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.082
# Model:                            OLS   Adj. R-squared:                  0.082
# Method:                 Least Squares   F-statistic:                     435.8
# Date:                Wed, 18 Mar 2015   Prob (F-statistic):          5.37e-182
# Time:                        16:31:22   Log-Likelihood:                -56917.
# No. Observations:                9731   AIC:                         1.138e+05
# Df Residuals:                    9728   BIC:                         1.139e+05
# Df Model:                           2
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    135.4494      0.914    148.144      0.000       133.657   137.242
# AssessTot   8.495e-07   6.51e-08     13.054      0.000      7.22e-07  9.77e-07
# AssessLand  3.136e-07   2.31e-07      1.360      0.174     -1.39e-07  7.66e-07
# ==============================================================================
# Omnibus:                     7378.364   Durbin-Watson:                   1.807
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           192447.293
# Skew:                           3.423   Prob(JB):                         0.00
# Kurtosis:                      23.683   Cond. No.                     3.22e+07
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 3.22e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# but a combination with the exmept values could help
print lm.smf_linear(['AssessTot', 'ExemptTot',],
                    'EUIwn', bd_train).summary()
print lm.smf_linear(['AssessTot', 'ExemptLand',],
                    'EUIwn', bd_train).summary()
# Out:
# EUIwn ~ AssessTot + ExemptTot
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.089
# Model:                            OLS   Adj. R-squared:                  0.089
# Method:                 Least Squares   F-statistic:                     475.4
# Date:                Wed, 18 Mar 2015   Prob (F-statistic):          9.95e-198
# Time:                        16:31:23   Log-Likelihood:                -56881.
# No. Observations:                9731   AIC:                         1.138e+05
# Df Residuals:                    9728   BIC:                         1.138e+05
# Df Model:                           2
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    135.3535      0.911    148.582      0.000       133.568   137.139
# AssessTot   7.765e-07   3.58e-08     21.672      0.000      7.06e-07  8.47e-07
# ExemptTot   6.823e-07    7.9e-08      8.636      0.000      5.27e-07  8.37e-07
# ==============================================================================
# Omnibus:                     7259.821   Durbin-Watson:                   1.816
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           187713.707
# Skew:                           3.342   Prob(JB):                         0.00
# Kurtosis:                      23.452   Cond. No.                     3.21e+07
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 3.21e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# EUIwn ~ AssessTot + ExemptLand
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.086
# Model:                            OLS   Adj. R-squared:                  0.086
# Method:                 Least Squares   F-statistic:                     456.4
# Date:                Wed, 18 Mar 2015   Prob (F-statistic):          3.37e-190
# Time:                        16:31:23   Log-Likelihood:                -56898.
# No. Observations:                9731   AIC:                         1.138e+05
# Df Residuals:                    9728   BIC:                         1.138e+05
# Df Model:                           2
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    135.2947      0.913    148.212      0.000       133.505   137.084
# AssessTot   8.488e-07   3.37e-08     25.159      0.000      7.83e-07  9.15e-07
# ExemptLand  2.165e-06   3.44e-07      6.301      0.000      1.49e-06  2.84e-06
# ==============================================================================
# Omnibus:                     7304.182   Durbin-Watson:                   1.813
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           188885.647
# Skew:                           3.374   Prob(JB):                         0.00
# Kurtosis:                      23.502   Cond. No.                     3.13e+07
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 3.13e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# **Conclusion**
#
# Combine the Assessed Total and Exempt Total to get the best results. Although all the data for this has some troubling multicolinearity flags.

# %% [markdown]
# ### Initial Combination
#
# Let's combine a few of these different variables that we explored to see if we can get a better model

# %%
lot_value_features = ['AssessTot', 'ExemptTot',]
building_area_features = ['PerComArea', 'PerOfficeArea', 'PerOtherArea', 'PerRetailArea', 'PerGarageArea',]
building_age_features = ['YearLastWork']

# %%
# combine building area with value
print lm.smf_linear(lot_value_features + building_area_features,
                    'EUIwn', bd_train).summary()
# Out:
# EUIwn ~ AssessTot + ExemptTot + PerComArea + PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.240
# Model:                            OLS   Adj. R-squared:                  0.239
# Method:                 Least Squares   F-statistic:                     437.9
# Date:                Wed, 18 Mar 2015   Prob (F-statistic):               0.00
# Time:                        16:31:25   Log-Likelihood:                -56001.
# No. Observations:                9731   AIC:                         1.120e+05
# Df Residuals:                    9723   BIC:                         1.121e+05
# Df Model:                           7
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       120.5828      0.952    126.665      0.000       118.717   122.449
# AssessTot      3.447e-07   3.55e-08      9.715      0.000      2.75e-07  4.14e-07
# ExemptTot      6.716e-07   7.32e-08      9.179      0.000      5.28e-07  8.15e-07
# PerComArea      -23.0887      3.648     -6.330      0.000       -30.239   -15.939
# PerOfficeArea   108.1948      4.651     23.264      0.000        99.078   117.311
# PerOtherArea    121.2774      4.864     24.936      0.000       111.744   130.811
# PerRetailArea   151.9862      7.440     20.429      0.000       137.403   166.569
# PerGarageArea    96.3762     11.568      8.332      0.000        73.701   119.051
# ==============================================================================
# Omnibus:                     6981.409   Durbin-Watson:                   1.878
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           207816.673
# Skew:                           3.092   Prob(JB):                         0.00
# Kurtosis:                      24.778   Cond. No.                     4.58e+08
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 4.58e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# combine building area with age
print lm.smf_linear(building_age_features + building_area_features,
                    'EUIwn', bd_train).summary()
# Out:
# EUIwn ~ YearLastWork + PerComArea + PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.223
# Model:                            OLS   Adj. R-squared:                  0.222
# Method:                 Least Squares   F-statistic:                     464.1
# Date:                Wed, 18 Mar 2015   Prob (F-statistic):               0.00
# Time:                        16:31:26   Log-Likelihood:                -56109.
# No. Observations:                9731   AIC:                         1.122e+05
# Df Residuals:                    9724   BIC:                         1.123e+05
# Df Model:                           6
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept      -468.8066     53.469     -8.768      0.000      -573.618  -363.996
# YearLastWork      0.3016      0.027     11.077      0.000         0.248     0.355
# PerComArea      -24.1223      3.688     -6.542      0.000       -31.351   -16.894
# PerOfficeArea   122.9471      4.532     27.130      0.000       114.064   131.830
# PerOtherArea    125.8198      4.912     25.617      0.000       116.192   135.447
# PerRetailArea   152.0308      7.528     20.196      0.000       137.275   166.787
# PerGarageArea    99.2697     11.717      8.473      0.000        76.303   122.237
# ==============================================================================
# Omnibus:                     6909.429   Durbin-Watson:                   1.855
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           196799.139
# Skew:                           3.061   Prob(JB):                         0.00
# Kurtosis:                      24.164   Cond. No.                     1.34e+05
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 1.34e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# combine building age with lot value
print lm.smf_linear(building_age_features + lot_value_features,
                    'EUIwn', bd_train).summary()
# Out:
# EUIwn ~ YearLastWork + AssessTot + ExemptTot
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.106
# Model:                            OLS   Adj. R-squared:                  0.106
# Method:                 Least Squares   F-statistic:                     383.5
# Date:                Wed, 18 Mar 2015   Prob (F-statistic):          1.83e-235
# Time:                        16:31:26   Log-Likelihood:                -56791.
# No. Observations:                9731   AIC:                         1.136e+05
# Df Residuals:                    9727   BIC:                         1.136e+05
# Df Model:                           3
# ================================================================================
#                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# Intercept     -634.4888     57.066    -11.118      0.000      -746.351  -522.627
# YearLastWork     0.3918      0.029     13.492      0.000         0.335     0.449
# AssessTot     7.408e-07   3.56e-08     20.806      0.000      6.71e-07  8.11e-07
# ExemptTot     5.787e-07   7.87e-08      7.358      0.000      4.25e-07  7.33e-07
# ==============================================================================
# Omnibus:                     7228.448   Durbin-Watson:                   1.822
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           187283.255
# Skew:                           3.319   Prob(JB):                         0.00
# Kurtosis:                      23.441   Cond. No.                     2.03e+09
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 2.03e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# combine all three
print lm.smf_linear(building_age_features + lot_value_features + building_area_features,
                    'EUIwn', bd_train).summary()
# Out:
# EUIwn ~ YearLastWork + AssessTot + ExemptTot + PerComArea + PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.246
# Model:                            OLS   Adj. R-squared:                  0.245
# Method:                 Least Squares   F-statistic:                     396.0
# Date:                Wed, 18 Mar 2015   Prob (F-statistic):               0.00
# Time:                        16:31:27   Log-Likelihood:                -55962.
# No. Observations:                9731   AIC:                         1.119e+05
# Df Residuals:                    9722   BIC:                         1.120e+05
# Df Model:                           8
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept      -350.0589     53.133     -6.588      0.000      -454.210  -245.907
# YearLastWork      0.2398      0.027      8.859      0.000         0.187     0.293
# AssessTot      3.284e-07   3.54e-08      9.278      0.000      2.59e-07  3.98e-07
# ExemptTot      6.172e-07   7.31e-08      8.439      0.000      4.74e-07  7.61e-07
# PerComArea      -23.2236      3.633     -6.392      0.000       -30.345   -16.102
# PerOfficeArea   107.5213      4.633     23.208      0.000        98.440   116.603
# PerOtherArea    117.3776      4.864     24.130      0.000       107.842   126.913
# PerRetailArea   147.7403      7.426     19.896      0.000       133.185   162.296
# PerGarageArea    87.9822     11.561      7.610      0.000        65.321   110.643
# ==============================================================================
# Omnibus:                     6989.350   Durbin-Watson:                   1.880
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           208483.005
# Skew:                           3.097   Prob(JB):                         0.00
# Kurtosis:                      24.813   Cond. No.                     2.06e+09
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 2.06e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# **Conclusion**
#
# The age and lot value characteristics add some explanatory power to the usage values, but at the expense of some additional multicoliniearity flags. Perhaps we can improve the regression with other fields.

# %% [markdown]
# ### Adding other variables

# %%
other_fields = ['Easements',
 'NumBldgs',
 'NumFloors',
 'UnitsRes',
 'UnitsTotal',
 'LotFront',
 'LotDepth',
 'BldgFront',
 'BldgDepth',
 'MaxAllwFAR',]

for f in other_fields:
    print '#\n%s\n#' % f
    print lm.smf_linear(building_area_features + [f],
                    'EUIwn', bd_train).summary()
# Out:
# #
# Easements
# #
# EUIwn ~ PerComArea + PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + Easements
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.214
# Model:                            OLS   Adj. R-squared:                  0.213
# Method:                 Least Squares   F-statistic:                     441.1
# Date:                Wed, 18 Mar 2015   Prob (F-statistic):               0.00
# Time:                        16:31:29   Log-Likelihood:                -56163.
# No. Observations:                9731   AIC:                         1.123e+05
# Df Residuals:                    9724   BIC:                         1.124e+05
# Df Model:                           6
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       123.1181      0.955    128.935      0.000       121.246   124.990
# PerComArea      -24.2622      3.709     -6.542      0.000       -31.532   -16.993
# PerOfficeArea   124.9158      4.553     27.434      0.000       115.990   133.841
# PerOtherArea    131.5234      4.911     26.781      0.000       121.897   141.150
# PerRetailArea   157.5806      7.552     20.867      0.000       142.777   172.384
# PerGarageArea   107.0725     11.779      9.090      0.000        83.982   130.163
# Easements        17.6228      4.680      3.765      0.000         8.448    26.797
# ==============================================================================
# Omnibus:                     6889.824   Durbin-Watson:                   1.851
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           193887.011
# Skew:                           3.052   Prob(JB):                         0.00
# Kurtosis:                      23.998   Cond. No.                         16.1
# ==============================================================================
# #
# NumBldgs
# #
# EUIwn ~ PerComArea + PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + NumBldgs
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.215
# Model:                            OLS   Adj. R-squared:                  0.215
# Method:                 Least Squares   F-statistic:                     444.9
# Date:                Wed, 18 Mar 2015   Prob (F-statistic):               0.00
# Time:                        16:31:29   Log-Likelihood:                -56155.
# No. Observations:                9731   AIC:                         1.123e+05
# Df Residuals:                    9724   BIC:                         1.124e+05
# Df Model:                           6
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       122.0503      0.981    124.448      0.000       120.128   123.973
# PerComArea      -23.6027      3.705     -6.370      0.000       -30.866   -16.339
# PerOfficeArea   125.0625      4.549     27.490      0.000       116.145   133.980
# PerOtherArea    131.5714      4.907     26.815      0.000       121.953   141.189
# PerRetailArea   158.0568      7.545     20.948      0.000       143.267   172.847
# PerGarageArea   111.4147     11.723      9.504      0.000        88.434   134.395
# NumBldgs          0.6770      0.120      5.635      0.000         0.442     0.913
# ==============================================================================
# Omnibus:                     6897.012   Durbin-Watson:                   1.852
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           196549.170
# Skew:                           3.052   Prob(JB):                         0.00
# Kurtosis:                      24.154   Cond. No.                         104.
# ==============================================================================
# #
# NumFloors
# #
# EUIwn ~ PerComArea + PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + NumFloors
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.221
# Model:                            OLS   Adj. R-squared:                  0.221
# Method:                 Least Squares   F-statistic:                     461.1
# Date:                Wed, 18 Mar 2015   Prob (F-statistic):               0.00
# Time:                        16:31:29   Log-Likelihood:                -56117.
# No. Observations:                9731   AIC:                         1.122e+05
# Df Residuals:                    9724   BIC:                         1.123e+05
# Df Model:                           6
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       113.3940      1.350     84.009      0.000       110.748   116.040
# PerComArea      -20.0669      3.710     -5.409      0.000       -27.339   -12.795
# PerOfficeArea   111.6624      4.707     23.720      0.000       102.435   120.890
# PerOtherArea    126.3841      4.913     25.725      0.000       116.754   136.014
# PerRetailArea   156.8935      7.516     20.875      0.000       142.161   171.626
# PerGarageArea   101.7227     11.711      8.686      0.000        78.766   124.679
# NumFloors         0.9813      0.094     10.405      0.000         0.796     1.166
# ==============================================================================
# Omnibus:                     7095.618   Durbin-Watson:                   1.855
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           211773.111
# Skew:                           3.169   Prob(JB):                         0.00
# Kurtosis:                      24.957   Cond. No.                         216.
# ==============================================================================
# #
# UnitsRes
# #
# EUIwn ~ PerComArea + PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + UnitsRes
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.213
# Model:                            OLS   Adj. R-squared:                  0.213
# Method:                 Least Squares   F-statistic:                     439.5
# Date:                Wed, 18 Mar 2015   Prob (F-statistic):               0.00
# Time:                        16:31:29   Log-Likelihood:                -56167.
# No. Observations:                9731   AIC:                         1.123e+05
# Df Residuals:                    9724   BIC:                         1.124e+05
# Df Model:                           6
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       122.3088      1.042    117.430      0.000       120.267   124.350
# PerComArea      -22.9263      3.734     -6.141      0.000       -30.245   -15.608
# PerOfficeArea   124.9397      4.555     27.428      0.000       116.011   133.869
# PerOtherArea    131.4541      4.913     26.755      0.000       121.823   141.085
# PerRetailArea   157.6445      7.555     20.867      0.000       142.836   172.453
# PerGarageArea   109.3178     11.756      9.299      0.000        86.274   132.362
# UnitsRes          0.0085      0.003      2.582      0.010         0.002     0.015
# ==============================================================================
# Omnibus:                     6897.593   Durbin-Watson:                   1.849
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           195388.258
# Skew:                           3.055   Prob(JB):                         0.00
# Kurtosis:                      24.085   Cond. No.                     4.03e+03
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 4.03e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# #
# UnitsTotal
# #
# EUIwn ~ PerComArea + PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + UnitsTotal
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.213
# Model:                            OLS   Adj. R-squared:                  0.213
# Method:                 Least Squares   F-statistic:                     439.2
# Date:                Wed, 18 Mar 2015   Prob (F-statistic):               0.00
# Time:                        16:31:29   Log-Likelihood:                -56168.
# No. Observations:                9731   AIC:                         1.123e+05
# Df Residuals:                    9724   BIC:                         1.124e+05
# Df Model:                           6
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       122.4552      1.043    117.434      0.000       120.411   124.499
# PerComArea      -23.1911      3.728     -6.220      0.000       -30.500   -15.883
# PerOfficeArea   124.8218      4.556     27.399      0.000       115.892   133.752
# PerOtherArea    131.5157      4.913     26.766      0.000       121.884   141.147
# PerRetailArea   157.6501      7.555     20.866      0.000       142.840   172.460
# PerGarageArea   109.4040     11.761      9.303      0.000        86.351   132.457
# UnitsTotal        0.0072      0.003      2.221      0.026         0.001     0.014
# ==============================================================================
# Omnibus:                     6899.324   Durbin-Watson:                   1.849
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           195392.213
# Skew:                           3.056   Prob(JB):                         0.00
# Kurtosis:                      24.084   Cond. No.                     4.12e+03
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 4.12e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# #
# LotFront
# #
# EUIwn ~ PerComArea + PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + LotFront
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.222
# Model:                            OLS   Adj. R-squared:                  0.222
# Method:                 Least Squares   F-statistic:                     462.9
# Date:                Wed, 18 Mar 2015   Prob (F-statistic):               0.00
# Time:                        16:31:29   Log-Likelihood:                -56112.
# No. Observations:                9731   AIC:                         1.122e+05
# Df Residuals:                    9724   BIC:                         1.123e+05
# Df Model:                           6
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       113.5201      1.316     86.275      0.000       110.941   116.099
# PerComArea      -27.2742      3.701     -7.370      0.000       -34.529   -20.020
# PerOfficeArea   130.3055      4.557     28.596      0.000       121.373   139.238
# PerOtherArea    133.6922      4.889     27.344      0.000       124.108   143.276
# PerRetailArea   156.3016      7.513     20.803      0.000       141.574   171.029
# PerGarageArea   107.4056     11.677      9.198      0.000        84.516   130.295
# LotFront          0.0585      0.005     10.813      0.000         0.048     0.069
# ==============================================================================
# Omnibus:                     6722.785   Durbin-Watson:                   1.853
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           182818.492
# Skew:                           2.953   Prob(JB):                         0.00
# Kurtosis:                      23.396   Cond. No.                     3.47e+03
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 3.47e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# #
# LotDepth
# #
# EUIwn ~ PerComArea + PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + LotDepth
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.220
# Model:                            OLS   Adj. R-squared:                  0.220
# Method:                 Least Squares   F-statistic:                     457.4
# Date:                Wed, 18 Mar 2015   Prob (F-statistic):               0.00
# Time:                        16:31:29   Log-Likelihood:                -56125.
# No. Observations:                9731   AIC:                         1.123e+05
# Df Residuals:                    9724   BIC:                         1.123e+05
# Df Model:                           6
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       115.0511      1.290     89.198      0.000       112.523   117.580
# PerComArea      -28.7742      3.727     -7.721      0.000       -36.080   -21.469
# PerOfficeArea   129.1044      4.556     28.334      0.000       120.173   138.036
# PerOtherArea    133.9110      4.898     27.341      0.000       124.310   143.512
# PerRetailArea   155.2256      7.527     20.623      0.000       140.472   169.980
# PerGarageArea   108.9845     11.689      9.323      0.000        86.071   131.898
# LotDepth          0.0542      0.006      9.546      0.000         0.043     0.065
# ==============================================================================
# Omnibus:                     6843.416   Durbin-Watson:                   1.853
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           194130.234
# Skew:                           3.018   Prob(JB):                         0.00
# Kurtosis:                      24.033   Cond. No.                     3.36e+03
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 3.36e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# #
# BldgFront
# #
# EUIwn ~ PerComArea + PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + BldgFront
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.213
# Model:                            OLS   Adj. R-squared:                  0.213
# Method:                 Least Squares   F-statistic:                     439.8
# Date:                Wed, 18 Mar 2015   Prob (F-statistic):               0.00
# Time:                        16:31:29   Log-Likelihood:                -56166.
# No. Observations:                9731   AIC:                         1.123e+05
# Df Residuals:                    9724   BIC:                         1.124e+05
# Df Model:                           6
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       121.2709      1.219     99.522      0.000       118.882   123.659
# PerComArea      -24.7377      3.718     -6.653      0.000       -32.026   -17.449
# PerOfficeArea   125.7723      4.565     27.553      0.000       116.824   134.720
# PerOtherArea    132.3827      4.921     26.901      0.000       122.736   142.029
# PerRetailArea   157.9043      7.554     20.903      0.000       143.096   172.712
# PerGarageArea   110.4437     11.739      9.408      0.000        87.433   133.455
# BldgFront         0.0164      0.006      2.798      0.005         0.005     0.028
# ==============================================================================
# Omnibus:                     6870.776   Durbin-Watson:                   1.849
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           192726.960
# Skew:                           3.040   Prob(JB):                         0.00
# Kurtosis:                      23.937   Cond. No.                     2.89e+03
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 2.89e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# #
# BldgDepth
# #
# EUIwn ~ PerComArea + PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + BldgDepth
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.213
# Model:                            OLS   Adj. R-squared:                  0.213
# Method:                 Least Squares   F-statistic:                     439.3
# Date:                Wed, 18 Mar 2015   Prob (F-statistic):               0.00
# Time:                        16:31:29   Log-Likelihood:                -56168.
# No. Observations:                9731   AIC:                         1.123e+05
# Df Residuals:                    9724   BIC:                         1.124e+05
# Df Model:                           6
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       121.7863      1.169    104.210      0.000       119.495   124.077
# PerComArea      -25.3863      3.754     -6.762      0.000       -32.745   -18.028
# PerOfficeArea   125.6780      4.566     27.524      0.000       116.727   134.629
# PerOtherArea    132.6817      4.935     26.886      0.000       123.008   142.355
# PerRetailArea   158.2723      7.558     20.941      0.000       143.457   173.087
# PerGarageArea   111.0520     11.739      9.460      0.000        88.041   134.063
# BldgDepth         0.0156      0.007      2.379      0.017         0.003     0.028
# ==============================================================================
# Omnibus:                     6881.558   Durbin-Watson:                   1.849
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           193557.842
# Skew:                           3.047   Prob(JB):                         0.00
# Kurtosis:                      23.982   Cond. No.                     2.58e+03
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 2.58e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# #
# MaxAllwFAR
# #
# EUIwn ~ PerComArea + PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + MaxAllwFAR
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.213
# Model:                            OLS   Adj. R-squared:                  0.213
# Method:                 Least Squares   F-statistic:                     439.9
# Date:                Wed, 18 Mar 2015   Prob (F-statistic):               0.00
# Time:                        16:31:29   Log-Likelihood:                -56166.
# No. Observations:                9731   AIC:                         1.123e+05
# Df Residuals:                    9724   BIC:                         1.124e+05
# Df Model:                           6
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       120.2126      1.452     82.764      0.000       117.365   123.060
# PerComArea      -23.6863      3.711     -6.383      0.000       -30.960   -16.412
# PerOfficeArea   120.3924      4.815     25.002      0.000       110.953   129.831
# PerOtherArea    130.6845      4.922     26.550      0.000       121.036   140.333
# PerRetailArea   156.0051      7.578     20.586      0.000       141.150   170.860
# PerGarageArea   110.6841     11.738      9.430      0.000        87.676   133.692
# MaxAllwFAR        0.6849      0.236      2.904      0.004         0.223     1.147
# ==============================================================================
# Omnibus:                     6949.017   Durbin-Watson:                   1.848
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           198899.580
# Skew:                           3.085   Prob(JB):                         0.00
# Kurtosis:                      24.271   Cond. No.                         101.
# ==============================================================================

# %%
# no warnings with the following and a small increase in R2
best_continuous_features = building_area_features + "Easements NumBldgs NumFloors MaxAllwFAR".split()
print lm.smf_linear(best_continuous_features,
                    'EUIwn', bd_train).summary()
# Out:
# EUIwn ~ PerComArea + PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + Easements + NumBldgs + NumFloors + MaxAllwFAR
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.227
# Model:                            OLS   Adj. R-squared:                  0.226
# Method:                 Least Squares   F-statistic:                     316.5
# Date:                Wed, 18 Mar 2015   Prob (F-statistic):               0.00
# Time:                        16:31:29   Log-Likelihood:                -56084.
# No. Observations:                9731   AIC:                         1.122e+05
# Df Residuals:                    9721   BIC:                         1.123e+05
# Df Model:                           9
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       113.6604      1.534     74.092      0.000       110.653   116.667
# PerComArea      -19.1784      3.703     -5.179      0.000       -26.437   -11.920
# PerOfficeArea   114.8219      4.796     23.940      0.000       105.420   124.224
# PerOtherArea    126.1786      4.898     25.764      0.000       116.578   135.779
# PerRetailArea   159.4719      7.525     21.193      0.000       144.722   174.222
# PerGarageArea    96.7653     11.728      8.251      0.000        73.777   119.754
# Easements        14.3324      4.659      3.076      0.002         5.199    23.466
# NumBldgs          0.7198      0.120      5.996      0.000         0.484     0.955
# NumFloors         1.2667      0.118     10.697      0.000         1.035     1.499
# MaxAllwFAR       -1.0399      0.296     -3.516      0.000        -1.620    -0.460
# ==============================================================================
# Omnibus:                     7066.954   Durbin-Watson:                   1.866
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           211360.846
# Skew:                           3.149   Prob(JB):                         0.00
# Kurtosis:                      24.946   Cond. No.                         236.
# ==============================================================================

# %% [markdown]
# **Conclusion**
#
# Adding the following fields to the regression helps slightly and doesn't raise any immediate data issues:
# * Easements
# * NumBldgs
# * NumFloors
# * MaxAllwFAR

# %% [markdown]
# ### A Few Dummies
#
# We have a few dummies built in before we ge too heavy on the categorical features that need to be transformed in to dummies. Let's check to see if these have any relevance.

# %%
print lm.smf_linear(pluto_class,
                    'EUIwn', bd_train).summary()
# Out:
# EUIwn ~ Landmarked + BuiltCode + Altered
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     32.73
# Date:                Wed, 18 Mar 2015   Prob (F-statistic):           4.81e-21
# Time:                        16:46:13   Log-Likelihood:                -57286.
# No. Observations:                9731   AIC:                         1.146e+05
# Df Residuals:                    9727   BIC:                         1.146e+05
# Df Model:                           3
# ===================================================================================
#                       coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------
# Intercept         141.3108      1.100    128.518      0.000       139.155   143.466
# Altered[T.True]    10.6206      1.897      5.599      0.000         6.902    14.339
# Landmarked         47.4252      6.252      7.586      0.000        35.170    59.681
# BuiltCode          -9.4485      3.633     -2.601      0.009       -16.569    -2.328
# ==============================================================================
# Omnibus:                     7162.815   Durbin-Watson:                   1.727
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           165766.597
# Skew:                           3.320   Prob(JB):                         0.00
# Kurtosis:                      22.099   Cond. No.                         7.59
# ==============================================================================

# %%
# Not much explanatory power, but still signficant
# Adding in to the best previous model doesn't help though
best_dummies = ['Altered', 'Landmarked', 'BuiltCode']
print lm.smf_linear(best_continuous_features + best_dummies,
                    'EUIwn', bd_train).summary()
# Out:
# EUIwn ~ PerComArea + PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + Easements + NumBldgs + NumFloors + MaxAllwFAR + Altered + Landmarked + BuiltCode
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.227
# Model:                            OLS   Adj. R-squared:                  0.226
# Method:                 Least Squares   F-statistic:                     237.5
# Date:                Wed, 18 Mar 2015   Prob (F-statistic):               0.00
# Time:                        16:47:38   Log-Likelihood:                -56084.
# No. Observations:                9731   AIC:                         1.122e+05
# Df Residuals:                    9718   BIC:                         1.123e+05
# Df Model:                          12
# ===================================================================================
#                       coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------
# Intercept         113.7363      1.596     71.255      0.000       110.607   116.865
# Altered[T.True]     0.7396      1.739      0.425      0.671        -2.670     4.149
# PerComArea        -19.2316      3.711     -5.183      0.000       -26.505   -11.958
# PerOfficeArea     114.9244      4.807     23.905      0.000       105.501   124.348
# PerOtherArea      126.3100      4.906     25.743      0.000       116.692   135.928
# PerRetailArea     159.6249      7.529     21.200      0.000       144.866   174.384
# PerGarageArea      96.5710     11.745      8.222      0.000        73.548   119.594
# Easements          14.2485      4.660      3.057      0.002         5.113    23.384
# NumBldgs            0.7209      0.120      6.004      0.000         0.486     0.956
# NumFloors           1.2634      0.120     10.541      0.000         1.028     1.498
# MaxAllwFAR         -1.0427      0.303     -3.440      0.001        -1.637    -0.448
# Landmarked         -2.2910      5.654     -0.405      0.685       -13.374     8.792
# BuiltCode          -3.6404      3.224     -1.129      0.259        -9.961     2.680
# ==============================================================================
# Omnibus:                     7071.552   Durbin-Watson:                   1.866
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           211978.836
# Skew:                           3.151   Prob(JB):                         0.00
# Kurtosis:                      24.979   Cond. No.                         236.
# ==============================================================================

# %% [markdown]
# ## Current Best Model
#
# > EUIwn ~ PerComArea + PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + Easements + NumBldgs + NumFloors + MaxAllwFAR

# %% [markdown]
# ### Playing with Categorical Values
#
# We have a number of fields that have categorical data in them and are just begging to be made in to dummy variables!

# %%
# will start by looking at the BldgClass category from PLUTO
X = pd.get_dummies(bd_train[pluto_class_dummies[0]])

# do a quick f_regression test and sort the results by r2
results2 = lm.f_test(X, bd_train[['EUIwn']])
results2.sort('r2', ascending=False)
# Out:
#        F score feature        p-value        r2
# 21  571.372927      I1  2.510845e-121  0.077418
# 5   191.678506      D4   5.212605e-43  0.027380
# 25  175.351639      I9   1.541575e-39  0.025106
# 24  144.436901      I6   6.132530e-33  0.020772
# 41  136.758885      O4   2.707869e-31  0.019690
# 3   126.810120      D1   3.696629e-29  0.018283
# 32  120.337018      K6   9.106772e-28  0.017366
# 28  118.159728      J6   2.678256e-27  0.017057
# 40  106.940559      O3   7.004736e-25  0.015463
# 48   77.601177      P7   1.579225e-18  0.011268
# 50   74.633709      R5   6.980103e-18  0.010842
# 12   68.262337      F2   1.704859e-16  0.009926
# 33   61.761450      K9   4.476006e-15  0.008989
# 9    59.596046      E7   1.331661e-14  0.008677
# 17   51.772152      H2   6.900014e-13  0.007546
# 23   51.082031      I5   9.780771e-13  0.007446
# 30   42.304700      K1   8.364277e-11  0.006175
# 18   32.980907      H3   9.707949e-09  0.004820
# 44   31.659495      O9   1.910163e-08  0.004628
# 19   28.442183      H5   9.964555e-08  0.004160
# 16   27.999728      H1   1.251189e-07  0.004095
# 15   26.143429      G1   3.256224e-07  0.003825
# 20   19.700221      H9   9.201894e-06  0.002885
# 38   18.541179      O1   1.686059e-05  0.002716
# 14   17.561319      F9   2.817079e-05  0.002572
# 39   16.084717      O2   6.121880e-05  0.002357
# 11   15.935677      F1   6.622043e-05  0.002335
# 10   15.733751      E9   7.365941e-05  0.002305
# 6    14.627141      D7   1.321845e-04  0.002144
# 26   14.574539      J4   1.359180e-04  0.002136
# 22   13.953352      I2   1.889347e-04  0.002045
# 0    13.662657      C1   2.204800e-04  0.002003
# 46   12.309314      P5   4.536144e-04  0.001805
# 7    12.109440      E1   5.048146e-04  0.001775
# 29   10.095775      J8   1.492739e-03  0.001481
# 4     9.059192      D3   2.623349e-03  0.001329
# 43    8.374689      O6   3.816906e-03  0.001228
# 31    8.073612      K2   4.504793e-03  0.001184
# 47    7.939391      P6   4.850952e-03  0.001165
# 1     7.932084      C6   4.870557e-03  0.001164
# 2     7.305224      D0   6.892498e-03  0.001072
# 8     6.917058      E3   8.556940e-03  0.001015
# 53    6.256445      W7   1.239752e-02  0.000918
# 37    5.929937      N2   1.491128e-02  0.000870
# 13    5.506769      F4   1.897151e-02  0.000808
# 34    5.450874      L1   1.958745e-02  0.000800
# 42    3.933169      O5   4.738275e-02  0.000577
# 27    3.860299      J5   4.948212e-02  0.000567
# 45    3.556838      P3   5.934313e-02  0.000522
# 52    3.178945      W6   7.463741e-02  0.000467
# 35    2.930920      L3   8.694349e-02  0.000430
# 51    2.842855      RM   9.182685e-02  0.000417
# 49    2.827328      P8   9.271828e-02  0.000415
# 36    2.713555      L8   9.954518e-02  0.000398

# %%
# first value helps out a bunch
print lm.smf_linear(best_continuous_features + ['I1', 'I9', 'D4', 'K6', 'D1'],
                    'EUIwn', bd_train.join(X)).summary()
# Out:
# EUIwn ~ PerComArea + PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + Easements + NumBldgs + NumFloors + MaxAllwFAR + I1 + I9 + D4 + K6 + D1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.294
# Model:                            OLS   Adj. R-squared:                  0.292
# Method:                 Least Squares   F-statistic:                     201.8
# Date:                Wed, 18 Mar 2015   Prob (F-statistic):               0.00
# Time:                        17:28:37   Log-Likelihood:                -39210.
# No. Observations:                6811   AIC:                         7.845e+04
# Df Residuals:                    6796   BIC:                         7.855e+04
# Df Model:                          14
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       117.7739      2.477     47.555      0.000       112.919   122.629
# PerComArea      -23.1314      4.612     -5.016      0.000       -32.172   -14.091
# PerOfficeArea   105.4129      5.760     18.301      0.000        94.122   116.704
# PerOtherArea    110.6657      5.833     18.971      0.000        99.230   122.101
# PerRetailArea   126.7297      9.710     13.052      0.000       107.696   145.764
# PerGarageArea   112.3007     14.058      7.988      0.000        84.742   139.859
# Easements        17.6457      5.841      3.021      0.003         6.195    29.096
# NumBldgs          0.7587      0.154      4.931      0.000         0.457     1.060
# NumFloors         1.3068      0.141      9.270      0.000         1.030     1.583
# MaxAllwFAR       -0.6014      0.353     -1.702      0.089        -1.294     0.091
# I1              319.2871     14.512     22.001      0.000       290.838   347.736
# I9              262.5755     21.431     12.252      0.000       220.564   304.587
# D4              -15.3907      2.616     -5.883      0.000       -20.519   -10.262
# K6              134.4655     17.551      7.662      0.000       100.061   168.870
# D1               -4.3200      2.795     -1.546      0.122        -9.799     1.159
# ==============================================================================
# Omnibus:                     4673.849   Durbin-Watson:                   1.989
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           152882.131
# Skew:                           2.845   Prob(JB):                         0.00
# Kurtosis:                      25.502   Cond. No.                         354.
# ==============================================================================

# %%
# 03 not so much
print lm.smf_linear(best_continuous_features + ['I1', 'I9', 'D4', 'K6', 'D1', 'O3'],
                    'EUIwn', bd_train.join(X)).summary()
# Out:
# EUIwn ~ PerComArea + PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + Easements + NumBldgs + NumFloors + MaxAllwFAR + I1 + I9 + D4 + K6 + D1 + O3
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.297
# Model:                            OLS   Adj. R-squared:                  0.296
# Method:                 Least Squares   F-statistic:                     273.9
# Date:                Wed, 18 Mar 2015   Prob (F-statistic):               0.00
# Time:                        16:31:41   Log-Likelihood:                -55619.
# No. Observations:                9731   AIC:                         1.113e+05
# Df Residuals:                    9715   BIC:                         1.114e+05
# Df Model:                          15
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       116.4981      1.994     58.414      0.000       112.589   120.407
# PerComArea      -24.1957      3.718     -6.508      0.000       -31.484   -16.908
# PerOfficeArea   105.5925      4.847     21.786      0.000        96.092   115.093
# PerOtherArea    107.0954      4.716     22.708      0.000        97.851   116.340
# PerRetailArea   129.2089      7.881     16.395      0.000       113.760   144.658
# PerGarageArea    87.2168     11.193      7.792      0.000        65.275   109.158
# Easements        11.0260      4.451      2.477      0.013         2.301    19.751
# NumBldgs          0.6534      0.115      5.658      0.000         0.427     0.880
# NumFloors         1.2901      0.114     11.302      0.000         1.066     1.514
# MaxAllwFAR       -0.2907      0.287     -1.011      0.312        -0.854     0.273
# I1              304.5886     11.730     25.967      0.000       281.595   327.582
# I9              229.1174     17.455     13.126      0.000       194.901   263.333
# D4              -14.6621      2.104     -6.967      0.000       -18.787   -10.537
# K6              124.7496     13.224      9.433      0.000        98.827   150.672
# D1               -4.3591      2.249     -1.938      0.053        -8.768     0.049
# O3               -8.7865      5.209     -1.687      0.092       -18.997     1.424
# ==============================================================================
# Omnibus:                     6306.570   Durbin-Watson:                   1.911
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           190442.564
# Skew:                           2.645   Prob(JB):                         0.00
# Kurtosis:                      24.017   Cond. No.                         359.
# ==============================================================================

# %%
# I6 helps and really makes the MaxAllwFAR variable no longer significant
print lm.smf_linear(best_continuous_features + ['I1', 'I9', 'D4', 'K6', 'D1', 'I6'],
                    'EUIwn', bd_train.join(X)).summary()
# Out:
# EUIwn ~ PerComArea + PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + Easements + NumBldgs + NumFloors + MaxAllwFAR + I1 + I9 + D4 + K6 + D1 + I6
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.305
# Model:                            OLS   Adj. R-squared:                  0.304
# Method:                 Least Squares   F-statistic:                     284.2
# Date:                Wed, 18 Mar 2015   Prob (F-statistic):               0.00
# Time:                        16:31:41   Log-Likelihood:                -55564.
# No. Observations:                9731   AIC:                         1.112e+05
# Df Residuals:                    9715   BIC:                         1.113e+05
# Df Model:                          15
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       115.1914      1.980     58.176      0.000       111.310   119.073
# PerComArea      -23.7192      3.698     -6.415      0.000       -30.967   -16.471
# PerOfficeArea    99.9365      4.594     21.753      0.000        90.931   108.942
# PerOtherArea     94.5258      4.837     19.543      0.000        85.045   104.007
# PerRetailArea   129.2086      7.837     16.488      0.000       113.847   144.570
# PerGarageArea    87.8163     11.131      7.889      0.000        65.996   109.636
# Easements        10.8578      4.424      2.454      0.014         2.185    19.531
# NumBldgs          0.6710      0.115      5.843      0.000         0.446     0.896
# NumFloors         1.2877      0.113     11.345      0.000         1.065     1.510
# MaxAllwFAR       -0.0458      0.285     -0.161      0.872        -0.605     0.513
# I1              314.0497     11.680     26.888      0.000       291.155   336.945
# I9              237.2339     17.362     13.664      0.000       203.201   271.267
# D4              -14.6319      2.093     -6.992      0.000       -18.734   -10.530
# K6              125.3101     13.150      9.529      0.000        99.533   151.088
# D1               -3.8306      2.236     -1.713      0.087        -8.213     0.552
# I6               91.1045      8.627     10.561      0.000        74.194   108.014
# ==============================================================================
# Omnibus:                     6436.956   Durbin-Watson:                   1.912
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           203076.550
# Skew:                           2.712   Prob(JB):                         0.00
# Kurtosis:                      24.712   Cond. No.                         359.
# ==============================================================================

# %%
# eventually these dummies make the commercial area value no longer have significance
curr_features = ['PerComArea',
 'PerOfficeArea',
 'PerOtherArea',
 'PerRetailArea',
 'PerGarageArea',
 'Easements',
 'NumBldgs',
 'NumFloors',]
curr_features = curr_features + ['I1', 'I9', 'D4', 'K6', 'D1', 'I6', 'K1', 'J6',  'P7',
 'R5',
 'E7',
 'H2',
 'K9',
 'F2',
 'I5',
 'H3',
 'W6',
 'H1',
 'H5',
 'O1',
 'E1',
 'F1',
 'H9',
 'E9',
 'J8',
 'O6',
 'G1',]

# 03 not so much
print lm.smf_linear(curr_features,
                    'EUIwn', bd_train.join(X)).summary()
# Out:
# EUIwn ~ PerComArea + PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + Easements + NumBldgs + NumFloors + I1 + I9 + D4 + K6 + D1 + I6 + K1 + J6 + P7 + R5 + E7 + H2 + K9 + F2 + I5 + H3 + W6 + H1 + H5 + O1 + E1 + F1 + H9 + E9 + J8 + O6 + G1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.356
# Model:                            OLS   Adj. R-squared:                  0.354
# Method:                 Least Squares   F-statistic:                     153.1
# Date:                Wed, 18 Mar 2015   Prob (F-statistic):               0.00
# Time:                        16:31:42   Log-Likelihood:                -55194.
# No. Observations:                9731   AIC:                         1.105e+05
# Df Residuals:                    9695   BIC:                         1.107e+05
# Df Model:                          35
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       116.9818      1.801     64.955      0.000       113.452   120.512
# PerComArea       -9.6784      4.661     -2.076      0.038       -18.815    -0.541
# PerOfficeArea    78.2618      5.260     14.879      0.000        67.951    88.572
# PerOtherArea     44.9657      6.009      7.483      0.000        33.187    56.745
# PerRetailArea    67.4783      9.348      7.218      0.000        49.153    85.803
# PerGarageArea    38.0640     13.949      2.729      0.006        10.720    65.408
# Easements         8.2059      4.273      1.920      0.055        -0.171    16.583
# NumBldgs          0.6636      0.110      6.016      0.000         0.447     0.880
# NumFloors         1.3219      0.092     14.335      0.000         1.141     1.503
# I1              336.7437     11.347     29.676      0.000       314.500   358.987
# I9              256.6458     16.780     15.295      0.000       223.754   289.538
# D4              -16.2603      2.020     -8.050      0.000       -20.219   -12.301
# K6              167.3678     13.226     12.654      0.000       141.441   193.294
# D1               -5.6979      2.154     -2.645      0.008        -9.921    -1.475
# I6              120.1623      8.514     14.114      0.000       103.474   136.851
# K1              145.8806     17.708      8.238      0.000       111.169   180.592
# J6              263.1679     22.439     11.728      0.000       219.182   307.153
# P7              382.3631     31.684     12.068      0.000       320.255   444.471
# R5               34.2860      7.003      4.896      0.000        20.558    48.014
# E7              -65.0791      8.853     -7.351      0.000       -82.434   -47.725
# H2               88.4336     11.721      7.545      0.000        65.459   111.408
# K9               75.1639     10.994      6.837      0.000        53.613    96.715
# F2              247.9296     23.860     10.391      0.000       201.159   294.700
# I5              148.7253     19.706      7.547      0.000       110.098   187.353
# H3               75.1783     13.425      5.600      0.000        48.863   101.493
# W6                9.4137     10.881      0.865      0.387       -11.915    30.742
# H1              106.9941     18.076      5.919      0.000        71.562   142.427
# H5              192.8165     31.772      6.069      0.000       130.538   255.095
# O1               11.1231     10.600      1.049      0.294        -9.655    31.901
# E1              -24.6506      9.262     -2.661      0.008       -42.807    -6.495
# F1              -31.0732     10.890     -2.853      0.004       -52.420    -9.726
# H9               50.2954     12.235      4.111      0.000        26.313    74.278
# E9              -29.3597     10.817     -2.714      0.007       -50.564    -8.156
# J8              118.4643     31.749      3.731      0.000        56.229   180.699
# O6              147.3434     35.321      4.172      0.000        78.106   216.580
# G1               73.7417     20.128      3.664      0.000        34.286   113.198
# ==============================================================================
# Omnibus:                     5731.662   Durbin-Watson:                   1.906
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           163574.698
# Skew:                           2.314   Prob(JB):                         0.00
# Kurtosis:                      22.545   Cond. No.                         700.
# ==============================================================================

# %%
# adding the rest of the dummies and removing any of them that is no longer signficant also makes the NumBldgs no longer matter
curr_features = ['PerOfficeArea',
 'PerOtherArea',
 'PerRetailArea',
 'PerGarageArea',
 'Easements',
 'NumBldgs',
 'NumFloors',]
curr_features = curr_features + ['I1', 'I9', 'D4', 'K6', 'D1', 'I6', 'K1', 'J6',  'P7',
 'R5',
 'E7',
 'H2',
 'K9',
 'F2',
 'I5',
 'H3',
 'W6',
 'H1',
 'H5',
 'O1',
 'E1',
 'F1',
 'H9',
 'E9',
 'J8',
 'O6',
 'G1',
 'F9',
 'J4',
 'K2',
 'I2',
 'F4',
 'P5',
 'N2',
 'D0',
 'L1',
 'W5',
 'P6',
 'E3',
 'W7',
 'C6',
 'J5',
 'P3',]

# 03 not so much
print lm.smf_linear(curr_features,
                    'EUIwn', bd_train.join(X)).summary()
# Out:
# EUIwn ~ PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + Easements + NumBldgs + NumFloors + I1 + I9 + D4 + K6 + D1 + I6 + K1 + J6 + P7 + R5 + E7 + H2 + K9 + F2 + I5 + H3 + W6 + H1 + H5 + O1 + E1 + F1 + H9 + E9 + J8 + O6 + G1 + F9 + J4 + K2 + I2 + F4 + P5 + N2 + D0 + L1 + W5 + P6 + E3 + W7 + C6 + J5 + P3
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.368
# Model:                            OLS   Adj. R-squared:                  0.365
# Method:                 Least Squares   F-statistic:                     112.7
# Date:                Wed, 18 Mar 2015   Prob (F-statistic):               0.00
# Time:                        16:32:10   Log-Likelihood:                -55102.
# No. Observations:                9731   AIC:                         1.103e+05
# Df Residuals:                    9680   BIC:                         1.107e+05
# Df Model:                          50
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       117.3365      1.773     66.190      0.000       113.862   120.811
# PerOfficeArea    67.2982      2.997     22.456      0.000        61.424    73.173
# PerOtherArea     23.7045      4.595      5.159      0.000        14.697    32.711
# PerRetailArea    49.8176      8.664      5.750      0.000        32.834    66.801
# PerGarageArea    23.8319     13.400      1.779      0.075        -2.435    50.099
# Easements         8.0440      4.238      1.898      0.058        -0.263    16.351
# NumBldgs          0.3879      0.140      2.778      0.005         0.114     0.662
# NumFloors         1.3955      0.092     15.117      0.000         1.215     1.576
# I1              343.9554     11.306     30.422      0.000       321.793   366.117
# I9              262.3152     16.662     15.743      0.000       229.653   294.977
# D4              -16.9640      1.993     -8.514      0.000       -20.870   -13.058
# K6              174.5960     13.288     13.139      0.000       148.549   200.643
# D1               -6.1664      2.128     -2.898      0.004       -10.338    -1.995
# I6              129.5403      8.570     15.116      0.000       112.742   146.339
# K1              153.6234     17.701      8.679      0.000       118.926   188.321
# J6              269.5082     22.270     12.102      0.000       225.855   313.162
# P7              391.1521     31.443     12.440      0.000       329.518   452.786
# R5               36.6023      6.964      5.256      0.000        22.952    50.253
# E7              -74.1674      7.840     -9.460      0.000       -89.536   -58.799
# H2               97.8827     11.723      8.350      0.000        74.903   120.862
# K9               81.2926     11.009      7.384      0.000        59.713   102.872
# F2              238.9833     23.339     10.240      0.000       193.234   284.733
# I5              153.8036     19.556      7.865      0.000       115.470   192.137
# H3               85.1958     13.403      6.357      0.000        58.923   111.468
# W6               18.6440     10.877      1.714      0.087        -2.678    39.966
# H1              116.9699     17.994      6.501      0.000        81.698   152.242
# H5              203.5322     31.542      6.453      0.000       141.703   265.361
# O1               12.7061     10.517      1.208      0.227        -7.910    33.322
# E1              -33.2963      8.387     -3.970      0.000       -49.736   -16.857
# F1              -39.9797     10.091     -3.962      0.000       -59.760   -20.199
# H9               60.7041     12.241      4.959      0.000        36.709    84.699
# E9              -37.5697     10.090     -3.724      0.000       -57.347   -17.792
# J8              128.4924     31.508      4.078      0.000        66.731   190.254
# O6              148.6411     35.018      4.245      0.000        79.998   217.285
# G1               77.8315     19.958      3.900      0.000        38.710   116.953
# F9              -45.2025     12.632     -3.578      0.000       -69.965   -20.440
# J4              227.9529     49.494      4.606      0.000       130.934   324.972
# K2               66.7883     18.815      3.550      0.000        29.907   103.670
# I2              330.6158     69.979      4.725      0.000       193.443   467.789
# F4               53.8688     14.647      3.678      0.000        25.158    82.580
# P5              174.1598     40.423      4.308      0.000        94.921   253.398
# N2               29.8372     10.582      2.820      0.005         9.094    50.581
# D0              -32.5974      9.591     -3.399      0.001       -51.397   -13.798
# L1              -32.8740      6.074     -5.412      0.000       -44.780   -20.968
# W5               58.9387     69.895      0.843      0.399       -78.071   195.948
# P6              166.0100     49.575      3.349      0.001        68.832   263.188
# E3              -29.5620     15.328     -1.929      0.054       -59.609     0.485
# W7               75.1320     26.678      2.816      0.005        22.838   127.426
# C6               32.8068     10.720      3.060      0.002        11.793    53.821
# J5              129.1717     49.539      2.607      0.009        32.065   226.278
# P3               60.5238     26.675      2.269      0.023         8.236   112.812
# ==============================================================================
# Omnibus:                     5659.694   Durbin-Watson:                   1.911
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           164262.168
# Skew:                           2.266   Prob(JB):                         0.00
# Kurtosis:                      22.611   Cond. No.                     1.40e+03
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 1.4e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# adding the rest of the dummies and removing any of them that is no longer signficant also makes the NumBldgs no longer matter
curr_features = ['PerOfficeArea',
 'PerOtherArea',
 'PerRetailArea',
 'PerGarageArea',
 'Easements',
 #'NumBldgs',
 'NumFloors',]
curr_features = curr_features + ['I1', 'I9', 'D4', 'K6', 'D1', 'I6', 'K1', 'J6',  'P7',
 'R5',
 'E7',
 'H2',
 'K9',
 'F2',
 'I5',
 'H3',
 'W6',
 'H1',
 'H5',
 'O1',
 'E1',
 'F1',
 'H9',
 'E9',
 'J8',
 'O6',
 'G1',
 'F9',
 'J4',
 'K2',
 'I2',
 'F4',
 'P5',
 'N2',
 'D0',
 'I3',
 'L1',
 'W5',
 'P6',
 'E3',
 'W7',
 'C6',
 'J5',
 'P3',]

# 03 not so much
for i in range(1, len(curr_features)+1):
    print lm.smf_linear(curr_features[0:i],
                    'EUIwn', bd_train.join(X)], axis=1)).summary()
# Out:
# EUIwn ~ PerOfficeArea
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.082
# Model:                            OLS   Adj. R-squared:                  0.082
# Method:                 Least Squares   F-statistic:                     936.2
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):          4.75e-197
# Time:                        02:48:05   Log-Likelihood:                -62123.
# No. Observations:               10532   AIC:                         1.242e+05
# Df Residuals:                   10530   BIC:                         1.243e+05
# Df Model:                           1
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       137.7971      0.914    150.684      0.000       136.005   139.590
# PerOfficeArea    96.3153      3.148     30.597      0.000        90.145   102.486
# ==============================================================================
# Omnibus:                     7501.204   Durbin-Watson:                   1.584
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           152814.917
# Skew:                           3.212   Prob(JB):                         0.00
# Kurtosis:                      20.520   Cond. No.                         3.70
# ==============================================================================
# EUIwn ~ PerOfficeArea + PerOtherArea
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.174
# Model:                            OLS   Adj. R-squared:                  0.174
# Method:                 Least Squares   F-statistic:                     1112.
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):               0.00
# Time:                        02:48:05   Log-Likelihood:                -61562.
# No. Observations:               10532   AIC:                         1.231e+05
# Df Residuals:                   10529   BIC:                         1.232e+05
# Df Model:                           2
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       128.9944      0.904    142.678      0.000       127.222   130.767
# PerOfficeArea   104.9476      2.995     35.037      0.000        99.076   110.819
# PerOtherArea    119.0680      3.462     34.393      0.000       112.282   125.854
# ==============================================================================
# Omnibus:                     7184.763   Durbin-Watson:                   1.667
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           157615.964
# Skew:                           2.982   Prob(JB):                         0.00
# Kurtosis:                      20.989   Cond. No.                         4.34
# ==============================================================================
# EUIwn ~ PerOfficeArea + PerOtherArea + PerRetailArea
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.219
# Model:                            OLS   Adj. R-squared:                  0.218
# Method:                 Least Squares   F-statistic:                     981.5
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):               0.00
# Time:                        02:48:05   Log-Likelihood:                -61272.
# No. Observations:               10532   AIC:                         1.226e+05
# Df Residuals:                   10528   BIC:                         1.226e+05
# Df Model:                           3
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       123.1101      0.912    134.972      0.000       121.322   124.898
# PerOfficeArea   101.2774      2.918     34.706      0.000        95.557   106.998
# PerOtherArea    122.3531      3.371     36.296      0.000       115.745   128.961
# PerRetailArea   152.3818      6.248     24.389      0.000       140.135   164.629
# ==============================================================================
# Omnibus:                     6906.380   Durbin-Watson:                   1.696
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           155711.157
# Skew:                           2.802   Prob(JB):                         0.00
# Kurtosis:                      20.984   Cond. No.                         7.96
# ==============================================================================
# EUIwn ~ PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.224
# Model:                            OLS   Adj. R-squared:                  0.224
# Method:                 Least Squares   F-statistic:                     759.2
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):               0.00
# Time:                        02:48:05   Log-Likelihood:                -61236.
# No. Observations:               10532   AIC:                         1.225e+05
# Df Residuals:                   10527   BIC:                         1.225e+05
# Df Model:                           4
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       121.6481      0.925    131.498      0.000       119.835   123.461
# PerOfficeArea   102.0506      2.910     35.073      0.000        96.347   107.754
# PerOtherArea    123.1783      3.361     36.649      0.000       116.590   129.767
# PerRetailArea   150.3142      6.232     24.122      0.000       138.099   162.529
# PerGarageArea    94.8090     11.130      8.518      0.000        72.992   116.626
# ==============================================================================
# Omnibus:                     6868.795   Durbin-Watson:                   1.701
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           155974.404
# Skew:                           2.777   Prob(JB):                         0.00
# Kurtosis:                      21.016   Cond. No.                         14.2
# ==============================================================================
# EUIwn ~ PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + Easements
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.226
# Model:                            OLS   Adj. R-squared:                  0.225
# Method:                 Least Squares   F-statistic:                     613.0
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):               0.00
# Time:                        02:48:05   Log-Likelihood:                -61225.
# No. Observations:               10532   AIC:                         1.225e+05
# Df Residuals:                   10526   BIC:                         1.225e+05
# Df Model:                           5
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       121.3919      0.926    131.123      0.000       119.577   123.207
# PerOfficeArea   101.8915      2.907     35.050      0.000        96.193   107.590
# PerOtherArea    121.2035      3.384     35.817      0.000       114.570   127.837
# PerRetailArea   150.0425      6.226     24.101      0.000       137.839   162.246
# PerGarageArea    91.1610     11.146      8.179      0.000        69.313   113.009
# Easements        15.0547      3.210      4.690      0.000         8.762    21.347
# ==============================================================================
# Omnibus:                     6892.976   Durbin-Watson:                   1.704
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           157103.468
# Skew:                           2.790   Prob(JB):                         0.00
# Kurtosis:                      21.079   Cond. No.                         14.3
# ==============================================================================
# EUIwn ~ PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + Easements + NumFloors
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.235
# Model:                            OLS   Adj. R-squared:                  0.235
# Method:                 Least Squares   F-statistic:                     539.2
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):               0.00
# Time:                        02:48:05   Log-Likelihood:                -61160.
# No. Observations:               10532   AIC:                         1.223e+05
# Df Residuals:                   10525   BIC:                         1.224e+05
# Df Model:                           6
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       110.7951      1.303     85.037      0.000       108.241   113.349
# PerOfficeArea    91.2254      3.035     30.061      0.000        85.277    97.174
# PerOtherArea    119.5443      3.366     35.513      0.000       112.946   126.143
# PerRetailArea   154.4366      6.199     24.913      0.000       142.285   166.588
# PerGarageArea    84.6570     11.092      7.632      0.000        62.915   106.399
# Easements        15.3802      3.190      4.821      0.000         9.127    21.634
# NumFloors         1.0674      0.093     11.487      0.000         0.885     1.250
# ==============================================================================
# Omnibus:                     7116.489   Durbin-Watson:                   1.717
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           171668.804
# Skew:                           2.903   Prob(JB):                         0.00
# Kurtosis:                      21.907   Cond. No.                         200.
# ==============================================================================
# EUIwn ~ PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + Easements + NumFloors + I1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.291
# Model:                            OLS   Adj. R-squared:                  0.290
# Method:                 Least Squares   F-statistic:                     616.1
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):               0.00
# Time:                        02:48:05   Log-Likelihood:                -60763.
# No. Observations:               10532   AIC:                         1.215e+05
# Df Residuals:                   10524   BIC:                         1.216e+05
# Df Model:                           7
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       109.6941      1.255     87.382      0.000       107.233   112.155
# PerOfficeArea    84.7468      2.931     28.912      0.000        79.001    90.492
# PerOtherArea     99.3686      3.317     29.957      0.000        92.866   105.871
# PerRetailArea   158.0015      5.971     26.461      0.000       146.297   169.706
# PerGarageArea    80.3133     10.683      7.518      0.000        59.373   101.254
# Easements        16.8117      3.073      5.471      0.000        10.788    22.835
# NumFloors         1.1850      0.090     13.227      0.000         1.009     1.361
# I1              295.5369     10.293     28.711      0.000       275.360   315.714
# ==============================================================================
# Omnibus:                     6672.486   Durbin-Watson:                   1.771
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           162482.320
# Skew:                           2.635   Prob(JB):                         0.00
# Kurtosis:                      21.506   Cond. No.                         200.
# ==============================================================================
# EUIwn ~ PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + Easements + NumFloors + I1 + I9
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.313
# Model:                            OLS   Adj. R-squared:                  0.313
# Method:                 Least Squares   F-statistic:                     599.8
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):               0.00
# Time:                        02:48:06   Log-Likelihood:                -60593.
# No. Observations:               10532   AIC:                         1.212e+05
# Df Residuals:                   10523   BIC:                         1.213e+05
# Df Model:                           8
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       110.0664      1.235     89.088      0.000       107.645   112.488
# PerOfficeArea    83.0302      2.886     28.771      0.000        77.373    88.687
# PerOtherArea     89.5946      3.306     27.098      0.000        83.114    96.076
# PerRetailArea   159.2802      5.876     27.105      0.000       147.761   170.799
# PerGarageArea    79.2656     10.513      7.540      0.000        58.659    99.872
# Easements        17.9288      3.024      5.928      0.000        12.000    23.857
# NumFloors         1.1453      0.088     12.988      0.000         0.972     1.318
# I1              302.8293     10.137     29.874      0.000       282.959   322.699
# I9              254.4334     13.697     18.576      0.000       227.585   281.282
# ==============================================================================
# Omnibus:                     6435.430   Durbin-Watson:                   1.810
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           158162.253
# Skew:                           2.496   Prob(JB):                         0.00
# Kurtosis:                      21.316   Cond. No.                         261.
# ==============================================================================
# EUIwn ~ PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + Easements + NumFloors + I1 + I9 + D4
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.315
# Model:                            OLS   Adj. R-squared:                  0.315
# Method:                 Least Squares   F-statistic:                     538.7
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):               0.00
# Time:                        02:48:06   Log-Likelihood:                -60575.
# No. Observations:               10532   AIC:                         1.212e+05
# Df Residuals:                   10522   BIC:                         1.212e+05
# Df Model:                           9
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       112.8655      1.323     85.322      0.000       110.273   115.458
# PerOfficeArea    79.3355      2.950     26.898      0.000        73.554    85.117
# PerOtherArea     86.1537      3.353     25.695      0.000        79.581    92.726
# PerRetailArea   154.8440      5.916     26.175      0.000       143.248   166.440
# PerGarageArea    75.3843     10.517      7.168      0.000        54.769    95.999
# Easements        18.0875      3.020      5.990      0.000        12.168    24.007
# NumFloors         1.1885      0.088     13.452      0.000         1.015     1.362
# I1              303.1254     10.121     29.950      0.000       283.286   322.964
# I9              254.2262     13.675     18.590      0.000       227.420   281.032
# D4              -10.9285      1.865     -5.859      0.000       -14.585    -7.272
# ==============================================================================
# Omnibus:                     6431.202   Durbin-Watson:                   1.810
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           159098.299
# Skew:                           2.491   Prob(JB):                         0.00
# Kurtosis:                      21.377   Cond. No.                         261.
# ==============================================================================
# EUIwn ~ PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + Easements + NumFloors + I1 + I9 + D4 + K6
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.321
# Model:                            OLS   Adj. R-squared:                  0.320
# Method:                 Least Squares   F-statistic:                     497.4
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):               0.00
# Time:                        02:48:06   Log-Likelihood:                -60532.
# No. Observations:               10532   AIC:                         1.211e+05
# Df Residuals:                   10521   BIC:                         1.212e+05
# Df Model:                          10
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       113.1212      1.318     85.845      0.000       110.538   115.704
# PerOfficeArea    80.1359      2.939     27.268      0.000        74.375    85.897
# PerOtherArea     85.8405      3.339     25.705      0.000        79.294    92.386
# PerRetailArea   122.4864      6.839     17.910      0.000       109.081   135.892
# PerGarageArea    69.7974     10.491      6.653      0.000        49.232    90.362
# Easements        17.4118      3.008      5.788      0.000        11.515    23.309
# NumFloors         1.2382      0.088     14.046      0.000         1.065     1.411
# I1              302.6049     10.080     30.020      0.000       282.846   322.364
# I9              253.2564     13.620     18.594      0.000       226.558   279.955
# D4              -11.4321      1.859     -6.151      0.000       -15.075    -7.789
# K6              101.2913     10.871      9.318      0.000        79.983   122.600
# ==============================================================================
# Omnibus:                     6331.802   Durbin-Watson:                   1.812
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           157267.540
# Skew:                           2.434   Prob(JB):                         0.00
# Kurtosis:                      21.294   Cond. No.                         261.
# ==============================================================================
# EUIwn ~ PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + Easements + NumFloors + I1 + I9 + D4 + K6 + D1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.321
# Model:                            OLS   Adj. R-squared:                  0.320
# Method:                 Least Squares   F-statistic:                     452.4
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):               0.00
# Time:                        02:48:06   Log-Likelihood:                -60532.
# No. Observations:               10532   AIC:                         1.211e+05
# Df Residuals:                   10520   BIC:                         1.212e+05
# Df Model:                          11
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       114.2724      1.634     69.955      0.000       111.070   117.474
# PerOfficeArea    79.3997      3.003     26.441      0.000        73.513    85.286
# PerOtherArea     84.9199      3.427     24.776      0.000        78.201    91.638
# PerRetailArea   120.6724      7.006     17.224      0.000       106.939   134.405
# PerGarageArea    68.5885     10.540      6.507      0.000        47.928    89.249
# Easements        17.3726      3.009      5.774      0.000        11.475    23.270
# NumFloors         1.2173      0.090     13.542      0.000         1.041     1.393
# I1              302.5091     10.080     30.010      0.000       282.750   322.268
# I9              253.3085     13.620     18.598      0.000       226.610   280.006
# D4              -12.3186      2.002     -6.154      0.000       -16.242    -8.395
# K6              101.8603     10.881      9.361      0.000        80.532   123.189
# D1               -2.5582      2.145     -1.193      0.233        -6.763     1.647
# ==============================================================================
# Omnibus:                     6323.740   Durbin-Watson:                   1.811
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           156950.305
# Skew:                           2.430   Prob(JB):                         0.00
# Kurtosis:                      21.277   Cond. No.                         261.
# ==============================================================================
# EUIwn ~ PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + Easements + NumFloors + I1 + I9 + D4 + K6 + D1 + I6
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.328
# Model:                            OLS   Adj. R-squared:                  0.327
# Method:                 Least Squares   F-statistic:                     427.5
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):               0.00
# Time:                        02:48:06   Log-Likelihood:                -60479.
# No. Observations:               10532   AIC:                         1.210e+05
# Df Residuals:                   10519   BIC:                         1.211e+05
# Df Model:                          12
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       113.6210      1.627     69.844      0.000       110.432   116.810
# PerOfficeArea    77.9113      2.992     26.041      0.000        72.047    83.776
# PerOtherArea     74.2475      3.567     20.815      0.000        67.255    81.240
# PerRetailArea   121.6332      6.972     17.445      0.000       107.966   135.300
# PerGarageArea    69.0343     10.489      6.582      0.000        48.475    89.594
# Easements        18.5239      2.996      6.183      0.000        12.651    24.397
# NumFloors         1.2722      0.090     14.197      0.000         1.097     1.448
# I1              310.5424     10.062     30.864      0.000       290.820   330.265
# I9              260.9699     13.574     19.225      0.000       234.362   287.578
# D4              -12.3052      1.992     -6.178      0.000       -16.210    -8.401
# K6              101.7672     10.828      9.399      0.000        80.543   122.992
# D1               -2.2626      2.135     -1.060      0.289        -6.448     1.922
# I6               89.9728      8.804     10.219      0.000        72.715   107.230
# ==============================================================================
# Omnibus:                     6427.640   Durbin-Watson:                   1.814
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           165837.069
# Skew:                           2.475   Prob(JB):                         0.00
# Kurtosis:                      21.799   Cond. No.                         261.
# ==============================================================================
# EUIwn ~ PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + Easements + NumFloors + I1 + I9 + D4 + K6 + D1 + I6 + K1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.333
# Model:                            OLS   Adj. R-squared:                  0.332
# Method:                 Least Squares   F-statistic:                     403.4
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):               0.00
# Time:                        02:48:06   Log-Likelihood:                -60441.
# No. Observations:               10532   AIC:                         1.209e+05
# Df Residuals:                   10518   BIC:                         1.210e+05
# Df Model:                          13
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       114.1827      1.622     70.388      0.000       111.003   117.363
# PerOfficeArea    78.4424      2.982     26.308      0.000        72.598    84.287
# PerOtherArea     73.6090      3.555     20.706      0.000        66.641    80.577
# PerRetailArea    92.2299      7.712     11.959      0.000        77.113   107.347
# PerGarageArea    68.4672     10.451      6.551      0.000        47.981    88.953
# Easements        18.6198      2.985      6.237      0.000        12.768    24.471
# NumFloors         1.3075      0.089     14.629      0.000         1.132     1.483
# I1              310.0063     10.026     30.921      0.000       290.354   329.659
# I9              260.1460     13.526     19.233      0.000       233.633   286.659
# D4              -13.0323      1.986     -6.561      0.000       -16.926    -9.138
# K6              126.1697     11.141     11.325      0.000       104.331   148.008
# D1               -3.0431      2.129     -1.429      0.153        -7.217     1.130
# I6               89.9891      8.772     10.258      0.000        72.794   107.185
# K1              136.9040     15.590      8.781      0.000       106.344   167.464
# ==============================================================================
# Omnibus:                     6393.954   Durbin-Watson:                   1.822
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           165214.201
# Skew:                           2.455   Prob(JB):                         0.00
# Kurtosis:                      21.772   Cond. No.                         320.
# ==============================================================================
# EUIwn ~ PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + Easements + NumFloors + I1 + I9 + D4 + K6 + D1 + I6 + K1 + J6
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.339
# Model:                            OLS   Adj. R-squared:                  0.338
# Method:                 Least Squares   F-statistic:                     385.7
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):               0.00
# Time:                        02:48:06   Log-Likelihood:                -60389.
# No. Observations:               10532   AIC:                         1.208e+05
# Df Residuals:                   10517   BIC:                         1.209e+05
# Df Model:                          14
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       113.8931      1.615     70.542      0.000       110.728   117.058
# PerOfficeArea    76.8779      2.971     25.875      0.000        71.054    82.702
# PerOtherArea     71.0390      3.547     20.030      0.000        64.087    77.991
# PerRetailArea    93.0822      7.675     12.128      0.000        78.038   108.127
# PerGarageArea    68.6811     10.400      6.604      0.000        48.295    89.067
# Easements        18.6529      2.971      6.279      0.000        12.830    24.476
# NumFloors         1.3342      0.089     14.995      0.000         1.160     1.509
# I1              312.2886      9.979     31.293      0.000       292.727   331.850
# I9              262.1628     13.461     19.475      0.000       235.776   288.550
# D4              -13.0430      1.977     -6.598      0.000       -16.918    -9.168
# K6              125.7776     11.087     11.345      0.000       104.046   147.510
# D1               -2.9233      2.119     -1.380      0.168        -7.077     1.230
# I6               92.3942      8.733     10.580      0.000        75.276   109.512
# K1              136.4671     15.515      8.796      0.000       106.056   166.879
# J6              242.7062     23.780     10.206      0.000       196.093   289.319
# ==============================================================================
# Omnibus:                     6108.841   Durbin-Watson:                   1.824
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           144519.481
# Skew:                           2.327   Prob(JB):                         0.00
# Kurtosis:                      20.540   Cond. No.                         460.
# ==============================================================================
# EUIwn ~ PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + Easements + NumFloors + I1 + I9 + D4 + K6 + D1 + I6 + K1 + J6 + P7
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.346
# Model:                            OLS   Adj. R-squared:                  0.345
# Method:                 Least Squares   F-statistic:                     371.5
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):               0.00
# Time:                        02:48:07   Log-Likelihood:                -60332.
# No. Observations:               10532   AIC:                         1.207e+05
# Df Residuals:                   10516   BIC:                         1.208e+05
# Df Model:                          15
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       113.7543      1.606     70.834      0.000       110.606   116.902
# PerOfficeArea    76.2679      2.956     25.804      0.000        70.474    82.062
# PerOtherArea     68.2151      3.537     19.284      0.000        61.281    75.149
# PerRetailArea    93.6006      7.634     12.261      0.000        78.637   108.565
# PerGarageArea    68.7673     10.344      6.648      0.000        48.490    89.044
# Easements        19.0558      2.955      6.449      0.000        13.264    24.848
# NumFloors         1.3469      0.089     15.217      0.000         1.173     1.520
# I1              314.4485      9.928     31.673      0.000       294.988   333.909
# I9              264.2343     13.391     19.733      0.000       237.986   290.482
# D4              -13.0548      1.966     -6.640      0.000       -16.909    -9.201
# K6              125.4942     11.027     11.380      0.000       103.879   147.110
# D1               -2.8676      2.107     -1.361      0.174        -6.999     1.263
# I6               94.8474      8.689     10.916      0.000        77.815   111.879
# K1              136.1993     15.431      8.826      0.000       105.951   166.447
# J6              244.5081     23.653     10.337      0.000       198.144   290.872
# P7              358.1527     33.412     10.719      0.000       292.659   423.646
# ==============================================================================
# Omnibus:                     6066.534   Durbin-Watson:                   1.816
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           143740.584
# Skew:                           2.304   Prob(JB):                         0.00
# Kurtosis:                      20.502   Cond. No.                         650.
# ==============================================================================
# EUIwn ~ PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + Easements + NumFloors + I1 + I9 + D4 + K6 + D1 + I6 + K1 + J6 + P7 + R5
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.347
# Model:                            OLS   Adj. R-squared:                  0.346
# Method:                 Least Squares   F-statistic:                     348.8
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):               0.00
# Time:                        02:48:07   Log-Likelihood:                -60329.
# No. Observations:               10532   AIC:                         1.207e+05
# Df Residuals:                   10515   BIC:                         1.208e+05
# Df Model:                          16
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       113.9635      1.608     70.875      0.000       110.812   117.115
# PerOfficeArea    75.1913      2.989     25.153      0.000        69.332    81.051
# PerOtherArea     67.4714      3.550     19.004      0.000        60.512    74.431
# PerRetailArea    91.2028      7.698     11.847      0.000        76.113   106.293
# PerGarageArea    68.5023     10.343      6.623      0.000        48.229    88.776
# Easements        19.2007      2.955      6.498      0.000        13.408    24.993
# NumFloors         1.3330      0.089     15.032      0.000         1.159     1.507
# I1              315.1695      9.930     31.738      0.000       295.704   334.635
# I9              265.0353     13.392     19.791      0.000       238.785   291.286
# D4              -13.0851      1.966     -6.657      0.000       -16.938    -9.232
# K6              127.3988     11.054     11.526      0.000       105.732   149.066
# D1               -2.9859      2.108     -1.417      0.157        -7.117     1.145
# I6               95.5005      8.691     10.988      0.000        78.464   112.537
# K1              138.2968     15.453      8.950      0.000       108.006   168.587
# J6              245.2920     23.650     10.372      0.000       198.934   291.650
# P7              358.8770     33.406     10.743      0.000       293.395   424.359
# R5               16.7510      7.024      2.385      0.017         2.983    30.519
# ==============================================================================
# Omnibus:                     6064.990   Durbin-Watson:                   1.817
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           144080.269
# Skew:                           2.302   Prob(JB):                         0.00
# Kurtosis:                      20.525   Cond. No.                         650.
# ==============================================================================
# EUIwn ~ PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + Easements + NumFloors + I1 + I9 + D4 + K6 + D1 + I6 + K1 + J6 + P7 + R5 + E7
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.352
# Model:                            OLS   Adj. R-squared:                  0.351
# Method:                 Least Squares   F-statistic:                     335.6
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):               0.00
# Time:                        02:48:07   Log-Likelihood:                -60288.
# No. Observations:               10532   AIC:                         1.206e+05
# Df Residuals:                   10514   BIC:                         1.207e+05
# Df Model:                          17
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       116.1987      1.621     71.689      0.000       113.022   119.376
# PerOfficeArea    73.9806      2.981     24.818      0.000        68.137    79.824
# PerOtherArea     66.0358      3.540     18.652      0.000        59.096    72.976
# PerRetailArea    88.2991      7.676     11.504      0.000        73.253   103.345
# PerGarageArea    65.7592     10.308      6.380      0.000        45.554    85.964
# Easements        19.3146      2.944      6.561      0.000        13.544    25.085
# NumFloors         1.2837      0.089     14.502      0.000         1.110     1.457
# I1              314.7465      9.893     31.817      0.000       295.355   334.138
# I9              264.9847     13.341     19.863      0.000       238.834   291.135
# D4              -14.7159      1.967     -7.483      0.000       -18.571   -10.861
# K6              127.9855     11.012     11.623      0.000       106.400   149.571
# D1               -4.8866      2.110     -2.316      0.021        -9.023    -0.750
# I6               94.9814      8.658     10.970      0.000        78.009   111.954
# K1              138.9393     15.394      9.025      0.000       108.764   169.115
# J6              244.7684     23.560     10.389      0.000       198.587   290.950
# P7              358.4719     33.279     10.772      0.000       293.239   423.705
# R5               16.9850      6.997      2.427      0.015         3.269    30.701
# E7              -73.9756      8.196     -9.026      0.000       -90.041   -57.910
# ==============================================================================
# Omnibus:                     6107.446   Durbin-Watson:                   1.816
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           147749.567
# Skew:                           2.319   Prob(JB):                         0.00
# Kurtosis:                      20.753   Cond. No.                         650.
# ==============================================================================
# EUIwn ~ PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + Easements + NumFloors + I1 + I9 + D4 + K6 + D1 + I6 + K1 + J6 + P7 + R5 + E7 + H2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.354
# Model:                            OLS   Adj. R-squared:                  0.352
# Method:                 Least Squares   F-statistic:                     319.4
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):               0.00
# Time:                        02:48:07   Log-Likelihood:                -60274.
# No. Observations:               10532   AIC:                         1.206e+05
# Df Residuals:                   10513   BIC:                         1.207e+05
# Df Model:                          18
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       116.7921      1.622     71.988      0.000       113.612   119.972
# PerOfficeArea    74.1851      2.977     24.918      0.000        68.349    80.021
# PerOtherArea     61.0895      3.652     16.729      0.000        53.931    68.247
# PerRetailArea    87.3806      7.667     11.397      0.000        72.351   102.410
# PerGarageArea    65.5770     10.294      6.370      0.000        45.399    85.755
# Easements        19.8905      2.942      6.762      0.000        14.124    25.657
# NumFloors         1.2350      0.089     13.899      0.000         1.061     1.409
# I1              317.9932      9.897     32.129      0.000       298.592   337.394
# I9              268.7257     13.341     20.143      0.000       242.575   294.876
# D4              -14.7628      1.964     -7.517      0.000       -18.613   -10.913
# K6              128.3453     10.997     11.671      0.000       106.789   149.902
# D1               -5.1653      2.108     -2.450      0.014        -9.297    -1.033
# I6               98.8353      8.676     11.392      0.000        81.829   115.842
# K1              139.3996     15.374      9.067      0.000       109.264   169.535
# J6              247.0927     23.532     10.500      0.000       200.965   293.220
# P7              362.2281     33.241     10.897      0.000       297.069   427.387
# R5               18.3213      6.992      2.620      0.009         4.615    32.028
# E7              -74.1962      8.185     -9.065      0.000       -90.240   -58.152
# H2               65.3447     12.066      5.416      0.000        41.693    88.997
# ==============================================================================
# Omnibus:                     6121.486   Durbin-Watson:                   1.818
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           149000.428
# Skew:                           2.325   Prob(JB):                         0.00
# Kurtosis:                      20.830   Cond. No.                         650.
# ==============================================================================
# EUIwn ~ PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + Easements + NumFloors + I1 + I9 + D4 + K6 + D1 + I6 + K1 + J6 + P7 + R5 + E7 + H2 + K9
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.355
# Model:                            OLS   Adj. R-squared:                  0.354
# Method:                 Least Squares   F-statistic:                     305.0
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):               0.00
# Time:                        02:48:07   Log-Likelihood:                -60259.
# No. Observations:               10532   AIC:                         1.206e+05
# Df Residuals:                   10512   BIC:                         1.207e+05
# Df Model:                          19
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       117.1366      1.621     72.240      0.000       113.958   120.315
# PerOfficeArea    73.9363      2.974     24.864      0.000        68.107    79.765
# PerOtherArea     59.7826      3.655     16.357      0.000        52.618    66.947
# PerRetailArea    68.9510      8.386      8.222      0.000        52.513    85.389
# PerGarageArea    62.9938     10.291      6.121      0.000        42.821    83.167
# Easements        19.5918      2.938      6.668      0.000        13.832    25.351
# NumFloors         1.2569      0.089     14.150      0.000         1.083     1.431
# I1              318.5243      9.885     32.224      0.000       299.148   337.900
# I9              269.0417     13.323     20.194      0.000       242.926   295.158
# D4              -15.1787      1.963     -7.733      0.000       -19.026   -11.331
# K6              143.8984     11.355     12.672      0.000       121.640   166.157
# D1               -5.6277      2.107     -2.671      0.008        -9.757    -1.498
# I6               99.6889      8.666     11.503      0.000        82.702   116.676
# K1              156.3939     15.674      9.978      0.000       125.670   187.117
# J6              247.5307     23.501     10.533      0.000       201.465   293.597
# P7              362.7839     33.197     10.928      0.000       297.711   427.857
# R5               20.9309      7.000      2.990      0.003         7.210    34.652
# E7              -74.3410      8.174     -9.095      0.000       -90.364   -58.318
# H2               66.4712     12.052      5.515      0.000        42.847    90.095
# K9               61.5770     11.425      5.390      0.000        39.181    83.973
# ==============================================================================
# Omnibus:                     6098.653   Durbin-Watson:                   1.821
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           149515.378
# Skew:                           2.310   Prob(JB):                         0.00
# Kurtosis:                      20.871   Cond. No.                         650.
# ==============================================================================
# ...
# D1               -6.6393      2.130     -3.117      0.002       -10.814    -2.464
# I6              125.9990      8.756     14.391      0.000       108.836   143.162
# K1              167.5229     15.453     10.841      0.000       137.232   197.814
# J6              266.3509     22.963     11.599      0.000       221.338   311.363
# P7              388.0760     32.426     11.968      0.000       324.514   451.638
# R5               29.2298      6.871      4.254      0.000        15.761    42.698
# E7              -74.4305      7.986     -9.320      0.000       -90.085   -58.776
# H2               93.9884     12.012      7.824      0.000        70.442   117.535
# K9               74.5553     11.264      6.619      0.000        52.476    96.635
# F2              238.2504     24.079      9.895      0.000       191.052   285.449
# I5              151.8854     20.165      7.532      0.000       112.358   191.413
# H3               77.1977     12.081      6.390      0.000        53.516   100.879
# W6               31.3859      8.882      3.534      0.000        13.975    48.797
# H1              104.1454     17.501      5.951      0.000        69.840   138.451
# H5              197.8610     32.513      6.086      0.000       134.130   261.592
# O1               21.7699     10.415      2.090      0.037         1.354    42.186
# E1              -33.7677      8.415     -4.013      0.000       -50.263   -17.272
# F1              -43.3548     10.011     -4.331      0.000       -62.978   -23.731
# H9               50.4361     12.224      4.126      0.000        26.475    74.397
# E9              -38.5720     10.010     -3.853      0.000       -58.193   -18.951
# J8              136.7990     27.514      4.972      0.000        82.867   190.731
# O6              147.3654     36.133      4.078      0.000        76.539   218.192
# G1               70.5652     19.908      3.545      0.000        31.541   109.589
# F9              -44.9828     13.029     -3.453      0.001       -70.522   -19.444
# J4              225.4132     51.067      4.414      0.000       125.313   325.513
# K2               61.0718     19.357      3.155      0.002        23.128    99.016
# I2              326.9131     72.202      4.528      0.000       185.383   468.444
# F4               85.4665     13.956      6.124      0.000        58.109   112.824
# P5              170.7575     41.706      4.094      0.000        89.005   252.510
# N2               37.9448     10.675      3.554      0.000        17.019    58.871
# D0              -33.1129      9.891     -3.348      0.001       -52.501   -13.725
# I3              150.8550     42.040      3.588      0.000        68.450   233.261
# L1              -33.3142      6.174     -5.395      0.000       -45.417   -21.211
# W5              122.7791     41.727      2.942      0.003        40.986   204.572
# P6              160.4447     51.144      3.137      0.002        60.192   260.698
# E3              -29.7569     15.810     -1.882      0.060       -60.748     1.235
# W7               71.9106     27.501      2.615      0.009        18.003   125.818
# C6               46.0219      7.055      6.524      0.000        32.193    59.851
# ==============================================================================
# Omnibus:                     5776.956   Durbin-Watson:                   1.839
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           145453.646
# Skew:                           2.128   Prob(JB):                         0.00
# Kurtosis:                      20.702   Cond. No.                     1.45e+03
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 1.45e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# EUIwn ~ PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + Easements + NumFloors + I1 + I9 + D4 + K6 + D1 + I6 + K1 + J6 + P7 + R5 + E7 + H2 + K9 + F2 + I5 + H3 + W6 + H1 + H5 + O1 + E1 + F1 + H9 + E9 + J8 + O6 + G1 + F9 + J4 + K2 + I2 + F4 + P5 + N2 + D0 + I3 + L1 + W5 + P6 + E3 + W7 + C6 + J5
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.390
# Model:                            OLS   Adj. R-squared:                  0.387
# Method:                 Least Squares   F-statistic:                     136.7
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):               0.00
# Time:                        02:48:22   Log-Likelihood:                -59970.
# No. Observations:               10532   AIC:                         1.200e+05
# Df Residuals:                   10482   BIC:                         1.204e+05
# Df Model:                          49
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       117.5778      1.728     68.043      0.000       114.191   120.965
# PerOfficeArea    68.0182      3.002     22.658      0.000        62.134    73.902
# PerOtherArea     26.8755      4.500      5.973      0.000        18.055    35.696
# PerRetailArea    57.7764      8.583      6.732      0.000        40.953    74.600
# PerGarageArea    27.4818     12.727      2.159      0.031         2.534    52.430
# Easements        18.1295      3.032      5.980      0.000        12.187    24.072
# NumFloors         1.3871      0.090     15.350      0.000         1.210     1.564
# I1              342.5107      9.844     34.794      0.000       323.215   361.807
# I9              291.8375     13.132     22.223      0.000       266.096   317.579
# D4              -16.6139      1.969     -8.436      0.000       -20.474   -12.754
# K6              156.6447     11.289     13.876      0.000       134.516   178.773
# D1               -6.6536      2.129     -3.125      0.002       -10.828    -2.479
# I6              126.6434      8.757     14.461      0.000       109.477   143.810
# K1              167.9194     15.450     10.869      0.000       137.634   198.204
# J6              266.7804     22.958     11.620      0.000       221.777   311.783
# P7              388.6932     32.420     11.989      0.000       325.145   452.242
# R5               29.4497      6.870      4.287      0.000        15.983    42.916
# E7              -74.4220      7.984     -9.321      0.000       -90.073   -58.771
# H2               94.7233     12.013      7.885      0.000        71.175   118.271
# K9               74.9102     11.262      6.652      0.000        52.834    96.986
# F2              238.2363     24.073      9.897      0.000       191.049   285.423
# I5              152.2262     20.161      7.551      0.000       112.707   191.745
# H3               77.9252     12.082      6.450      0.000        54.243   101.608
# W6               31.9724      8.883      3.599      0.000        14.559    49.386
# H1              104.8973     17.500      5.994      0.000        70.595   139.200
# H5              198.6163     32.506      6.110      0.000       134.898   262.335
# O1               21.8501     10.413      2.098      0.036         1.439    42.261
# E1              -33.7770      8.413     -4.015      0.000       -50.269   -17.285
# F1              -43.3613     10.009     -4.332      0.000       -62.980   -23.743
# H9               51.1616     12.224      4.185      0.000        27.200    75.124
# E9              -38.5752     10.007     -3.855      0.000       -58.192   -18.959
# J8              137.4162     27.508      4.995      0.000        83.495   191.337
# O6              147.4353     36.124      4.081      0.000        76.626   218.245
# G1               70.5464     19.904      3.544      0.000        31.532   109.561
# F9              -44.9891     13.026     -3.454      0.001       -70.522   -19.456
# J4              225.9463     51.055      4.426      0.000       125.869   326.023
# K2               61.3599     19.353      3.171      0.002        23.424    99.296
# I2              327.6759     72.186      4.539      0.000       186.178   469.174
# F4               85.4545     13.953      6.124      0.000        58.104   112.805
# P5              171.2293     41.697      4.107      0.000        89.496   252.963
# N2               38.5558     10.676      3.612      0.000        17.629    59.482
# D0              -33.0806      9.888     -3.345      0.001       -52.464   -13.697
# I3              151.2776     42.030      3.599      0.000        68.891   233.664
# L1              -33.2816      6.173     -5.391      0.000       -45.382   -21.181
# W5              123.2993     41.717      2.956      0.003        41.525   205.074
# P6              160.9697     51.133      3.148      0.002        60.740   261.199
# E3              -29.7707     15.807     -1.883      0.060       -60.755     1.213
# W7               72.5693     27.496      2.639      0.008        18.672   126.467
# C6               46.0058      7.053      6.523      0.000        32.180    59.831
# J5              125.7748     51.095      2.462      0.014        25.618   225.932
# ==============================================================================
# Omnibus:                     5782.531   Durbin-Watson:                   1.839
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           145960.652
# Skew:                           2.130   Prob(JB):                         0.00
# Kurtosis:                      20.733   Cond. No.                     1.45e+03
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 1.45e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# EUIwn ~ PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + Easements + NumFloors + I1 + I9 + D4 + K6 + D1 + I6 + K1 + J6 + P7 + R5 + E7 + H2 + K9 + F2 + I5 + H3 + W6 + H1 + H5 + O1 + E1 + F1 + H9 + E9 + J8 + O6 + G1 + F9 + J4 + K2 + I2 + F4 + P5 + N2 + D0 + I3 + L1 + W5 + P6 + E3 + W7 + C6 + J5 + P3
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.390
# Model:                            OLS   Adj. R-squared:                  0.387
# Method:                 Least Squares   F-statistic:                     134.1
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):               0.00
# Time:                        02:48:22   Log-Likelihood:                -59967.
# No. Observations:               10532   AIC:                         1.200e+05
# Df Residuals:                   10481   BIC:                         1.204e+05
# Df Model:                          50
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       117.5364      1.728     68.026      0.000       114.150   120.923
# PerOfficeArea    67.8361      3.003     22.593      0.000        61.951    73.722
# PerOtherArea     25.6078      4.537      5.644      0.000        16.714    34.502
# PerRetailArea    57.7616      8.581      6.731      0.000        40.941    74.583
# PerGarageArea    27.4694     12.725      2.159      0.031         2.526    52.413
# Easements        18.1595      3.031      5.991      0.000        12.218    24.101
# NumFloors         1.3908      0.090     15.391      0.000         1.214     1.568
# I1              343.4636      9.852     34.861      0.000       324.151   362.776
# I9              292.7658     13.137     22.286      0.000       267.015   318.517
# D4              -16.6124      1.969     -8.437      0.000       -20.472   -12.753
# K6              156.7303     11.287     13.886      0.000       134.605   178.855
# D1               -6.6344      2.129     -3.116      0.002       -10.808    -2.461
# I6              127.7365      8.771     14.564      0.000       110.544   144.929
# K1              168.0115     15.447     10.876      0.000       137.732   198.291
# J6              267.5592     22.957     11.655      0.000       222.558   312.560
# P7              389.7523     32.418     12.023      0.000       326.207   453.297
# R5               29.7464      6.870      4.330      0.000        16.280    43.213
# E7              -74.3706      7.983     -9.316      0.000       -90.019   -58.722
# H2               95.8682     12.023      7.974      0.000        72.301   119.435
# K9               75.1535     11.261      6.674      0.000        53.080    97.227
# F2              238.2788     24.069      9.900      0.000       191.100   285.458
# I5              152.8853     20.160      7.584      0.000       113.369   192.402
# H3               79.0807     12.092      6.540      0.000        55.379   102.783
# W6               32.9806      8.894      3.708      0.000        15.546    50.415
# H1              106.0988     17.505      6.061      0.000        71.785   140.413
# H5              199.8647     32.506      6.149      0.000       136.147   263.582
# O1               22.0508     10.411      2.118      0.034         1.642    42.459
# E1              -33.7283      8.412     -4.010      0.000       -50.217   -17.240
# F1              -43.3154     10.007     -4.329      0.000       -62.931   -23.700
# H9               52.3467     12.235      4.279      0.000        28.364    76.329
# E9              -38.5220     10.006     -3.850      0.000       -58.135   -18.909
# J8              138.3792     27.507      5.031      0.000        84.460   192.298
# O6              147.6151     36.118      4.087      0.000        76.817   218.413
# G1               70.5759     19.900      3.547      0.000        31.568   109.584
# F9              -44.9477     13.024     -3.451      0.001       -70.477   -19.419
# J4              226.8908     51.048      4.445      0.000       126.828   326.954
# K2               61.4898     19.350      3.178      0.001        23.561    99.419
# I2              328.9482     72.176      4.558      0.000       187.470   470.426
# F4               85.4981     13.951      6.129      0.000        58.152   112.844
# P5              171.9540     41.691      4.124      0.000        90.232   253.676
# N2               39.5957     10.685      3.706      0.000        18.651    60.540
# D0              -33.0591      9.887     -3.344      0.001       -52.439   -13.679
# I3              152.0010     42.024      3.617      0.000        69.626   234.376
# L1              -33.2375      6.172     -5.385      0.000       -45.336   -21.139
# W5              124.2085     41.712      2.978      0.003        42.444   205.973
# P6              161.5850     51.125      3.161      0.002        61.371   261.799
# E3              -29.7286     15.804     -1.881      0.060       -60.707     1.250
# W7               73.6988     27.496      2.680      0.007        19.801   127.597
# C6               46.0376      7.052      6.528      0.000        32.215    59.861
# J5              126.8643     51.089      2.483      0.013        26.720   227.009
# P3               59.0971     27.494      2.149      0.032         5.204   112.990
# ==============================================================================
# Omnibus:                     5787.903   Durbin-Watson:                   1.838
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           146472.993
# Skew:                           2.132   Prob(JB):                         0.00
# Kurtosis:                      20.765   Cond. No.                     1.45e+03
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 1.45e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ###The best regression so far before we start to have multicolinearity issues

# %%
# The best regression so far before we start to have multicolinearity issues
continuous_features = ['PerOfficeArea',
                       'PerOtherArea',
                       'PerRetailArea',
                       'PerGarageArea',
                       'Easements',
                       'NumFloors',]

dummies = ['I1',
 'I9',
 'D4',
 'K6',
 'D1',
 'I6',
 'K1',
 'J6',
 'P7',
 'R5',
 'E7',
 'H2',
 'K9',
 'F2',
 'I5',
 'H3',
 'W6',
 'H1',
 'H5',
 'O1',
 'E1',
 'F1',
 'H9',
 'E9',
 'J8',
 'O6',
 'G1',
 'F9']

print lm.smf_linear(continuous_features + dummies,
                    'EUIwn',bd_train.join(X)).summary()
# Out:
# EUIwn ~ PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + Easements + NumFloors + I1 + I9 + D4 + K6 + D1 + I6 + K1 + J6 + P7 + R5 + E7 + H2 + K9 + F2 + I5 + H3 + W6 + H1 + H5 + O1 + E1 + F1 + H9 + E9 + J8 + O6 + G1 + F9
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.359
# Model:                            OLS   Adj. R-squared:                  0.356
# Method:                 Least Squares   F-statistic:                     111.5
# Date:                Wed, 18 Mar 2015   Prob (F-statistic):               0.00
# Time:                        17:30:08   Log-Likelihood:                -38881.
# No. Observations:                6811   AIC:                         7.783e+04
# Df Residuals:                    6776   BIC:                         7.807e+04
# Df Model:                          34
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       119.5677      2.098     56.999      0.000       115.455   123.680
# PerOfficeArea    66.9291      3.782     17.697      0.000        59.515    74.343
# PerOtherArea     39.5388      5.277      7.493      0.000        29.194    49.883
# PerRetailArea    48.5308     10.524      4.612      0.000        27.901    69.161
# PerGarageArea    46.2411     16.258      2.844      0.004        14.371    78.111
# Easements        15.8513      5.595      2.833      0.005         4.884    26.818
# NumFloors         1.2730      0.113     11.266      0.000         1.051     1.494
# I1              350.1366     13.971     25.061      0.000       322.748   377.525
# I9              291.6611     20.526     14.209      0.000       251.424   331.898
# D4              -18.0022      2.448     -7.353      0.000       -22.802   -13.203
# K6              182.8035     17.481     10.457      0.000       148.536   217.071
# D1               -6.6056      2.605     -2.536      0.011       -11.711    -1.500
# I6              124.7242     10.871     11.473      0.000       103.414   146.035
# K1              124.3322     20.583      6.041      0.000        83.983   164.681
# J6              288.0945     24.586     11.718      0.000       239.898   336.291
# P7              366.4253     36.773      9.965      0.000       294.339   438.512
# R5               41.5235      9.042      4.592      0.000        23.798    59.249
# E7              -76.6678      9.917     -7.731      0.000       -96.108   -57.227
# H2               75.6515     14.492      5.220      0.000        47.243   104.060
# K9               88.5713     13.663      6.483      0.000        61.788   115.354
# F2              297.7635     27.713     10.744      0.000       243.437   352.090
# I5              157.7802     22.266      7.086      0.000       114.132   201.429
# H3               70.4994     15.356      4.591      0.000        40.397   100.602
# W6                3.3988     13.771      0.247      0.805       -23.597    30.395
# H1               94.2724     20.882      4.514      0.000        53.336   135.209
# H5              185.9406     33.090      5.619      0.000       121.073   250.808
# O1               31.9427     14.994      2.130      0.033         2.550    61.335
# E1              -34.2543     11.595     -2.954      0.003       -56.985   -11.524
# F1              -46.7976     12.860     -3.639      0.000       -72.008   -21.587
# H9               46.0177     14.872      3.094      0.002        16.863    75.172
# E9              -50.7298     12.859     -3.945      0.000       -75.937   -25.523
# J8              111.1725     33.054      3.363      0.001        46.376   175.969
# O6              143.0251     51.820      2.760      0.006        41.443   244.608
# G1               97.2183     25.589      3.799      0.000        47.056   147.381
# F9              -56.6767     14.451     -3.922      0.000       -85.006   -28.347
# ==============================================================================
# Omnibus:                     4195.869   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           129991.633
# Skew:                           2.436   Prob(JB):                         0.00
# Kurtosis:                      23.840   Cond. No.                         826.
# ==============================================================================

# %%
X = pd.concat([X, bd], axis=1)
reg = linear_model.LinearRegression()
reg.fit(X[curr_features], bd[['EUIwn']])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, normalize=False)

# %%
A = pd.get_dummies(bd[pluto_class_dummies[0]])
B = bd

print "The two DataFrames have the same index: " + str(list(A.index) == list(bd.index))
print "Observations in A: " + str(len(A))
print "Observations in B: " + str(len(B))
print "Observations in A join B: " + str(len(B.join(A)))
print "Observations in A concat B: " + str(len(pd.concat([A, bd[['EUIwn']]], axis=1)))
# Out:
# The two DataFrames have the same index: True
# Observations in A: 10532
# Observations in B: 10532
# Observations in A join B: 12564
# Observations in A concat B: 10532

# %%
y_predict = reg.predict(X[curr_features])
y_true = bd[['EUIwn']]
print metrics.r2_score(y_true, y_predict)
plt.scatter(bd[['EUIwn']], y_predict - y_true)

# %%
metrics.r2_score(y_true, y_predict)
# Out:
# 0.3772793765428597

# %%
plt.scatter(bd[['EUIwn']], y_predict - y_true)

# %%
curr_features = ['PerOfficeArea',
 'PerOtherArea',
 'PerRetailArea',
 'PerGarageArea',
 'Easements',
 'NumBldgs',
 'NumFloors','YearLastWork',]

reg = linear_model.LinearRegression()
y = bd.EUIwn
reg.fit(bd[curr_features], y)

y_predict = reg.predict(bd[curr_features])
y_true = y
print metrics.r2_score(y_true, y_predict)
plt.scatter(bd[['EUIwn']], y_predict - y_true)
# Out:
# 0.245128684797

# %%
y = -1 * bd.EUIwn

# %%
' + I1 + I9 + D4 + K6 + D1 + I6 + K1 + J6 + P7 + R5 + E7 + H2 + K9 + F2 + I5 + H3 + W6 + H1 + H5 + O1 + E1 + F1 + H9 + E9 + J8 + O6 + G1 + F9'.split(' + ')
# Out:
# ['',
#  'I1',
#  'I9',
#  'D4',
#  'K6',
#  'D1',
#  'I6',
#  'K1',
#  'J6',
#  'P7',
#  'R5',
#  'E7',
#  'H2',
#  'K9',
#  'F2',
#  'I5',
#  'H3',
#  'W6',
#  'H1',
#  'H5',
#  'O1',
#  'E1',
#  'F1',
#  'H9',
#  'E9',
#  'J8',
#  'O6',
#  'G1',
#  'F9']
