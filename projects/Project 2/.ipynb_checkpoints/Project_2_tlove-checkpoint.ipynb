# %%
# %pylab inline
import pandas as pd
import seaborn as sns
from __future__ import division
import datetime
sns.set_style('white')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# #Project 2 - Predicting Large Building Energy Intensity in NYC
#
# *Author:* Theodore Love
#
# *Date:* March 16, 2015
#
# **Contents**
# 1. Overview of Data Collected in Project 1
# 2. Exploring New Data Sets
# 3. Combining Data Sets

# %% [markdown]
# ## 1. Overview of Data Collected in Project 1

# %% [markdown]
# This analysis is primarily based on data relating to [NYC Local Law 84](http://www.nyc.gov/html/gbee/html/plan/ll84.shtml), which requires private sector buildings that are larger than 50,000 square feet, and two or more private sector buildings on a single lot that are larger than 100,000 square feet, to provide annual data on energy and water consumption. Significant analysis has been done on this data set and presented in a [series of reports](http://www.nyc.gov/html/gbee/html/plan/ll84_scores.shtml). This analysis attempts to extend this previous work.
#
# The original data covers five basic categories of information:
# * Building Location (borough/block/lot, address, etc.)
# * Building Info (building type, square footage, id, etc.)
# * Energy Usage (gross kBTUs/ft2, weather normalized kBTUs/ft2, ENERGY STAR score)
# * Water Usage per ft2 (along with source)
# * GHG Emissions (calculated from kBtu/ft2 and a coefficient estimate)
#
# All of this data is sourced from [NYC Open Data](https://nycopendata.socrata.com/), and has both zip code and borough/block/lot information, which makes for a good way to work in other data sets.
#
# **Data Sets Used in Project 1**
#
# |Name | Source |
# |---| --- |
# |Local Law 84 Disclosures (2011) | [Source](https://data.cityofnewyork.us/Environment/Energy-and-Water-Data-Disclosure-for-Local-Law-84-/q39e-7gbs)|
# |Local Law 84 Disclosures (2012 | [Source](https://data.cityofnewyork.us/Environment/Energy-and-Water-Data-Disclosure-for-Local-Law-84-/5gde-fmj3)|
#
# **Data for Project 2**
#
# In order to keep this project's analysis to a more manageable scope, we will **only look at data for 2012**, which was both more comprehensive and had less issues than 2011 data. This also allows us to establish **BBL** as a a unique key (with a little bit of wrangling).

# %% [markdown]
# ## 2. Exploring New Data Sets

# %% [markdown]
# Since the data sets used in this next section were too large to upload to github, I have them saved in a local directory. Source links for each data set are in the descriptions below.
#
# ####*NOTE: The full cleaned and merged data set is stored in this same directory, skip to the beginning of Section 4 to import it without processing other data*

# %%
data_folder = '/Users/Theo/Dropbox (Personal)/ProgrammingProjects/GADSdata'

# %% [markdown]
# ####NYC PLUTO Data
#
# NYC maintains extensive land use and geographic data at the tax lot level in their Primary Land Use Tax Lot Output database ([PLUTO](http://www.nyc.gov/html/dcp/html/bytes/dwn_pluto_mappluto.shtml)). NYC maintains [historical PLUTO data](http://www.nyc.gov/html/dcp/html/bytes/archive_pluto_mappluto.shtml) back to 2002, and for this analysis, the latest 2012 data (v2) is used, in order to align as closely as possible with the timing of the Local Law 84 data from 2012.

# %%
"""
2012 PLUTO data is saved by borough, so each is imported separately and then combined
 - Skip blank line at bottom
 - Skip leading spaces
 - BBL is a unique key
"""

# Manhattan
mn = pd.read_csv(data_folder + '/nyc_pluto_12v2/mn12v2.txt', 
                 skipfooter=1,
                 engine="python",
                 skipinitialspace=True,
                 )

# Bronx
bx = pd.read_csv(data_folder + '/nyc_pluto_12v2/bx12v2.txt',
                 skipfooter=1,
                 engine="python",
                 skipinitialspace=True,
                 )

# Brooklyn
bk = pd.read_csv(data_folder + '/nyc_pluto_12v2/bk12v2.txt',
                 skipfooter=1,
                 engine="python",
                 skipinitialspace=True,
                 )

# Queens
qn = pd.read_csv(data_folder + '/nyc_pluto_12v2/qn12v2.txt',
                 skipfooter=1,
                 engine="python",
                 skipinitialspace=True,
                 )

# Staten Island
si = pd.read_csv(data_folder + '/nyc_pluto_12v2/si12v2.txt',
                 skipfooter=1,
                 engine="python",
                 skipinitialspace=True,
                 )

# Combine and set BBL as the index (already checked for uniqueness)
pluto = pd.concat([mn,bx,bk,qn,si], axis=0)
pluto.describe()
# Out:
#                Block            Lot             CD        Council  \
# count  859324.000000  859324.000000  859324.000000  855398.000000
# mean     5301.815771     125.284543     354.036419      32.030069
# std      3695.489329     712.010049     101.004411      13.215942
# min         0.000000       0.000000     101.000000       0.000000
# 25%      2298.000000      19.000000     306.000000      22.000000
# 50%      4803.000000      38.000000     401.000000      32.000000
# 75%      7456.000000      64.000000     412.000000      44.000000
# max     16350.000000    9978.000000     595.000000      51.000000
#
#           PolicePrct      Easements       LotArea         BldgArea  \
# count  855388.000000  859324.000000  8.593240e+05    859324.000000
# mean       86.806960       0.005074  7.867791e+03      6313.022123
# std        29.413449       0.083615  3.703630e+05     66822.328779
# min         1.000000       0.000000  0.000000e+00         0.000000
# 25%        66.000000       0.000000  2.000000e+03      1440.000000
# 50%       102.000000       0.000000  2.513000e+03      2088.000000
# 75%       111.000000       0.000000  4.000000e+03      3120.000000
# max       123.000000      13.000000  2.147557e+08  27600000.000000
#
#                ComArea          ResArea       ...              BuiltFAR  \
# count    859324.000000    859324.000000       ...         859324.000000
# mean       2228.923938      4082.527828       ...              1.140965
# std       59277.914889     29323.434469       ...             12.595126
# min           0.000000         0.000000       ...              0.000000
# 25%           0.000000      1281.000000       ...              0.480000
# 50%           0.000000      1898.000000       ...              0.780000
# 75%           0.000000      2763.000000       ...              1.280000
# max    27600000.000000  13211398.000000       ...           6088.800000
#
#           MaxAllwFAR       BoroCode           BBL        CondoNo  \
# count  859324.000000  859324.000000  8.593240e+05  859324.000000
# mean        1.446861       3.459120  3.512138e+09       8.970288
# std         1.468102       1.023812  1.031994e+09     127.951807
# min         0.000000       1.000000  1.000010e+09       0.000000
# 25%         0.600000       3.000000  3.030790e+09       0.000000
# 50%         0.900000       4.000000  4.008320e+09       0.000000
# 75%         2.000000       4.000000  4.106040e+09       0.000000
# max        15.000000       5.000000  5.080500e+09    9566.000000
#
#            Tract2010          XCoord         YCoord        APPBBL  \
# count  859324.000000   829419.000000  829419.000000  8.581930e+05
# mean     9232.698645  1006257.479815  191689.518341  3.538946e+08
# std     26256.936042    32217.315934   30463.493201  1.162034e+09
# min         0.000000   913236.000000  120308.000000  0.000000e+00
# 25%       206.000000   989615.500000  168454.000000  0.000000e+00
# 50%       484.000000  1008653.000000  189303.000000  0.000000e+00
# 75%      1116.000000  1028971.000000  211104.000000  0.000000e+00
# max    157903.000000  1067277.000000  272316.000000  5.080480e+09
#
#           PLUTOMapID
# count  859324.000000
# mean        1.004698
# std         0.093883
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         5.000000
#
# [8 rows x 42 columns]

# %% [markdown]
# ####Housing Code Violations
#
# [Housing code violations](https://data.cityofnewyork.us/Housing-Development/Housing-Maintenance-Code-Violations/wvxf-dwi5) may have some predictive power for **Multifamily** buildings, and are available by BBL.
#
# In order to make the data as relevant as possible to 2012, only violations that were observed in 2012 will be used (i.e. **InspectionDate** has the year 2012).
#
# The data is by unique violation, so some aggregation is necessary. Each violation has a text description, which may be interesting to examine later, but for now the pertinant field will be **OrderNumber**, which corresponds to the law which is being violated.
#
# After filtering and aggregating, we have a dataframe that, for each **BBL**, provides a count of violations observed in 2012 for each **OrderNumber**.

# %%
# import the data and create a bbl field
hmcv = pd.read_csv(data_folder + "/housing_maint_violations/Housing_Maintenance_Code_Violations.csv", low_memory=False)
hmcv['bbl'] = hmcv.BoroID.map(str) + \
              hmcv.Block.apply(lambda x: str(x).zfill(5)) + \
              hmcv.Lot.apply(lambda x: str(x).zfill(4))
hmcv.bbl = hmcv.bbl.map(int)

# convert the InspectionDate to a datetime field and extract a new column for year
hmcv.InspectionDate = pd.to_datetime(hmcv.InspectionDate)
hmcv['InspectionYear'] = hmcv.InspectionDate.apply(lambda x: x.year)

# get the count of each OrderNum by BBL in 2012 and make a sum of violations feature
hmcv_2012 = pd.pivot_table(hmcv[hmcv.InspectionYear == 2012][['bbl','OrderNumber']],
                           values=['OrderNumber'],
                           index=['bbl'],
                           columns=['OrderNumber'],
                           aggfunc=len,
                           fill_value=0)
hmcv_2012.columns = 'hmcv_num_' + hmcv_2012.columns.map(str)
hmcv_2012['violations'] = hmcv_2012.sum(axis=1)
hmcv_2012.describe()
# Out:
#         hmcv_num_4   hmcv_num_8  hmcv_num_84  hmcv_num_106  hmcv_num_109  \
# count  2760.000000  2760.000000  2760.000000   2760.000000   2760.000000
# mean      0.002536     0.000362     0.000362      0.009783      0.002536
# std       0.063091     0.019035     0.019035      0.115390      0.073691
# min       0.000000     0.000000     0.000000      0.000000      0.000000
# 25%       0.000000     0.000000     0.000000      0.000000      0.000000
# 50%       0.000000     0.000000     0.000000      0.000000      0.000000
# 75%       0.000000     0.000000     0.000000      0.000000      0.000000
# max       2.000000     1.000000     1.000000      3.000000      3.000000
#
#        hmcv_num_118  hmcv_num_176  hmcv_num_188  hmcv_num_209  hmcv_num_483  \
# count   2760.000000   2760.000000   2760.000000   2760.000000   2760.000000
# mean       0.000362      0.000725      0.002174      0.000725      0.001449
# std        0.019035      0.026914      0.046583      0.026914      0.038049
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#            ...       hmcv_num_1042  hmcv_num_1051  hmcv_num_1061  \
# count      ...         2760.000000    2760.000000    2760.000000
# mean       ...            0.008333       0.000362       0.005072
# std        ...            0.143493       0.019035       0.080612
# min        ...            0.000000       0.000000       0.000000
# 25%        ...            0.000000       0.000000       0.000000
# 50%        ...            0.000000       0.000000       0.000000
# 75%        ...            0.000000       0.000000       0.000000
# max        ...            4.000000       1.000000       2.000000
#
#        hmcv_num_1067  hmcv_num_1492  hmcv_num_1493  hmcv_num_1501  \
# count    2760.000000    2760.000000    2760.000000    2760.000000
# mean        0.002174       0.000362       0.001812       0.007971
# std         0.065914       0.019035       0.042532       0.092926
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         3.000000       1.000000       1.000000       2.000000
#
#        hmcv_num_1502  hmcv_num_1503   violations
# count    2760.000000    2760.000000  2760.000000
# mean        0.307246       0.165580     8.538406
# std         0.827108       0.552214    14.117484
# min         0.000000       0.000000     1.000000
# 25%         0.000000       0.000000     2.000000
# 50%         0.000000       0.000000     4.000000
# 75%         0.000000       0.000000    10.000000
# max        14.000000       6.000000   293.000000
#
# [8 rows x 178 columns]

# %% [markdown]
# ##3. Combining Data Sets
#
# **Local Law 84 Data**
#
# We will only look at 2012 data for this project, and will start by importing the 2012 Local Law 84 data and cleaning it the same way we did in Project 1, but without creating any variables.

# %%
# import and rename columns
buildings = pd.read_csv(data_folder +  '/Energy_and_Water_Data_Disclosure_for_Local_Law_84__2012.csv')
buildings.columns = "bbl st_no st_name borough zip bench_sub entry_no EUI EUIwn water_ft2 \
            water_method energy_star GHG floor_area property_type no_buildings reported_BINS".split()
buildings.ix[buildings['energy_star'] == 'Exempt', 'energy_star'] = np.NaN

# Remove the anomalies the same was as in Project 1
curr = len(buildings)
print "Anomalies"
print "========="
print "Starting observations: %i" % curr

buildings = buildings[pd.notnull(buildings['EUIwn'])]
print "Missing EUIwn: %i" % (curr - len(buildings))
curr = len(buildings)

buildings = buildings[buildings['EUI'] > 0]
print "EUI of 0: %i" % (curr - len(buildings))
curr = len(buildings)

buildings = buildings[buildings['EUIwn'] >= 5]
print "EUIwn < 5: %i" % (curr - len(buildings))
curr = len(buildings)

buildings = buildings[buildings['EUIwn'] <= 1000]
print "EUIwn > 1,000: %i" % (curr - len(buildings))
curr = len(buildings)

buildings = buildings[buildings['floor_area'] >= 25000]
print "floor area < 25k ft2: %i" % (curr - len(buildings))
curr = len(buildings)

buildings = buildings[pd.notnull(buildings['GHG'])]
print "Missing GHG: %i" % (curr - len(buildings))
curr = len(buildings)

print "Water per ft2 > 100: %i (kept observation)" % len(buildings[buildings['water_ft2'] > 100])  
buildings['water_ft2'] = buildings['water_ft2'].apply(lambda x: np.NaN if x > 100 else x)

print "Remaining observations: %i" % len(buildings)
buildings = buildings.set_index('bbl')
# Out:
# Anomalies
# =========
# Starting observations: 14112
# Missing EUIwn: 3041
# EUI of 0: 67
# EUIwn < 5: 52
# EUIwn > 1,000: 110
# floor area < 25k ft2: 273
# Missing GHG: 37
# Water per ft2 > 100: 480 (kept observation)
# Remaining observations: 10532

# %% [markdown]
# **Merge in New Data**
#
# Merge in the *pluto* and *hmcv_2012* data on **bbl**.

# %%
print "Buildings imported: %i features and %i observations." % (len(buildings.columns), len(buildings))

# merge in the housing maintenance code violations
bd = buildings.join(hmcv_2012)
print "Code Violation data merged: %i features and %i observations." % (len(bd.columns), len(bd))

# merge in the PLUTO data
bd = bd.merge(pluto, how='left', left_index=True, right_on=['BBL'])
print "Pluto data merged: %i features and %i observations." % (len(bd.columns), len(bd))

bd = bd.set_index(bd.BBL)
# Out:
# Buildings imported: 16 features and 10532 observations.
# Code Violation data merged: 194 features and 10532 observations.
# Pluto data merged: 274 features and 10532 observations.

# %% [markdown]
# **New Variables and Relevant Feature Lists**
#
# Create some new variables and lists for each different kind of feature that we want to explore in our supervised machine learning. Put the features in to three general categories
#
# > **Targets**: variables to predict
#
# > **Class Dummies**: classification columns that need to be made in to dummy columns (ignored until later)
#
# > **Class**: classification columns that are already True/False
#
# > **Cont**: continuous variables

# %%
"""
ORIGINAL DATA
"""
# original data set features that could be relevent
targets = ['EUIwn', 'EUI']
orig_class_dummies = [u'borough', u'zip', u'property_type',]
orig_class = [u'water_method']
orig_cont = [u'water_ft2', u'energy_star', u'GHG', u'floor_area', u'no_buildings',]

# normalize EUIwn
bd['EUIwn_norm'] = bd.EUIwn.apply(lambda x: (x - bd.EUIwn.min())/ (bd.EUIwn.max() - bd.EUIwn.min()))

"""
PLUTO DATA
"""
# PLUTO data set features that could be relevant. 
pluto_class_dummies = [u'BldgClass', u'LandUse', u'OwnerType', u'AreaSource', u'Ext', \
                       u'ProxCode', u'IrrLotCode', u'LotType', u'BsmtCode']
pluto_class = []
pluto_cont = [u'Easements', u'LotArea', u'BldgArea', u'ComArea', u'ResArea', u'OfficeArea', \
              u'RetailArea', u'GarageArea', u'StrgeArea', u'FactryArea', u'OtherArea', \
              u'NumBldgs', u'NumFloors', u'UnitsRes', u'UnitsTotal', u'LotFront', u'LotDepth', \
              u'BldgFront', u'BldgDepth', u'AssessLand', u'AssessTot', u'ExemptLand', u'ExemptTot', \
              u'BuiltFAR', u'MaxAllwFAR']

# Make a dummy field for if the BBL has a Landmark
bd['Landmarked'] = bd.Landmark.apply(lambda x: 0 if x == (' ' * 35) else 1)
pluto_class.append('Landmarked')

# convert BuiltCode to a dummy of 1 means year built is an estimate
bd.BuiltCode = bd.BuiltCode.apply(lambda x: 1 if x == 'E' else 0)
pluto_class.append('BuiltCode')

# convert the 9 observations with year built of 0 to the mean of year built and make BuiltCode true
bd.ix[bd.YearBuilt == 0, 'BuiltCode'] = 1
bd.ix[bd.YearBuilt == 0, 'YearBuilt'] = bd.YearBuilt.mean()
pluto_cont.append('YearBuilt')

# latest year work was done
bd['YearLastWork'] = bd[['YearBuilt','YearAlter1','YearAlter2']].max(axis=1)
pluto_cont.append('YearLastWork')

# dummy for if alterations ever occured
bd['Altered'] = (bd.YearAlter1 > 0)
pluto_class.append('Altered')

# lot area percentages
bd.ix[bd.BldgArea == 0, ['BldgArea']] = 1 # Six BBLs have an area of 0, so change to 1 for purposes of division
area_types = [u'ComArea', u'ResArea', u'OfficeArea', u'RetailArea', u'GarageArea', u'StrgeArea', u'FactryArea', u'OtherArea',]
for a in area_types:
    col = 'Per'+ a
    bd[col] = bd[a] / bd['BldgArea']
    pluto_cont.append(col)
    
"""
HMCV DATA
"""
hmcv_class_dummies = []
hmcv_class = []
hmcv_cont = list(hmcv_2012.columns)

# fill in the missing values with 0 and drop any columns that don't have any values
bd[list(hmcv_2012.columns)] = bd[list(hmcv_2012.columns)].fillna(0)
bd_sum = bd[list(hmcv_2012.columns)].sum()
no_violations = list(bd_sum[bd_sum == 0].index)
hmcv_cont = [x for x in hmcv_cont if x not in no_violations]
bd.drop(labels=no_violations, axis=1, inplace=True)

"""
COMBINED FEATURES
"""
all_class_dummies = orig_class_dummies + pluto_class_dummies + hmcv_class_dummies
all_class = orig_class + pluto_class + hmcv_class
all_cont = orig_cont + pluto_cont + hmcv_cont

# %% [markdown]
# #4. Predicting High Intensity Users

# %% [markdown]
# Let's see if we can predict the EUIwn based on the separate PLUTO and Code Violation data

# %%
# import the custom machine learning helper functions that are in a separate module
import mltl

# %% [markdown]
# ### Target Variable: Weather-normalized Energy Usage Intensity (EUIwn)

# %%
plt.figure(figsize=(12,6))
plt.subplot(121)
bd.EUIwn.hist()
plt.subplot(122)
log(bd.EUIwn).hist()

# %% [markdown]
# ###Initial selection of Continuous Variables
#
# Let's test out the continuous variables in a linear regression to see if anything sticks out

# %%
# create the X and the y
features = pluto_cont + hmcv_cont
X = bd[features]
y = bd[['EUIwn']]

# use the f_test from our linear regression helper class to see what was significant at the 95% confidence interval
lm = mltl.Linear()
linear_results = lm.f_test(X, y, ci=0.95)
print "%i of %i features passed (%0.1f percent)" % (len(linear_results), len(features), 100*len(linear_results)/len(features))
linear_results.sort('r2', ascending=False)
# Out:
# 34 of 116 features passed (29.3 percent)
#         F score        feature        p-value        r2
# 26  1749.962531     PerComArea   0.000000e+00  0.142506
# 27  1209.274401     PerResArea  6.428154e-251  0.103011
# 20  1163.123336      AssessTot  6.647013e-242  0.099471
# 28   936.194893  PerOfficeArea  4.752672e-197  0.081648
# 19   925.867613     AssessLand  5.489268e-195  0.080820
# 33   892.557935   PerOtherArea  2.541136e-188  0.078140
# 3    881.747460        ComArea  3.736983e-186  0.077267
# 22   735.945571      ExemptTot  1.026343e-156  0.065325
# 5    596.528981     OfficeArea  3.364265e-128  0.053613
# 21   513.869961     ExemptLand  4.053416e-111  0.046530
# 29   501.518835  PerRetailArea  1.484194e-108  0.045462
# 25   387.925844   YearLastWork   7.795344e-85  0.035531
# 2    383.004062       BldgArea   8.423753e-84  0.035096
# 12   361.655746      NumFloors   2.599448e-79  0.033205
# 23   353.548367     MaxAllwFAR   1.325218e-77  0.032485
# 10   311.940110      OtherArea   8.069583e-69  0.028772
# 24   256.940448      YearBuilt   3.771368e-57  0.023820
# 16   193.869983       LotDepth   1.107749e-43  0.018078
# 6    183.087861     RetailArea   2.273303e-41  0.017090
# 15   155.038695       LotFront   2.434099e-35  0.014510
# 1    143.647804        LotArea   6.940212e-33  0.013458
# 7    118.395404     GarageArea   1.987559e-27  0.011119
# 0     75.642817      Easements   3.905040e-18  0.007132
# 31    71.701319   PerStrgeArea   2.836663e-17  0.006763
# 4     68.004031        ResArea   1.825936e-16  0.006417
# 18    62.227809      BldgDepth   3.362579e-15  0.005875
# 17    55.799782      BldgFront   8.660105e-14  0.005271
# 30    43.736614  PerGarageArea   3.938905e-11  0.004136
# 13    41.307632       UnitsRes   1.356855e-10  0.003908
# 14    29.488626     UnitsTotal   5.749615e-08  0.002793
# 32    28.576924  PerFactryArea   9.193146e-08  0.002707
# 8     18.510533      StrgeArea   1.704933e-05  0.001755
# 11    10.195906       NumBldgs   1.411668e-03  0.000967
# 9     10.070724     FactryArea   1.510770e-03  0.000955

# %% [markdown]
# Generally we see that:
# * Looks like the data on usage area by type is doing well, and taking it as a percent of the total is the best. This makes sense given that industry type should be one of the best indicators of EUI. It seems the best split is between the commercial versus residential.
# * Assessed value does well, and so does exempt tax amount
# * YearLastWork does better than YearBuilt (which is good)
# * None of the violation data passed
#
# Let's see where we get with a linear model looking at a selection of these values

# %% [markdown]
# ###Building Area Usage
#
# The initial f-test results show that, as expected, it matters what the building is used for. We also see that looking at usage type as a percentage of total type seemed to have much more better effect, which frees us up to use the total **BldgArea** as a measure of amplitude.
#
# The main split to be expected is the one between residential and commercial, and since they are both the highest explanatory variables on their own, it probably won't help that much to add them together. The difference will probably come from looking at values that effect the extremes (perhaps storage or industrial work).
#
# Let's play the various building area percentage fields and the total area to see what we can come up with.

# %%
# start with building age data
print lm.smf_linear(['PerComArea'],
                    'EUIwn', bd).summary()
# Out:
# EUIwn ~ PerComArea
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.143
# Model:                            OLS   Adj. R-squared:                  0.142
# Method:                 Least Squares   F-statistic:                     1750.
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):               0.00
# Time:                        00:57:21   Log-Likelihood:                -61761.
# No. Observations:               10532   AIC:                         1.235e+05
# Df Residuals:                   10530   BIC:                         1.235e+05
# Df Model:                           1
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    124.4247      0.995    125.038      0.000       122.474   126.375
# PerComArea    84.2451      2.014     41.833      0.000        80.298    88.193
# ==============================================================================
# Omnibus:                     6533.330   Durbin-Watson:                   1.608
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           126668.962
# Skew:                           2.639   Prob(JB):                         0.00
# Kurtosis:                      19.149   Cond. No.                         2.64
# ==============================================================================

# %%
# check to see if building total area helps (it will probably cause multicolinearity issues)
print lm.smf_linear(['PerComArea', 'BldgArea'],
                    'EUIwn', bd).summary()
# Out:
# EUIwn ~ PerComArea + BldgArea
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.158
# Model:                            OLS   Adj. R-squared:                  0.158
# Method:                 Least Squares   F-statistic:                     986.9
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):               0.00
# Time:                        00:57:22   Log-Likelihood:                -61666.
# No. Observations:               10532   AIC:                         1.233e+05
# Df Residuals:                   10529   BIC:                         1.234e+05
# Df Model:                           2
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    119.9745      1.037    115.675      0.000       117.941   122.008
# PerComArea    79.3894      2.026     39.178      0.000        75.417    83.362
# BldgArea    3.129e-05   2.26e-06     13.857      0.000      2.69e-05  3.57e-05
# ==============================================================================
# Omnibus:                     6550.968   Durbin-Watson:                   1.640
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           133690.656
# Skew:                           2.630   Prob(JB):                         0.00
# Kurtosis:                      19.643   Cond. No.                     1.05e+06
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 1.05e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# test if residential adds any value
print lm.smf_linear(['PerComArea', 'PerResArea'],
                    'EUIwn', bd).summary()
# Out:
# EUIwn ~ PerComArea + PerResArea
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.143
# Model:                            OLS   Adj. R-squared:                  0.142
# Method:                 Least Squares   F-statistic:                     875.6
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):               0.00
# Time:                        00:57:22   Log-Likelihood:                -61761.
# No. Observations:               10532   AIC:                         1.235e+05
# Df Residuals:                   10529   BIC:                         1.235e+05
# Df Model:                           2
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    127.8708      3.260     39.222      0.000       121.480   134.261
# PerComArea    80.8444      3.666     22.051      0.000        73.658    88.031
# PerResArea    -3.4558      3.113     -1.110      0.267        -9.559     2.647
# ==============================================================================
# Omnibus:                     6532.576   Durbin-Watson:                   1.608
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           126666.596
# Skew:                           2.639   Prob(JB):                         0.00
# Kurtosis:                      19.149   Cond. No.                         8.67
# ==============================================================================

# %%
# Since residential doesn't, test office
print lm.smf_linear(['PerComArea', 'PerOfficeArea'],
                    'EUIwn', bd).summary()
# Out:
# EUIwn ~ PerComArea + PerOfficeArea
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.148
# Model:                            OLS   Adj. R-squared:                  0.148
# Method:                 Least Squares   F-statistic:                     914.3
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):               0.00
# Time:                        00:57:22   Log-Likelihood:                -61728.
# No. Observations:               10532   AIC:                         1.235e+05
# Df Residuals:                   10529   BIC:                         1.235e+05
# Df Model:                           2
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       124.7025      0.993    125.640      0.000       122.757   126.648
# PerComArea       71.8573      2.510     28.630      0.000        66.938    76.777
# PerOfficeArea    31.1742      3.791      8.223      0.000        23.743    38.605
# ==============================================================================
# Omnibus:                     6677.248   Durbin-Watson:                   1.611
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           129956.671
# Skew:                           2.722   Prob(JB):                         0.00
# Kurtosis:                      19.325   Cond. No.                         5.28
# ==============================================================================

# %%
# See if office and res are a better fit
print lm.smf_linear(['PerResArea', 'PerOfficeArea'],
                    'EUIwn', bd).summary()
# Out:
# EUIwn ~ PerResArea + PerOfficeArea
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.123
# Model:                            OLS   Adj. R-squared:                  0.123
# Method:                 Least Squares   F-statistic:                     738.9
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):          5.12e-301
# Time:                        00:57:23   Log-Likelihood:                -61879.
# No. Observations:               10532   AIC:                         1.238e+05
# Df Residuals:                   10529   BIC:                         1.238e+05
# Df Model:                           2
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       174.5688      1.875     93.090      0.000       170.893   178.245
# PerResArea      -44.8705      2.012    -22.304      0.000       -48.814   -40.927
# PerOfficeArea    55.5469      3.578     15.524      0.000        48.533    62.561
# ==============================================================================
# Omnibus:                     7461.022   Durbin-Watson:                   1.611
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           179936.212
# Skew:                           3.117   Prob(JB):                         0.00
# Kurtosis:                      22.266   Cond. No.                         6.08
# ==============================================================================

# %%
# Res didn't work, so let's try adding more to commercial, first with Other
print lm.smf_linear(['PerComArea', 'PerOfficeArea', 'PerOtherArea'],
                    'EUIwn', bd).summary()
# Out:
# EUIwn ~ PerComArea + PerOfficeArea + PerOtherArea
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.181
# Model:                            OLS   Adj. R-squared:                  0.180
# Method:                 Least Squares   F-statistic:                     773.7
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):               0.00
# Time:                        00:57:23   Log-Likelihood:                -61522.
# No. Observations:               10532   AIC:                         1.231e+05
# Df Residuals:                   10528   BIC:                         1.231e+05
# Df Model:                           3
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       125.6644      0.975    128.952      0.000       123.754   127.575
# PerComArea       28.9360      3.232      8.952      0.000        22.600    35.272
# PerOfficeArea    76.8107      4.334     17.722      0.000        68.315    85.306
# PerOtherArea     92.7852      4.530     20.485      0.000        83.907   101.664
# ==============================================================================
# Omnibus:                     6930.165   Durbin-Watson:                   1.663
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           146307.860
# Skew:                           2.842   Prob(JB):                         0.00
# Kurtosis:                      20.352   Cond. No.                         7.90
# ==============================================================================

# %%
# Now retail
print lm.smf_linear(['PerComArea', 'PerOfficeArea', 'PerOtherArea', 'PerRetailArea'],
                    'EUIwn', bd).summary()
# Out:
# EUIwn ~ PerComArea + PerOfficeArea + PerOtherArea + PerRetailArea
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.219
# Model:                            OLS   Adj. R-squared:                  0.219
# Method:                 Least Squares   F-statistic:                     739.5
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):               0.00
# Time:                        00:57:24   Log-Likelihood:                -61267.
# No. Observations:               10532   AIC:                         1.225e+05
# Df Residuals:                   10527   BIC:                         1.226e+05
# Df Model:                           4
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       124.0401      0.954    130.035      0.000       122.170   125.910
# PerComArea      -12.0262      3.629     -3.314      0.001       -19.139    -4.913
# PerOfficeArea   112.6883      4.513     24.972      0.000       103.843   121.534
# PerOtherArea    133.5299      4.767     28.009      0.000       124.185   142.875
# PerRetailArea   164.1383      7.182     22.853      0.000       150.060   178.217
# ==============================================================================
# Omnibus:                     6976.037   Durbin-Watson:                   1.700
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           159700.345
# Skew:                           2.838   Prob(JB):                         0.00
# Kurtosis:                      21.213   Cond. No.                         11.1
# ==============================================================================

# %%
# Storage (starting to gain less explanitory power)
print lm.smf_linear(['PerComArea', 'PerOfficeArea', 'PerOtherArea', 'PerRetailArea', 'PerStrgeArea ',],
                    'EUIwn', bd).summary()
# Out:
# EUIwn ~ PerComArea + PerOfficeArea + PerOtherArea + PerRetailArea + PerStrgeArea
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.221
# Model:                            OLS   Adj. R-squared:                  0.221
# Method:                 Least Squares   F-statistic:                     598.9
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):               0.00
# Time:                        00:57:24   Log-Likelihood:                -61253.
# No. Observations:               10532   AIC:                         1.225e+05
# Df Residuals:                   10526   BIC:                         1.226e+05
# Df Model:                           5
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       123.8230      0.954    129.858      0.000       121.954   125.692
# PerComArea       11.0927      5.654      1.962      0.050         0.010    22.176
# PerOfficeArea    89.5931      6.253     14.327      0.000        77.335   101.851
# PerOtherArea    110.4455      6.438     17.156      0.000        97.826   123.065
# PerRetailArea   141.2009      8.366     16.878      0.000       124.802   157.600
# PerStrgeArea    -38.2965      7.189     -5.327      0.000       -52.388   -24.205
# ==============================================================================
# Omnibus:                     6913.570   Durbin-Watson:                   1.701
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           156011.444
# Skew:                           2.806   Prob(JB):                         0.00
# Kurtosis:                      21.001   Cond. No.                         17.5
# ==============================================================================

# %%
# Garage (starting to gain less explanitory power)
print lm.smf_linear(['PerComArea', 'PerOfficeArea', 'PerOtherArea', 'PerRetailArea', 'PerStrgeArea ', 'PerGarageArea',],
                    'EUIwn', bd).summary()
# Out:
# EUIwn ~ PerComArea + PerOfficeArea + PerOtherArea + PerRetailArea + PerStrgeArea  + PerGarageArea
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.227
# Model:                            OLS   Adj. R-squared:                  0.226
# Method:                 Least Squares   F-statistic:                     514.2
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):               0.00
# Time:                        00:57:25   Log-Likelihood:                -61217.
# No. Observations:               10532   AIC:                         1.224e+05
# Df Residuals:                   10525   BIC:                         1.225e+05
# Df Model:                           6
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       123.0905      0.954    128.980      0.000       121.220   124.961
# PerComArea      -15.4950      6.458     -2.399      0.016       -28.155    -2.835
# PerOfficeArea   116.5320      7.005     16.636      0.000       102.801   130.263
# PerOtherArea    137.2426      7.161     19.164      0.000       123.205   151.280
# PerRetailArea   165.0937      8.807     18.745      0.000       147.830   182.357
# PerStrgeArea    -10.6819      7.879     -1.356      0.175       -26.126     4.762
# PerGarageArea   107.3787     12.743      8.426      0.000        82.400   132.357
# ==============================================================================
# Omnibus:                     6970.156   Durbin-Watson:                   1.709
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           162072.974
# Skew:                           2.829   Prob(JB):                         0.00
# Kurtosis:                      21.366   Cond. No.                         22.6
# ==============================================================================

# %%
# Garage throws off storage, so let's test with garage and no storage
print lm.smf_linear(['PerComArea', 'PerOfficeArea', 'PerOtherArea', 'PerRetailArea', 'PerGarageArea',],
                    'EUIwn', bd).summary()
# Out:
# EUIwn ~ PerComArea + PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.227
# Model:                            OLS   Adj. R-squared:                  0.226
# Method:                 Least Squares   F-statistic:                     616.6
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):               0.00
# Time:                        00:57:25   Log-Likelihood:                -61218.
# No. Observations:               10532   AIC:                         1.224e+05
# Df Residuals:                   10526   BIC:                         1.225e+05
# Df Model:                           5
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       123.0916      0.954    128.976      0.000       121.221   124.962
# PerComArea      -22.6071      3.768     -6.001      0.000       -29.992   -15.222
# PerOfficeArea   123.6623      4.627     26.726      0.000       114.592   132.732
# PerOtherArea    144.3609      4.870     29.641      0.000       134.814   153.908
# PerRetailArea   171.9836      7.193     23.909      0.000       157.883   186.084
# PerGarageArea   114.5647     11.589      9.886      0.000        91.848   137.281
# ==============================================================================
# Omnibus:                     6987.488   Durbin-Watson:                   1.709
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           163377.960
# Skew:                           2.837   Prob(JB):                         0.00
# Kurtosis:                      21.442   Cond. No.                         15.9
# ==============================================================================

# %%
# That fixed it with a better R2
# Only one left to add, factory
print lm.smf_linear(['PerComArea', 'PerOfficeArea', 'PerOtherArea', 'PerRetailArea', 'PerGarageArea', 'PerFactryArea'],
                    'EUIwn', bd).summary()
# Out:
# EUIwn ~ PerComArea + PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + PerFactryArea
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.227
# Model:                            OLS   Adj. R-squared:                  0.226
# Method:                 Least Squares   F-statistic:                     513.9
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):               0.00
# Time:                        00:57:26   Log-Likelihood:                -61218.
# No. Observations:               10532   AIC:                         1.225e+05
# Df Residuals:                   10525   BIC:                         1.225e+05
# Df Model:                           6
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       123.0919      0.954    128.973      0.000       121.221   124.963
# PerComArea      -24.3446      4.553     -5.347      0.000       -33.270   -15.420
# PerOfficeArea   125.3884      5.278     23.755      0.000       115.042   135.735
# PerOtherArea    146.1005      5.502     26.553      0.000       135.315   156.886
# PerRetailArea   173.8292      7.689     22.607      0.000       158.757   188.901
# PerGarageArea   116.2675     11.857      9.806      0.000        93.026   139.509
# PerFactryArea     5.4237      7.981      0.680      0.497       -10.220    21.067
# ==============================================================================
# Omnibus:                     6978.595   Durbin-Watson:                   1.709
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           162688.251
# Skew:                           2.833   Prob(JB):                         0.00
# Kurtosis:                      21.402   Cond. No.                         17.7
# ==============================================================================

# %% [markdown]
# **Conclusion**
#
# Best combination of usage by area is:
# * PerComArea
# * PerOfficeArea
# * PerOtherArea
# * PerRetailArea
# * PerGarageArea
#
# Decent explanitory power with an R^2 of 0.227 and no red flags regarding multicolinearity.

# %% [markdown]
# ### Building Age
#
# We had two variables that looked good, so let's see how they do

# %%
# Start with comparing the two
print lm.smf_linear(['YearBuilt',],
                    'EUIwn', bd).summary()
print lm.smf_linear(['YearLastWork',],
                    'EUIwn', bd).summary()
print lm.smf_linear(['YearLastWork', 'YearBuilt'],
                    'EUIwn', bd).summary()
# Out:
# EUIwn ~ YearBuilt
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.024
# Model:                            OLS   Adj. R-squared:                  0.024
# Method:                 Least Squares   F-statistic:                     256.9
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):           3.77e-57
# Time:                        01:03:29   Log-Likelihood:                -62444.
# No. Observations:               10532   AIC:                         1.249e+05
# Df Residuals:                   10530   BIC:                         1.249e+05
# Df Model:                           1
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept   -834.6257     61.268    -13.623      0.000      -954.722  -714.529
# YearBuilt      0.5042      0.031     16.029      0.000         0.443     0.566
# ==============================================================================
# Omnibus:                     7410.330   Durbin-Watson:                   1.517
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           142202.036
# Skew:                           3.179   Prob(JB):                         0.00
# Kurtosis:                      19.841   Cond. No.                     1.35e+05
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 1.35e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# EUIwn ~ YearLastWork
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.036
# Model:                            OLS   Adj. R-squared:                  0.035
# Method:                 Least Squares   F-statistic:                     387.9
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):           7.80e-85
# Time:                        01:03:29   Log-Likelihood:                -62381.
# No. Observations:               10532   AIC:                         1.248e+05
# Df Residuals:                   10530   BIC:                         1.248e+05
# Df Model:                           1
# ================================================================================
#                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# Intercept    -1022.4929     59.402    -17.213      0.000     -1138.933  -906.053
# YearLastWork     0.5948      0.030     19.696      0.000         0.536     0.654
# ==============================================================================
# Omnibus:                     7352.618   Durbin-Watson:                   1.544
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           142228.115
# Skew:                           3.139   Prob(JB):                         0.00
# Kurtosis:                      19.873   Cond. No.                     1.33e+05
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 1.33e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# EUIwn ~ YearLastWork + YearBuilt
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.042
# Model:                            OLS   Adj. R-squared:                  0.041
# Method:                 Least Squares   F-statistic:                     228.0
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):           1.16e-97
# Time:                        01:03:29   Log-Likelihood:                -62348.
# No. Observations:               10532   AIC:                         1.247e+05
# Df Residuals:                   10529   BIC:                         1.247e+05
# Df Model:                           2
# ================================================================================
#                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# Intercept    -1330.5196     70.366    -18.908      0.000     -1468.451 -1192.588
# YearLastWork     0.4708      0.034     13.941      0.000         0.405     0.537
# YearBuilt        0.2834      0.035      8.105      0.000         0.215     0.352
# ==============================================================================
# Omnibus:                     7359.401   Durbin-Watson:                   1.545
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           142356.372
# Skew:                           3.143   Prob(JB):                         0.00
# Kurtosis:                      19.878   Cond. No.                     2.22e+05
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 2.22e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# **Conclusion**
#
# Stick to YearLastWork since it has better explanatory power and combining the two would give multicolinearity issues.

# %% [markdown]
# ### Lot Value
#
# We have a few variables to look at regarding lot values, including:
# * AssessTot
# * AssessLand
# * ExemptTot
# * ExemptLand
#
# Let's work through the combos that make sense to avoid multi-colinearity

# %%
# Start with comparing four
print lm.smf_linear(['AssessTot',],
                    'EUIwn', bd).summary()
print lm.smf_linear(['AssessLand',],
                    'EUIwn', bd).summary()
print lm.smf_linear(['ExemptTot',],
                    'EUIwn', bd).summary()
print lm.smf_linear(['ExemptLand',],
                    'EUIwn', bd).summary()
# Out:
# EUIwn ~ AssessTot
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.099
# Model:                            OLS   Adj. R-squared:                  0.099
# Method:                 Least Squares   F-statistic:                     1163.
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):          6.65e-242
# Time:                        01:14:34   Log-Likelihood:                -62019.
# No. Observations:               10532   AIC:                         1.240e+05
# Df Residuals:                   10530   BIC:                         1.241e+05
# Df Model:                           1
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    136.0427      0.913    148.934      0.000       134.252   137.833
# AssessTot   9.568e-07   2.81e-08     34.105      0.000      9.02e-07  1.01e-06
# ==============================================================================
# Omnibus:                     7607.512   Durbin-Watson:                   1.650
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           166982.039
# Skew:                           3.249   Prob(JB):                         0.00
# Kurtosis:                      21.392   Cond. No.                     3.49e+07
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 3.49e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# EUIwn ~ AssessLand
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.081
# Model:                            OLS   Adj. R-squared:                  0.081
# Method:                 Least Squares   F-statistic:                     925.9
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):          5.49e-195
# Time:                        01:14:34   Log-Likelihood:                -62127.
# No. Observations:               10532   AIC:                         1.243e+05
# Df Residuals:                   10530   BIC:                         1.243e+05
# Df Model:                           1
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    138.2213      0.911    151.767      0.000       136.436   140.006
# AssessLand  3.182e-06   1.05e-07     30.428      0.000      2.98e-06  3.39e-06
# ==============================================================================
# Omnibus:                     7572.476   Durbin-Watson:                   1.622
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           166228.609
# Skew:                           3.227   Prob(JB):                         0.00
# Kurtosis:                      21.362   Cond. No.                     9.23e+06
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 9.23e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# EUIwn ~ ExemptTot
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.065
# Model:                            OLS   Adj. R-squared:                  0.065
# Method:                 Least Squares   F-statistic:                     735.9
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):          1.03e-156
# Time:                        01:14:34   Log-Likelihood:                -62215.
# No. Observations:               10532   AIC:                         1.244e+05
# Df Residuals:                   10530   BIC:                         1.244e+05
# Df Model:                           1
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    142.7765      0.883    161.633      0.000       141.045   144.508
# ExemptTot   1.323e-06   4.88e-08     27.128      0.000      1.23e-06  1.42e-06
# ==============================================================================
# Omnibus:                     7274.247   Durbin-Watson:                   1.583
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           143646.138
# Skew:                           3.081   Prob(JB):                         0.00
# Kurtosis:                      20.011   Cond. No.                     1.85e+07
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 1.85e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# EUIwn ~ ExemptLand
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.047
# Model:                            OLS   Adj. R-squared:                  0.046
# Method:                 Least Squares   F-statistic:                     513.9
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):          4.05e-111
# Time:                        01:14:34   Log-Likelihood:                -62320.
# No. Observations:               10532   AIC:                         1.246e+05
# Df Residuals:                   10530   BIC:                         1.247e+05
# Df Model:                           1
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    143.9498      0.889    162.009      0.000       142.208   145.691
# ExemptLand  5.323e-06   2.35e-07     22.669      0.000      4.86e-06  5.78e-06
# ==============================================================================
# Omnibus:                     7321.811   Durbin-Watson:                   1.567
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           143132.386
# Skew:                           3.115   Prob(JB):                         0.00
# Kurtosis:                      19.952   Cond. No.                     3.84e+06
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 3.84e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# we don't expect the assesed total and assessed land combined to help much
print "ASSESS"
print lm.smf_linear(['AssessTot', 'AssessLand',],
                    'EUIwn', bd).summary()

print "\nEXEMPT"
# and same with exempt
print lm.smf_linear(['AssessTot', 'AssessLand',],
                    'EUIwn', bd).summary()
# Out:
# ASSESS
# EUIwn ~ AssessTot + AssessLand
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.100
# Model:                            OLS   Adj. R-squared:                  0.099
# Method:                 Least Squares   F-statistic:                     582.3
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):          1.38e-240
# Time:                        01:14:34   Log-Likelihood:                -62019.
# No. Observations:               10532   AIC:                         1.240e+05
# Df Residuals:                   10529   BIC:                         1.241e+05
# Df Model:                           2
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    136.0334      0.913    148.922      0.000       134.243   137.824
# AssessTot   8.927e-07   6.02e-08     14.817      0.000      7.75e-07  1.01e-06
# AssessLand  2.676e-07   2.22e-07      1.204      0.229     -1.68e-07  7.03e-07
# ==============================================================================
# Omnibus:                     7609.300   Durbin-Watson:                   1.650
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           167105.051
# Skew:                           3.250   Prob(JB):                         0.00
# Kurtosis:                      21.399   Cond. No.                     3.60e+07
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 3.6e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# EXEMPT
# EUIwn ~ AssessTot + AssessLand
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.100
# Model:                            OLS   Adj. R-squared:                  0.099
# Method:                 Least Squares   F-statistic:                     582.3
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):          1.38e-240
# Time:                        01:14:34   Log-Likelihood:                -62019.
# No. Observations:               10532   AIC:                         1.240e+05
# Df Residuals:                   10529   BIC:                         1.241e+05
# Df Model:                           2
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    136.0334      0.913    148.922      0.000       134.243   137.824
# AssessTot   8.927e-07   6.02e-08     14.817      0.000      7.75e-07  1.01e-06
# AssessLand  2.676e-07   2.22e-07      1.204      0.229     -1.68e-07  7.03e-07
# ==============================================================================
# Omnibus:                     7609.300   Durbin-Watson:                   1.650
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           167105.051
# Skew:                           3.250   Prob(JB):                         0.00
# Kurtosis:                      21.399   Cond. No.                     3.60e+07
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 3.6e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# but a combination with the exmept values could help
print lm.smf_linear(['AssessTot', 'ExemptTot',],
                    'EUIwn', bd).summary()
print lm.smf_linear(['AssessTot', 'ExemptLand',],
                    'EUIwn', bd).summary()
# Out:
# EUIwn ~ AssessTot + ExemptTot
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.107
# Model:                            OLS   Adj. R-squared:                  0.107
# Method:                 Least Squares   F-statistic:                     630.3
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):          2.73e-259
# Time:                        01:14:35   Log-Likelihood:                -61976.
# No. Observations:               10532   AIC:                         1.240e+05
# Df Residuals:                   10529   BIC:                         1.240e+05
# Df Model:                           2
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    136.3859      0.910    149.804      0.000       134.601   138.171
# AssessTot   7.658e-07   3.46e-08     22.148      0.000      6.98e-07  8.34e-07
# ExemptTot   5.533e-07    5.9e-08      9.378      0.000      4.38e-07  6.69e-07
# ==============================================================================
# Omnibus:                     7533.619   Durbin-Watson:                   1.653
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           164840.749
# Skew:                           3.203   Prob(JB):                         0.00
# Kurtosis:                      21.292   Cond. No.                     3.73e+07
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 3.73e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# EUIwn ~ AssessTot + ExemptLand
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.104
# Model:                            OLS   Adj. R-squared:                  0.104
# Method:                 Least Squares   F-statistic:                     609.8
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):          2.56e-251
# Time:                        01:14:35   Log-Likelihood:                -61994.
# No. Observations:               10532   AIC:                         1.240e+05
# Df Residuals:                   10529   BIC:                         1.240e+05
# Df Model:                           2
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    136.2154      0.912    149.424      0.000       134.428   138.002
# AssessTot   8.404e-07   3.24e-08     25.942      0.000      7.77e-07  9.04e-07
# ExemptLand  1.882e-06   2.64e-07      7.141      0.000      1.37e-06   2.4e-06
# ==============================================================================
# Omnibus:                     7569.218   Durbin-Watson:                   1.653
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           165557.651
# Skew:                           3.226   Prob(JB):                         0.00
# Kurtosis:                      21.320   Cond. No.                     3.50e+07
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 3.5e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# **Conclusion**
#
# Combine the Assessed Total and Exempt Total to get the best results. Although all the data for this has some troubling multicolinearity flags.

# %% [markdown]
# ### Initial Combination
#
# Let's combine a few of these different variables that we explored to see if we can get a better model

# %%
lot_value_features = ['AssessTot', 'ExemptTot',]
building_area_features = ['PerComArea', 'PerOfficeArea', 'PerOtherArea', 'PerRetailArea', 'PerGarageArea',]
building_age_features = ['YearLastWork']

# %%
# combine building area with value
print lm.smf_linear(lot_value_features + building_area_features,
                    'EUIwn', bd).summary()
# Out:
# EUIwn ~ AssessTot + ExemptTot + PerComArea + PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.260
# Model:                            OLS   Adj. R-squared:                  0.260
# Method:                 Least Squares   F-statistic:                     529.1
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):               0.00
# Time:                        01:17:56   Log-Likelihood:                -60983.
# No. Observations:               10532   AIC:                         1.220e+05
# Df Residuals:                   10524   BIC:                         1.220e+05
# Df Model:                           7
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       120.3066      0.947    126.993      0.000       118.450   122.164
# AssessTot      3.392e-07   3.42e-08      9.915      0.000      2.72e-07  4.06e-07
# ExemptTot      5.536e-07    5.6e-08      9.887      0.000      4.44e-07  6.63e-07
# PerComArea      -21.5799      3.685     -5.856      0.000       -28.804   -14.356
# PerOfficeArea   107.2331      4.699     22.821      0.000        98.022   116.444
# PerOtherArea    124.4604      4.856     25.630      0.000       114.941   133.979
# PerRetailArea   167.0842      7.047     23.710      0.000       153.271   180.898
# PerGarageArea    96.4448     11.367      8.485      0.000        74.164   118.725
# ==============================================================================
# Omnibus:                     7128.462   Durbin-Watson:                   1.755
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           178020.311
# Skew:                           2.897   Prob(JB):                         0.00
# Kurtosis:                      22.290   Cond. No.                     5.27e+08
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 5.27e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# combine building area with age
print lm.smf_linear(building_age_features + building_area_features,
                    'EUIwn', bd).summary()
# Out:
# EUIwn ~ YearLastWork + PerComArea + PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.237
# Model:                            OLS   Adj. R-squared:                  0.236
# Method:                 Least Squares   F-statistic:                     544.0
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):               0.00
# Time:                        01:19:36   Log-Likelihood:                -61149.
# No. Observations:               10532   AIC:                         1.223e+05
# Df Residuals:                   10525   BIC:                         1.224e+05
# Df Model:                           6
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept      -516.4753     54.022     -9.560      0.000      -622.369  -410.582
# YearLastWork      0.3258      0.028     11.841      0.000         0.272     0.380
# PerComArea      -22.6431      3.743     -6.050      0.000       -29.980   -15.306
# PerOfficeArea   121.5083      4.600     26.413      0.000       112.491   130.526
# PerOtherArea    137.8270      4.870     28.302      0.000       128.281   147.373
# PerRetailArea   164.9259      7.171     22.999      0.000       150.869   178.983
# PerGarageArea   101.7515     11.564      8.799      0.000        79.084   124.419
# ==============================================================================
# Omnibus:                     7004.319   Durbin-Watson:                   1.720
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           165153.332
# Skew:                           2.844   Prob(JB):                         0.00
# Kurtosis:                      21.547   Cond. No.                     1.36e+05
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 1.36e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# combine building age with lot value
print lm.smf_linear(building_age_features + lot_value_features,
                    'EUIwn', bd).summary()
# Out:
# EUIwn ~ YearLastWork + AssessTot + ExemptTot
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.126
# Model:                            OLS   Adj. R-squared:                  0.125
# Method:                 Least Squares   F-statistic:                     504.1
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):          4.24e-306
# Time:                        01:20:20   Log-Likelihood:                -61864.
# No. Observations:               10532   AIC:                         1.237e+05
# Df Residuals:                   10528   BIC:                         1.238e+05
# Df Model:                           3
# ================================================================================
#                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# Intercept     -722.8911     57.321    -12.611      0.000      -835.250  -610.532
# YearLastWork     0.4373      0.029     14.993      0.000         0.380     0.494
# AssessTot     7.233e-07   3.43e-08     21.066      0.000      6.56e-07  7.91e-07
# ExemptTot      4.92e-07   5.85e-08      8.406      0.000      3.77e-07  6.07e-07
# ==============================================================================
# Omnibus:                     7467.459   Durbin-Watson:                   1.675
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           163206.730
# Skew:                           3.161   Prob(JB):                         0.00
# Kurtosis:                      21.219   Cond. No.                     2.37e+09
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 2.37e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# combine all three
print lm.smf_linear(building_age_features + lot_value_features + building_area_features,
                    'EUIwn', bd).summary()
# Out:
# EUIwn ~ YearLastWork + AssessTot + ExemptTot + PerComArea + PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.267
# Model:                            OLS   Adj. R-squared:                  0.266
# Method:                 Least Squares   F-statistic:                     478.4
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):               0.00
# Time:                        01:20:53   Log-Likelihood:                -60937.
# No. Observations:               10532   AIC:                         1.219e+05
# Df Residuals:                   10523   BIC:                         1.220e+05
# Df Model:                           8
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept      -389.8143     53.306     -7.313      0.000      -494.304  -285.325
# YearLastWork      0.2599      0.027      9.571      0.000         0.207     0.313
# AssessTot      3.204e-07   3.41e-08      9.390      0.000      2.53e-07  3.87e-07
# ExemptTot      5.277e-07   5.58e-08      9.453      0.000      4.18e-07  6.37e-07
# PerComArea      -21.6636      3.670     -5.904      0.000       -28.857   -14.471
# PerOfficeArea   106.4045      4.680     22.738      0.000        97.232   115.577
# PerOtherArea    120.2529      4.855     24.767      0.000       110.736   129.770
# PerRetailArea   161.7205      7.039     22.974      0.000       147.922   175.519
# PerGarageArea    87.1606     11.359      7.673      0.000        64.894   109.427
# ==============================================================================
# Omnibus:                     7126.010   Durbin-Watson:                   1.762
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           178244.567
# Skew:                           2.895   Prob(JB):                         0.00
# Kurtosis:                      22.304   Cond. No.                     2.41e+09
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 2.41e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# **Conclusion**
#
# The age and lot value characteristics add some explanatory power to the usage values, but at the expense of some additional multicoliniearity flags. Perhaps we can improve the regression with other fields.

# %% [markdown]
# ### Adding other variables

# %%
other_fields = ['Easements',
 'NumBldgs',
 'NumFloors',
 'UnitsRes',
 'UnitsTotal',
 'LotFront',
 'LotDepth',
 'BldgFront',
 'BldgDepth',
 'MaxAllwFAR',]

for f in other_fields:
    print '#\n%s\n#' % f
    print lm.smf_linear(building_area_features + [f],
                    'EUIwn', bd).summary()
# Out:
# #
# Easements
# #
# EUIwn ~ PerComArea + PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + Easements
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.228
# Model:                            OLS   Adj. R-squared:                  0.228
# Method:                 Least Squares   F-statistic:                     518.7
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):               0.00
# Time:                        01:26:05   Log-Likelihood:                -61207.
# No. Observations:               10532   AIC:                         1.224e+05
# Df Residuals:                   10525   BIC:                         1.225e+05
# Df Model:                           6
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       122.8434      0.955    128.655      0.000       120.972   124.715
# PerComArea      -22.7820      3.764     -6.053      0.000       -30.160   -15.404
# PerOfficeArea   123.6684      4.622     26.754      0.000       114.608   132.729
# PerOtherArea    142.5251      4.881     29.202      0.000       132.958   152.092
# PerRetailArea   171.8761      7.186     23.918      0.000       157.790   185.962
# PerGarageArea   111.0236     11.601      9.570      0.000        88.284   133.764
# Easements        15.2442      3.205      4.757      0.000         8.962    21.526
# ==============================================================================
# Omnibus:                     7013.218   Durbin-Watson:                   1.711
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           164626.269
# Skew:                           2.851   Prob(JB):                         0.00
# Kurtosis:                      21.510   Cond. No.                         16.0
# ==============================================================================
# #
# NumBldgs
# #
# EUIwn ~ PerComArea + PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + NumBldgs
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.229
# Model:                            OLS   Adj. R-squared:                  0.228
# Method:                 Least Squares   F-statistic:                     520.6
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):               0.00
# Time:                        01:26:05   Log-Likelihood:                -61203.
# No. Observations:               10532   AIC:                         1.224e+05
# Df Residuals:                   10525   BIC:                         1.225e+05
# Df Model:                           6
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       121.7584      0.982    123.962      0.000       119.833   123.684
# PerComArea      -22.0162      3.764     -5.850      0.000       -29.393   -14.639
# PerOfficeArea   123.7728      4.620     26.788      0.000       114.716   132.830
# PerOtherArea    143.8693      4.864     29.577      0.000       134.335   153.404
# PerRetailArea   172.3205      7.183     23.989      0.000       158.240   186.401
# PerGarageArea   113.9212     11.573      9.844      0.000        91.236   136.606
# NumBldgs          0.5423      0.097      5.606      0.000         0.353     0.732
# ==============================================================================
# Omnibus:                     6986.763   Durbin-Watson:                   1.713
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           164310.301
# Skew:                           2.834   Prob(JB):                         0.00
# Kurtosis:                      21.501   Cond. No.                         128.
# ==============================================================================
# #
# NumFloors
# #
# EUIwn ~ PerComArea + PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + NumFloors
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.235
# Model:                            OLS   Adj. R-squared:                  0.235
# Method:                 Least Squares   F-statistic:                     539.4
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):               0.00
# Time:                        01:26:05   Log-Likelihood:                -61159.
# No. Observations:               10532   AIC:                         1.223e+05
# Df Residuals:                   10525   BIC:                         1.224e+05
# Df Model:                           6
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       112.7346      1.344     83.903      0.000       110.101   115.368
# PerComArea      -18.4521      3.766     -4.900      0.000       -25.834   -11.070
# PerOfficeArea   109.5304      4.781     22.910      0.000       100.159   118.902
# PerOtherArea    138.9275      4.869     28.533      0.000       129.383   148.472
# PerRetailArea   172.1935      7.154     24.071      0.000       158.171   186.216
# PerGarageArea   104.8117     11.559      9.067      0.000        82.153   127.470
# NumFloors         1.0171      0.093     10.890      0.000         0.834     1.200
# ==============================================================================
# Omnibus:                     7179.221   Durbin-Watson:                   1.719
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           176372.115
# Skew:                           2.934   Prob(JB):                         0.00
# Kurtosis:                      22.169   Cond. No.                         214.
# ==============================================================================
# #
# UnitsRes
# #
# EUIwn ~ PerComArea + PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + UnitsRes
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.227
# Model:                            OLS   Adj. R-squared:                  0.226
# Method:                 Least Squares   F-statistic:                     514.7
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):               0.00
# Time:                        01:26:06   Log-Likelihood:                -61216.
# No. Observations:               10532   AIC:                         1.224e+05
# Df Residuals:                   10525   BIC:                         1.225e+05
# Df Model:                           6
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       122.1849      1.054    115.905      0.000       120.119   124.251
# PerComArea      -21.6984      3.794     -5.720      0.000       -29.135   -14.262
# PerOfficeArea   123.6678      4.626     26.731      0.000       114.599   132.736
# PerOtherArea    144.2849      4.870     29.628      0.000       134.739   153.831
# PerRetailArea   171.9580      7.192     23.909      0.000       157.860   186.056
# PerGarageArea   113.2274     11.606      9.756      0.000        90.477   135.977
# UnitsRes          0.0064      0.003      2.024      0.043         0.000     0.013
# ==============================================================================
# Omnibus:                     6985.954   Durbin-Watson:                   1.709
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           163496.279
# Skew:                           2.836   Prob(JB):                         0.00
# Kurtosis:                      21.450   Cond. No.                     4.17e+03
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 4.17e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# #
# UnitsTotal
# #
# EUIwn ~ PerComArea + PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + UnitsTotal
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.227
# Model:                            OLS   Adj. R-squared:                  0.226
# Method:                 Least Squares   F-statistic:                     514.4
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):               0.00
# Time:                        01:26:06   Log-Likelihood:                -61217.
# No. Observations:               10532   AIC:                         1.224e+05
# Df Residuals:                   10525   BIC:                         1.225e+05
# Df Model:                           6
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       122.3343      1.056    115.872      0.000       120.265   124.404
# PerComArea      -21.9304      3.789     -5.788      0.000       -29.357   -14.504
# PerOfficeArea   123.5760      4.627     26.708      0.000       114.506   132.646
# PerOtherArea    144.3293      4.870     29.636      0.000       134.783   153.875
# PerRetailArea   171.9583      7.193     23.907      0.000       157.859   186.057
# PerGarageArea   113.3500     11.610      9.763      0.000        90.591   136.109
# UnitsTotal        0.0052      0.003      1.677      0.094        -0.001     0.011
# ==============================================================================
# Omnibus:                     6987.385   Durbin-Watson:                   1.709
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           163510.471
# Skew:                           2.837   Prob(JB):                         0.00
# Kurtosis:                      21.450   Cond. No.                     4.27e+03
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 4.27e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# #
# LotFront
# #
# EUIwn ~ PerComArea + PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + LotFront
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.236
# Model:                            OLS   Adj. R-squared:                  0.236
# Method:                 Least Squares   F-statistic:                     543.1
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):               0.00
# Time:                        01:26:06   Log-Likelihood:                -61151.
# No. Observations:               10532   AIC:                         1.223e+05
# Df Residuals:                   10525   BIC:                         1.224e+05
# Df Model:                           6
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       113.8435      1.237     92.069      0.000       111.420   116.267
# PerComArea      -24.8857      3.749     -6.638      0.000       -32.234   -17.538
# PerOfficeArea   128.5680      4.617     27.847      0.000       119.518   137.618
# PerOtherArea    142.5360      4.842     29.437      0.000       133.045   152.027
# PerRetailArea   168.4849      7.154     23.551      0.000       154.462   182.508
# PerGarageArea   109.7401     11.523      9.524      0.000        87.153   132.327
# LotFront          0.0511      0.004     11.655      0.000         0.042     0.060
# ==============================================================================
# Omnibus:                     6833.635   Durbin-Watson:                   1.718
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           154582.113
# Skew:                           2.757   Prob(JB):                         0.00
# Kurtosis:                      20.940   Cond. No.                     3.97e+03
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 3.97e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# #
# LotDepth
# #
# EUIwn ~ PerComArea + PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + LotDepth
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.233
# Model:                            OLS   Adj. R-squared:                  0.232
# Method:                 Least Squares   F-statistic:                     532.3
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):               0.00
# Time:                        01:26:06   Log-Likelihood:                -61175.
# No. Observations:               10532   AIC:                         1.224e+05
# Df Residuals:                   10525   BIC:                         1.224e+05
# Df Model:                           6
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       115.6806      1.242     93.162      0.000       113.247   118.115
# PerComArea      -26.1012      3.771     -6.921      0.000       -33.494   -18.709
# PerOfficeArea   127.1264      4.624     27.495      0.000       118.063   136.190
# PerOtherArea    144.1146      4.851     29.709      0.000       134.606   153.623
# PerRetailArea   167.4514      7.181     23.318      0.000       153.375   181.528
# PerGarageArea   112.1357     11.545      9.713      0.000        89.505   134.767
# LotDepth          0.0454      0.005      9.276      0.000         0.036     0.055
# ==============================================================================
# Omnibus:                     6938.354   Durbin-Watson:                   1.715
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           162737.504
# Skew:                           2.806   Prob(JB):                         0.00
# Kurtosis:                      21.421   Cond. No.                     3.70e+03
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 3.7e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# #
# BldgFront
# #
# EUIwn ~ PerComArea + PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + BldgFront
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.230
# Model:                            OLS   Adj. R-squared:                  0.229
# Method:                 Least Squares   F-statistic:                     522.6
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):               0.00
# Time:                        01:26:06   Log-Likelihood:                -61198.
# No. Observations:               10532   AIC:                         1.224e+05
# Df Residuals:                   10525   BIC:                         1.225e+05
# Df Model:                           6
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       118.7469      1.169    101.547      0.000       116.455   121.039
# PerComArea      -24.0413      3.767     -6.382      0.000       -31.425   -16.657
# PerOfficeArea   125.4897      4.627     27.120      0.000       116.420   134.560
# PerOtherArea    144.8034      4.862     29.785      0.000       135.274   154.333
# PerRetailArea   170.6058      7.183     23.752      0.000       156.526   184.686
# PerGarageArea   113.9114     11.567      9.848      0.000        91.237   136.586
# BldgFront         0.0333      0.005      6.406      0.000         0.023     0.043
# ==============================================================================
# Omnibus:                     6937.382   Durbin-Watson:                   1.715
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           160956.230
# Skew:                           2.810   Prob(JB):                         0.00
# Kurtosis:                      21.309   Cond. No.                     3.10e+03
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 3.1e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# #
# BldgDepth
# #
# EUIwn ~ PerComArea + PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + BldgDepth
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.228
# Model:                            OLS   Adj. R-squared:                  0.227
# Method:                 Least Squares   F-statistic:                     516.8
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):               0.00
# Time:                        01:26:06   Log-Likelihood:                -61211.
# No. Observations:               10532   AIC:                         1.224e+05
# Df Residuals:                   10525   BIC:                         1.225e+05
# Df Model:                           6
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       120.5611      1.173    102.758      0.000       118.261   122.861
# PerComArea      -24.7116      3.808     -6.490      0.000       -32.176   -17.247
# PerOfficeArea   124.8126      4.635     26.930      0.000       115.728   133.898
# PerOtherArea    145.7582      4.882     29.856      0.000       136.188   155.328
# PerRetailArea   172.3053      7.190     23.966      0.000       158.212   186.398
# PerGarageArea   114.8951     11.582      9.920      0.000        92.192   137.598
# BldgDepth         0.0244      0.007      3.704      0.000         0.011     0.037
# ==============================================================================
# Omnibus:                     6957.988   Durbin-Watson:                   1.709
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           161561.030
# Skew:                           2.822   Prob(JB):                         0.00
# Kurtosis:                      21.339   Cond. No.                     2.56e+03
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 2.56e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# #
# MaxAllwFAR
# #
# EUIwn ~ PerComArea + PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + MaxAllwFAR
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.227
# Model:                            OLS   Adj. R-squared:                  0.227
# Method:                 Least Squares   F-statistic:                     515.8
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):               0.00
# Time:                        01:26:06   Log-Likelihood:                -61214.
# No. Observations:               10532   AIC:                         1.224e+05
# Df Residuals:                   10525   BIC:                         1.225e+05
# Df Model:                           6
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       119.8076      1.445     82.906      0.000       116.975   122.640
# PerComArea      -22.2792      3.768     -5.913      0.000       -29.664   -14.894
# PerOfficeArea   118.8390      4.892     24.291      0.000       109.249   128.429
# PerOtherArea    143.4452      4.878     29.407      0.000       133.884   153.007
# PerRetailArea   170.6538      7.204     23.689      0.000       156.533   184.775
# PerGarageArea   114.2946     11.585      9.866      0.000        91.586   137.003
# MaxAllwFAR        0.7161      0.237      3.025      0.002         0.252     1.180
# ==============================================================================
# Omnibus:                     7041.332   Durbin-Watson:                   1.709
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           166633.625
# Skew:                           2.865   Prob(JB):                         0.00
# Kurtosis:                      21.625   Cond. No.                         99.0
# ==============================================================================

# %%
# no warnings with the following and a small increase in R2
best_continuous_features = building_area_features + "Easements NumBldgs NumFloors MaxAllwFAR".split()
print lm.smf_linear(best_continuous_features,
                    'EUIwn', bd).summary()
# Out:
# EUIwn ~ PerComArea + PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + Easements + NumBldgs + NumFloors + MaxAllwFAR
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.241
# Model:                            OLS   Adj. R-squared:                  0.240
# Method:                 Least Squares   F-statistic:                     370.5
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):               0.00
# Time:                        02:29:21   Log-Likelihood:                -61122.
# No. Observations:               10532   AIC:                         1.223e+05
# Df Residuals:                   10522   BIC:                         1.223e+05
# Df Model:                           9
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       112.7592      1.533     73.552      0.000       109.754   115.764
# PerComArea      -17.2219      3.759     -4.582      0.000       -24.590    -9.854
# PerOfficeArea   112.4145      4.874     23.066      0.000       102.861   121.968
# PerOtherArea    136.5251      4.869     28.039      0.000       126.981   146.069
# PerRetailArea   174.4278      7.151     24.391      0.000       160.410   188.446
# PerGarageArea    98.5723     11.555      8.531      0.000        75.922   121.223
# Easements        13.2298      3.198      4.137      0.000         6.962    19.498
# NumBldgs          0.5791      0.097      5.967      0.000         0.389     0.769
# NumFloors         1.3160      0.117     11.252      0.000         1.087     1.545
# MaxAllwFAR       -1.0264      0.297     -3.456      0.001        -1.609    -0.444
# ==============================================================================
# Omnibus:                     7178.044   Durbin-Watson:                   1.731
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           177581.863
# Skew:                           2.931   Prob(JB):                         0.00
# Kurtosis:                      22.243   Cond. No.                         233.
# ==============================================================================

# %% [markdown]
# **Conclusion**
#
# Adding the following fields to the regression helps slightly and doesn't raise any immediate data issues:
# * Easements
# * NumBldgs
# * NumFloors
# * MaxAllwFAR

# %% [markdown]
# ### A Few Dummies
#
# We have a few dummies built in before we ge too heavy on the categorical features that need to be transformed in to dummies. Let's check to see if these have any relevance.

# %%
print lm.smf_linear(pluto_class + hmcv_class,
                    'EUIwn', bd).summary()
# Out:
# EUIwn ~ Landmarked + BuiltCode + Altered
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     41.15
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):           1.99e-26
# Time:                        01:45:30   Log-Likelihood:                -62510.
# No. Observations:               10532   AIC:                         1.250e+05
# Df Residuals:                   10528   BIC:                         1.251e+05
# Df Model:                           3
# ===================================================================================
#                       coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------
# Intercept         141.6076      1.109    127.729      0.000       139.434   143.781
# Altered[T.True]    14.0014      1.916      7.307      0.000        10.245    17.757
# Landmarked         46.4830      6.158      7.548      0.000        34.412    58.554
# BuiltCode          -0.5342      3.626     -0.147      0.883        -7.642     6.574
# ==============================================================================
# Omnibus:                     7407.275   Durbin-Watson:                   1.518
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           142880.587
# Skew:                           3.175   Prob(JB):                         0.00
# Kurtosis:                      19.890   Cond. No.                         7.41
# ==============================================================================

# %%
# Adding in Landmarked and Altered to our best model from before to see if it helps
best_dummies = ['Altered']
print lm.smf_linear(best_continuous_features + best_dummies,
                    'EUIwn', bd).summary()
# Out:
# EUIwn ~ PerComArea + PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + Easements + NumBldgs + NumFloors + MaxAllwFAR + Altered
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.241
# Model:                            OLS   Adj. R-squared:                  0.240
# Method:                 Least Squares   F-statistic:                     333.6
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):               0.00
# Time:                        01:45:32   Log-Likelihood:                -61121.
# No. Observations:               10532   AIC:                         1.223e+05
# Df Residuals:                   10521   BIC:                         1.223e+05
# Df Model:                          10
# ===================================================================================
#                       coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------
# Intercept         112.2511      1.579     71.097      0.000       109.156   115.346
# Altered[T.True]     2.3127      1.719      1.345      0.179        -1.058     5.683
# PerComArea        -17.5365      3.766     -4.657      0.000       -24.918   -10.155
# PerOfficeArea     112.4386      4.874     23.071      0.000       102.886   121.992
# PerOtherArea      136.4833      4.869     28.031      0.000       126.939   146.027
# PerRetailArea     174.2967      7.152     24.371      0.000       160.278   188.315
# PerGarageArea      99.2106     11.564      8.579      0.000        76.542   121.879
# Easements          13.0338      3.201      4.072      0.000         6.759    19.308
# NumBldgs            0.5813      0.097      5.990      0.000         0.391     0.772
# NumFloors           1.3379      0.118     11.331      0.000         1.106     1.569
# MaxAllwFAR         -1.1092      0.303     -3.657      0.000        -1.704    -0.515
# ==============================================================================
# Omnibus:                     7176.140   Durbin-Watson:                   1.731
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           177555.424
# Skew:                           2.930   Prob(JB):                         0.00
# Kurtosis:                      22.242   Cond. No.                         233.
# ==============================================================================

# %% [markdown]
# ## Current Best Model
#
# > EUIwn ~ PerComArea + PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + Easements + NumBldgs + NumFloors + MaxAllwFAR

# %% [markdown]
# ### Playing with Categorical Values
#
# We have a number of fields that have categorical data in them and are just begging to be made in to dummy variables!

# %%
X = pd.get_dummies(bd[pluto_class_dummies[0]])

results2 = lm.f_test(X, bd[['EUIwn']])
results2.sort('r2', ascending=False)
# Out:
#         F score feature        p-value        r2
# 23  1034.907130      I1  1.138608e-216  0.089487
# 28   406.162479      I9   1.164468e-88  0.037139
# 7    319.065035      D4   2.511714e-70  0.029409
# 36   280.224863      K6   4.244984e-62  0.025922
# 5    225.712918      D1   1.709347e-50  0.020985
# 42   198.209493      O3   1.302206e-44  0.018476
# 27   189.294623      I6   1.059877e-42  0.017659
# 43   171.090761      O4   8.570743e-39  0.015988
# 33   133.700286      K1   9.739475e-31  0.012538
# 31   103.875099      J6   2.792923e-24  0.009768
# 51    98.426174      P7   4.259795e-23  0.009261
# 53    95.580601      R5   1.769473e-22  0.008995
# 11    88.109824      E7   7.468431e-21  0.008298
# 19    80.485391      H2   3.425798e-19  0.007585
# 37    65.280205      K9   7.207911e-16  0.006161
# 14    51.038307      F2   9.657171e-13  0.004824
# 26    49.607125      I5   1.995592e-12  0.004689
# 20    47.430471      H3   6.024088e-12  0.004484
# 47    46.646631      O9   8.970279e-12  0.004410
# 56    37.619702      W6   8.905927e-10  0.003560
# 18    36.429680      H1   1.636082e-09  0.003448
# 41    31.455212      O2   2.092432e-08  0.002978
# 21    27.486432      H5   1.612658e-07  0.002604
# 40    26.549566      O1   2.615141e-07  0.002515
# 9     25.967873      E1   3.531680e-07  0.002460
# 13    24.762064      F1   6.588734e-07  0.002346
# 8     21.715138      D7   3.201655e-06  0.002058
# 22    21.033667      H9   4.564895e-06  0.001994
# 0     20.371315      C1   6.447053e-06  0.001931
# 12    19.605962      E9   9.613096e-06  0.001858
# 32    18.164614      J8   2.043729e-05  0.001722
# 45    18.010048      O6   2.216245e-05  0.001707
# 17    16.295792      G1   5.456779e-05  0.001545
# 16    15.844809      F9   6.921645e-05  0.001502
# 29    14.117537      J4   1.726621e-04  0.001339
# 34    14.021418      K2   1.817031e-04  0.001330
# 6     13.919620      D3   1.917992e-04  0.001320
# 24    13.556559      I2   2.326386e-04  0.001286
# 15    13.217081      F4   2.787320e-04  0.001254
# 49    11.882430      P5   5.688737e-04  0.001127
# 44    11.793562      O5   5.966492e-04  0.001119
# 39    11.411412      N2   7.325886e-04  0.001083
# 4     11.195570      D0   8.227962e-04  0.001062
# 25     9.363826      I3   2.218664e-03  0.000888
# 38     8.795561      L1   3.026420e-03  0.000835
# 52     7.907700      R4   4.931586e-03  0.000750
# 55     7.811784      W5   5.200057e-03  0.000741
# 50     7.664544      P6   5.641495e-03  0.000727
# 10     6.952186      E3   8.383976e-03  0.000660
# 54     5.956127      RM   1.468259e-02  0.000565
# 57     5.943573      W7   1.478747e-02  0.000564
# 3      5.767630      C9   1.634125e-02  0.000547
# 35     5.570908      K3   1.827942e-02  0.000529
# 1      5.528810      C6   1.872415e-02  0.000525
# 30     4.959929      J5   2.596233e-02  0.000471
# 48     4.293468      P3   3.828334e-02  0.000408
# 2      3.371497      C7   6.636163e-02  0.000320
# 46     2.795426      O7   9.456335e-02  0.000265

# %%
# first value helps out a bunch
print lm.smf_linear(best_continuous_features + ['I1', 'I9', 'D4', 'K6', 'D1'],
                    'EUIwn', pd.concat([X, bd], axis=1)).summary()
# Out:
# EUIwn ~ PerComArea + PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + Easements + NumBldgs + NumFloors + MaxAllwFAR + I1 + I9 + D4 + K6 + D1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.326
# Model:                            OLS   Adj. R-squared:                  0.325
# Method:                 Least Squares   F-statistic:                     362.7
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):               0.00
# Time:                        02:17:11   Log-Likelihood:                -60497.
# No. Observations:               10532   AIC:                         1.210e+05
# Df Residuals:                   10517   BIC:                         1.211e+05
# Df Model:                          14
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       116.9551      1.959     59.716      0.000       113.116   120.794
# PerComArea      -23.1347      3.725     -6.211      0.000       -30.436   -15.834
# PerOfficeArea   102.2272      4.622     22.119      0.000        93.168   111.287
# PerOtherArea    105.8182      4.673     22.643      0.000        96.658   114.979
# PerRetailArea   142.4449      7.647     18.628      0.000       127.456   157.434
# PerGarageArea    87.1891     10.911      7.991      0.000        65.801   108.578
# Easements        16.2551      3.017      5.388      0.000        10.342    22.168
# NumBldgs          0.4498      0.093      4.856      0.000         0.268     0.631
# NumFloors         1.2435      0.111     11.163      0.000         1.025     1.462
# MaxAllwFAR       -0.2697      0.283     -0.952      0.341        -0.825     0.285
# I1              300.8362     10.064     29.892      0.000       281.108   320.564
# I9              251.8363     13.581     18.544      0.000       225.216   278.457
# D4              -14.4769      2.073     -6.983      0.000       -18.541   -10.413
# K6              100.5444     10.887      9.235      0.000        79.204   121.885
# D1               -5.0611      2.245     -2.255      0.024        -9.461    -0.661
# ==============================================================================
# Omnibus:                     6464.145   Durbin-Watson:                   1.823
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           167599.464
# Skew:                           2.494   Prob(JB):                         0.00
# Kurtosis:                      21.896   Cond. No.                         283.
# ==============================================================================

# %%
# 03 not so much
print lm.smf_linear(best_continuous_features + ['I1', 'I9', 'D4', 'K6', 'D1', 'O3'],
                    'EUIwn', pd.concat([X, bd], axis=1)).summary()
# Out:
# EUIwn ~ PerComArea + PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + Easements + NumBldgs + NumFloors + MaxAllwFAR + I1 + I9 + D4 + K6 + D1 + O3
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.326
# Model:                            OLS   Adj. R-squared:                  0.325
# Method:                 Least Squares   F-statistic:                     338.6
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):               0.00
# Time:                        02:17:41   Log-Likelihood:                -60496.
# No. Observations:               10532   AIC:                         1.210e+05
# Df Residuals:                   10516   BIC:                         1.211e+05
# Df Model:                          15
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       116.7805      1.968     59.345      0.000       112.923   120.638
# PerComArea      -23.1429      3.725     -6.213      0.000       -30.444   -15.842
# PerOfficeArea   103.6004      4.860     21.316      0.000        94.074   113.127
# PerOtherArea    105.8512      4.674     22.649      0.000        96.690   115.012
# PerRetailArea   142.3957      7.647     18.621      0.000       127.406   157.385
# PerGarageArea    87.1951     10.912      7.991      0.000        65.806   108.584
# Easements        16.3148      3.017      5.407      0.000        10.400    22.229
# NumBldgs          0.4516      0.093      4.874      0.000         0.270     0.633
# NumFloors         1.2422      0.111     11.150      0.000         1.024     1.461
# MaxAllwFAR       -0.2370      0.285     -0.830      0.406        -0.796     0.322
# I1              300.5061     10.071     29.839      0.000       280.765   320.247
# I9              251.4675     13.587     18.508      0.000       224.835   278.100
# D4              -14.4665      2.073     -6.978      0.000       -18.530   -10.403
# K6              100.6556     10.888      9.245      0.000        79.313   121.998
# D1               -4.9861      2.246     -2.220      0.026        -9.389    -0.583
# O3               -4.7368      5.186     -0.913      0.361       -14.902     5.429
# ==============================================================================
# Omnibus:                     6464.032   Durbin-Watson:                   1.823
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           167891.704
# Skew:                           2.493   Prob(JB):                         0.00
# Kurtosis:                      21.914   Cond. No.                         283.
# ==============================================================================

# %%
# I6 helps and really makes the MaxAllwFAR variable no longer significant
print lm.smf_linear(best_continuous_features + ['I1', 'I9', 'D4', 'K6', 'D1', 'I6'],
                    'EUIwn', pd.concat([X, bd], axis=1)).summary()
# Out:
# EUIwn ~ PerComArea + PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + Easements + NumBldgs + NumFloors + MaxAllwFAR + I1 + I9 + D4 + K6 + D1 + I6
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.332
# Model:                            OLS   Adj. R-squared:                  0.331
# Method:                 Least Squares   F-statistic:                     348.8
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):               0.00
# Time:                        02:18:59   Log-Likelihood:                -60445.
# No. Observations:               10532   AIC:                         1.209e+05
# Df Residuals:                   10516   BIC:                         1.210e+05
# Df Model:                          15
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       115.4309      1.955     59.052      0.000       111.599   119.263
# PerComArea      -22.7454      3.707     -6.136      0.000       -30.011   -15.480
# PerOfficeArea    99.2808      4.608     21.544      0.000        90.248   108.314
# PerOtherArea     94.6584      4.778     19.812      0.000        85.293   104.024
# PerRetailArea   142.2578      7.609     18.695      0.000       127.342   157.174
# PerGarageArea    87.7054     10.859      8.077      0.000        66.421   108.990
# Easements        17.6336      3.005      5.868      0.000        11.743    23.524
# NumBldgs          0.4715      0.092      5.114      0.000         0.291     0.652
# NumFloors         1.2351      0.111     11.141      0.000         1.018     1.452
# MaxAllwFAR        0.0228      0.283      0.081      0.936        -0.532     0.578
# I1              309.4140     10.051     30.786      0.000       289.713   329.115
# I9              259.5332     13.536     19.174      0.000       233.001   286.066
# D4              -14.4276      2.063     -6.993      0.000       -18.472   -10.384
# K6              101.3754     10.835      9.357      0.000        80.138   122.613
# D1               -4.4524      2.235     -1.993      0.046        -8.832    -0.072
# I6               89.9562      8.823     10.196      0.000        72.661   107.251
# ==============================================================================
# Omnibus:                     6575.754   Durbin-Watson:                   1.825
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           177336.488
# Skew:                           2.543   Prob(JB):                         0.00
# Kurtosis:                      22.448   Cond. No.                         284.
# ==============================================================================

# %%
# eventually these dummies make the commercial area value no longer have significance
curr_features = ['PerComArea',
 'PerOfficeArea',
 'PerOtherArea',
 'PerRetailArea',
 'PerGarageArea',
 'Easements',
 'NumBldgs',
 'NumFloors',]
curr_features = curr_features + ['I1', 'I9', 'D4', 'K6', 'D1', 'I6', 'K1', 'J6',  'P7',
 'R5',
 'E7',
 'H2',
 'K9',
 'F2',
 'I5',
 'H3',
 'W6',
 'H1',
 'H5',
 'O1',
 'E1',
 'F1',
 'H9',
 'E9',
 'J8',
 'O6',
 'G1',]

# 03 not so much
print lm.smf_linear(curr_features,
                    'EUIwn', pd.concat([X, bd], axis=1)).summary()
# Out:
# EUIwn ~ PerComArea + PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + Easements + NumBldgs + NumFloors + I1 + I9 + D4 + K6 + D1 + I6 + K1 + J6 + P7 + R5 + E7 + H2 + K9 + F2 + I5 + H3 + W6 + H1 + H5 + O1 + E1 + F1 + H9 + E9 + J8 + O6 + G1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.377
# Model:                            OLS   Adj. R-squared:                  0.375
# Method:                 Least Squares   F-statistic:                     181.2
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):               0.00
# Time:                        02:33:37   Log-Likelihood:                -60082.
# No. Observations:               10532   AIC:                         1.202e+05
# Df Residuals:                   10496   BIC:                         1.205e+05
# Df Model:                          35
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       117.2773      1.780     65.880      0.000       113.788   120.767
# PerComArea       -5.9014      4.717     -1.251      0.211       -15.148     3.345
# PerOfficeArea    75.3939      5.315     14.184      0.000        64.975    85.813
# PerOtherArea     44.7820      6.023      7.435      0.000        32.976    56.588
# PerRetailArea    69.5730      9.341      7.448      0.000        51.262    87.884
# PerGarageArea    42.5182     13.255      3.208      0.001        16.537    68.500
# Easements        17.2816      3.066      5.637      0.000        11.272    23.291
# NumBldgs          0.4656      0.089      5.244      0.000         0.292     0.640
# NumFloors         1.2986      0.090     14.351      0.000         1.121     1.476
# I1              332.7984      9.870     33.716      0.000       313.450   352.146
# I9              282.4739     13.216     21.374      0.000       256.568   308.380
# D4              -16.1255      1.999     -8.067      0.000       -20.044   -12.207
# K6              150.1101     11.211     13.390      0.000       128.134   172.086
# D1               -6.4285      2.160     -2.976      0.003       -10.663    -2.194
# I6              116.7720      8.735     13.368      0.000        99.650   133.894
# K1              161.7482     15.440     10.476      0.000       131.484   192.013
# J6              260.0209     23.168     11.223      0.000       214.607   305.435
# P7              379.4162     32.718     11.597      0.000       315.283   443.550
# R5               27.3964      6.926      3.956      0.000        13.820    40.972
# E7              -69.0901      9.023     -7.657      0.000       -86.778   -51.403
# H2               85.0140     12.046      7.058      0.000        61.402   108.626
# K9               69.4075     11.276      6.155      0.000        47.305    91.510
# F2              243.4373     24.632      9.883      0.000       195.154   291.720
# I5              146.6230     20.346      7.207      0.000       106.741   186.505
# H3               67.5450     12.113      5.576      0.000        43.801    91.289
# W6               20.6140      8.885      2.320      0.020         3.198    38.030
# H1               94.5452     17.609      5.369      0.000        60.028   129.063
# H5              187.5924     32.795      5.720      0.000       123.309   251.876
# O1               19.8761     10.508      1.892      0.059        -0.721    40.473
# E1              -28.7654      9.325     -3.085      0.002       -47.044   -10.487
# F1              -38.1548     10.856     -3.515      0.000       -59.435   -16.874
# H9               40.7239     12.254      3.323      0.001        16.703    64.745
# E9              -33.9578     10.782     -3.149      0.002       -55.094   -12.822
# J8              126.9658     27.751      4.575      0.000        72.568   181.363
# O6              146.0342     36.484      4.003      0.000        74.518   217.551
# G1               62.1885     20.039      3.103      0.002        22.908   101.469
# ==============================================================================
# Omnibus:                     5908.128   Durbin-Watson:                   1.822
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           146426.316
# Skew:                           2.203   Prob(JB):                         0.00
# Kurtosis:                      20.727   Cond. No.                         731.
# ==============================================================================

# %%
# adding the rest of the dummies and removing any of them that is no longer signficant also makes the NumBldgs no longer matter
curr_features = ['PerOfficeArea',
 'PerOtherArea',
 'PerRetailArea',
 'PerGarageArea',
 'Easements',
 'NumBldgs',
 'NumFloors',]
curr_features = curr_features + ['I1', 'I9', 'D4', 'K6', 'D1', 'I6', 'K1', 'J6',  'P7',
 'R5',
 'E7',
 'H2',
 'K9',
 'F2',
 'I5',
 'H3',
 'W6',
 'H1',
 'H5',
 'O1',
 'E1',
 'F1',
 'H9',
 'E9',
 'J8',
 'O6',
 'G1',
 'F9',
 'J4',
 'K2',
 'I2',
 'F4',
 'P5',
 'N2',
 'D0',
 'I3',
 'L1',
 'W5',
 'P6',
 'E3',
 'W7',
 'C6',
 'J5',
 'P3',]

# 03 not so much
print lm.smf_linear(curr_features,
                    'EUIwn', pd.concat([X, bd], axis=1)).summary()
# Out:
# EUIwn ~ PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + Easements + NumBldgs + NumFloors + I1 + I9 + D4 + K6 + D1 + I6 + K1 + J6 + P7 + R5 + E7 + H2 + K9 + F2 + I5 + H3 + W6 + H1 + H5 + O1 + E1 + F1 + H9 + E9 + J8 + O6 + G1 + F9 + J4 + K2 + I2 + F4 + P5 + N2 + D0 + I3 + L1 + W5 + P6 + E3 + W7 + C6 + J5 + P3
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.390
# Model:                            OLS   Adj. R-squared:                  0.387
# Method:                 Least Squares   F-statistic:                     131.5
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):               0.00
# Time:                        02:37:59   Log-Likelihood:                -59967.
# No. Observations:               10532   AIC:                         1.200e+05
# Df Residuals:                   10480   BIC:                         1.204e+05
# Df Model:                          51
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       117.2158      1.750     66.983      0.000       113.786   120.646
# PerOfficeArea    67.9277      3.004     22.616      0.000        62.040    73.815
# PerOtherArea     25.6796      4.538      5.659      0.000        16.785    34.574
# PerRetailArea    57.9559      8.583      6.753      0.000        41.132    74.780
# PerGarageArea    27.2856     12.726      2.144      0.032         2.340    52.231
# Easements        17.9445      3.037      5.909      0.000        11.992    23.897
# NumBldgs          0.1365      0.118      1.155      0.248        -0.095     0.368
# NumFloors         1.3949      0.090     15.425      0.000         1.218     1.572
# I1              343.1512      9.856     34.817      0.000       323.832   362.470
# I9              292.3261     13.142     22.243      0.000       266.565   318.087
# D4              -16.5352      1.970     -8.393      0.000       -20.397   -12.673
# K6              156.6015     11.288     13.874      0.000       134.476   178.727
# D1               -6.5113      2.132     -3.054      0.002       -10.690    -2.333
# I6              127.7951      8.771     14.571      0.000       110.603   144.987
# K1              167.9943     15.447     10.875      0.000       137.715   198.274
# J6              267.5971     22.957     11.656      0.000       222.597   312.597
# P7              389.8243     32.417     12.025      0.000       326.280   453.368
# R5               29.7365      6.870      4.328      0.000        16.270    43.203
# E7              -74.2737      7.983     -9.304      0.000       -89.923   -58.625
# H2               95.8520     12.023      7.973      0.000        72.285   119.419
# K9               75.1606     11.261      6.675      0.000        53.088    97.233
# F2              238.3796     24.068      9.904      0.000       191.201   285.558
# I5              152.9681     20.159      7.588      0.000       113.452   192.484
# H3               79.0741     12.092      6.540      0.000        55.372   102.776
# W6               32.4209      8.907      3.640      0.000        14.961    49.881
# H1              106.1105     17.505      6.062      0.000        71.797   140.424
# H5              199.9449     32.505      6.151      0.000       136.228   263.662
# O1               22.1187     10.411      2.124      0.034         1.710    42.527
# E1              -33.5598      8.413     -3.989      0.000       -50.051   -17.069
# F1              -43.2358     10.007     -4.321      0.000       -62.851   -23.620
# H9               52.4295     12.235      4.285      0.000        28.447    76.412
# E9              -38.4354     10.006     -3.841      0.000       -58.049   -18.822
# J8              138.5510     27.507      5.037      0.000        84.632   192.470
# O6              147.6670     36.117      4.089      0.000        76.870   218.464
# G1               71.0014     19.903      3.567      0.000        31.987   110.015
# F9              -44.8383     13.024     -3.443      0.001       -70.367   -19.309
# J4              226.9041     51.047      4.445      0.000       126.842   326.966
# K2               61.5311     19.350      3.180      0.001        23.602    99.460
# I2              329.0195     72.175      4.559      0.000       187.544   470.495
# F4               85.5743     13.951      6.134      0.000        58.228   112.920
# P5              172.0335     41.690      4.126      0.000        90.313   253.754
# N2               39.6754     10.685      3.713      0.000        18.731    60.620
# D0              -32.9674      9.887     -3.334      0.001       -52.348   -13.587
# I3              151.7746     42.024      3.612      0.000        69.400   234.149
# L1              -33.1581      6.172     -5.372      0.000       -45.257   -21.059
# W5              124.1354     41.712      2.976      0.003        42.372   205.898
# P6              161.6365     51.124      3.162      0.002        61.424   261.849
# E3              -29.5982     15.804     -1.873      0.061       -60.577     1.381
# W7               73.7616     27.496      2.683      0.007        19.865   127.659
# C6               38.7053      9.488      4.079      0.000        20.107    57.303
# J5              126.9109     51.088      2.484      0.013        26.768   227.054
# P3               59.1543     27.493      2.152      0.031         5.262   113.046
# ==============================================================================
# Omnibus:                     5788.882   Durbin-Watson:                   1.838
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           146564.581
# Skew:                           2.132   Prob(JB):                         0.00
# Kurtosis:                      20.771   Cond. No.                     1.46e+03
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 1.46e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# adding the rest of the dummies and removing any of them that is no longer signficant also makes the NumBldgs no longer matter
curr_features = ['PerOfficeArea',
 'PerOtherArea',
 'PerRetailArea',
 'PerGarageArea',
 'Easements',
 'NumFloors',]
curr_features = curr_features + ['I1', 'I9', 'D4', 'K6', 'D1', 'I6', 'K1', 'J6',  'P7',
 'R5',
 'E7',
 'H2',
 'K9',
 'F2',
 'I5',
 'H3',
 'W6',
 'H1',
 'H5',
 'O1',
 'E1',
 'F1',
 'H9',
 'E9',
 'J8',
 'O6',
 'G1',
 'F9',
 'J4',
 'K2',
 'I2',
 'F4',
 'P5',
 'N2',
 'D0',
 'I3',
 'L1',
 'W5',
 'P6',
 'E3',
 'W7',
 'C6',
 'J5',
 'P3',]

# 03 not so much
print lm.smf_linear(curr_features,
                    'EUIwn', pd.concat([X, bd], axis=1)).summary()
# Out:
# EUIwn ~ PerOfficeArea + PerOtherArea + PerRetailArea + PerGarageArea + Easements + NumFloors + I1 + I9 + D4 + K6 + D1 + I6 + K1 + J6 + P7 + R5 + E7 + H2 + K9 + F2 + I5 + H3 + W6 + H1 + H5 + O1 + E1 + F1 + H9 + E9 + J8 + O6 + G1 + F9 + J4 + K2 + I2 + F4 + P5 + N2 + D0 + I3 + L1 + W5 + P6 + E3 + W7 + C6 + J5 + P3
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  EUIwn   R-squared:                       0.390
# Model:                            OLS   Adj. R-squared:                  0.387
# Method:                 Least Squares   F-statistic:                     134.1
# Date:                Tue, 17 Mar 2015   Prob (F-statistic):               0.00
# Time:                        02:38:41   Log-Likelihood:                -59967.
# No. Observations:               10532   AIC:                         1.200e+05
# Df Residuals:                   10481   BIC:                         1.204e+05
# Df Model:                          50
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       117.5364      1.728     68.026      0.000       114.150   120.923
# PerOfficeArea    67.8361      3.003     22.593      0.000        61.951    73.722
# PerOtherArea     25.6078      4.537      5.644      0.000        16.714    34.502
# PerRetailArea    57.7616      8.581      6.731      0.000        40.941    74.583
# PerGarageArea    27.4694     12.725      2.159      0.031         2.526    52.413
# Easements        18.1595      3.031      5.991      0.000        12.218    24.101
# NumFloors         1.3908      0.090     15.391      0.000         1.214     1.568
# I1              343.4636      9.852     34.861      0.000       324.151   362.776
# I9              292.7658     13.137     22.286      0.000       267.015   318.517
# D4              -16.6124      1.969     -8.437      0.000       -20.472   -12.753
# K6              156.7303     11.287     13.886      0.000       134.605   178.855
# D1               -6.6344      2.129     -3.116      0.002       -10.808    -2.461
# I6              127.7365      8.771     14.564      0.000       110.544   144.929
# K1              168.0115     15.447     10.876      0.000       137.732   198.291
# J6              267.5592     22.957     11.655      0.000       222.558   312.560
# P7              389.7523     32.418     12.023      0.000       326.207   453.297
# R5               29.7464      6.870      4.330      0.000        16.280    43.213
# E7              -74.3706      7.983     -9.316      0.000       -90.019   -58.722
# H2               95.8682     12.023      7.974      0.000        72.301   119.435
# K9               75.1535     11.261      6.674      0.000        53.080    97.227
# F2              238.2788     24.069      9.900      0.000       191.100   285.458
# I5              152.8853     20.160      7.584      0.000       113.369   192.402
# H3               79.0807     12.092      6.540      0.000        55.379   102.783
# W6               32.9806      8.894      3.708      0.000        15.546    50.415
# H1              106.0988     17.505      6.061      0.000        71.785   140.413
# H5              199.8647     32.506      6.149      0.000       136.147   263.582
# O1               22.0508     10.411      2.118      0.034         1.642    42.459
# E1              -33.7283      8.412     -4.010      0.000       -50.217   -17.240
# F1              -43.3154     10.007     -4.329      0.000       -62.931   -23.700
# H9               52.3467     12.235      4.279      0.000        28.364    76.329
# E9              -38.5220     10.006     -3.850      0.000       -58.135   -18.909
# J8              138.3792     27.507      5.031      0.000        84.460   192.298
# O6              147.6151     36.118      4.087      0.000        76.817   218.413
# G1               70.5759     19.900      3.547      0.000        31.568   109.584
# F9              -44.9477     13.024     -3.451      0.001       -70.477   -19.419
# J4              226.8908     51.048      4.445      0.000       126.828   326.954
# K2               61.4898     19.350      3.178      0.001        23.561    99.419
# I2              328.9482     72.176      4.558      0.000       187.470   470.426
# F4               85.4981     13.951      6.129      0.000        58.152   112.844
# P5              171.9540     41.691      4.124      0.000        90.232   253.676
# N2               39.5957     10.685      3.706      0.000        18.651    60.540
# D0              -33.0591      9.887     -3.344      0.001       -52.439   -13.679
# I3              152.0010     42.024      3.617      0.000        69.626   234.376
# L1              -33.2375      6.172     -5.385      0.000       -45.336   -21.139
# W5              124.2085     41.712      2.978      0.003        42.444   205.973
# P6              161.5850     51.125      3.161      0.002        61.371   261.799
# E3              -29.7286     15.804     -1.881      0.060       -60.707     1.250
# W7               73.6988     27.496      2.680      0.007        19.801   127.597
# C6               46.0376      7.052      6.528      0.000        32.215    59.861
# J5              126.8643     51.089      2.483      0.013        26.720   227.009
# P3               59.0971     27.494      2.149      0.032         5.204   112.990
# ==============================================================================
# Omnibus:                     5787.903   Durbin-Watson:                   1.838
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           146472.993
# Skew:                           2.132   Prob(JB):                         0.00
# Kurtosis:                      20.765   Cond. No.                     1.45e+03
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 1.45e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
A = pd.get_dummies(bd[pluto_class_dummies[0]])
B = bd

print "The two DataFrames have the same index: " + str(list(A.index) == list(bd.index))
print "Observations in A: " + str(len(A))
print "Observations in B: " + str(len(B))
print "Observations in A join B: " + str(len(B.join(A)))
print "Observations in A concat B: " + str(len(pd.concat([A, bd[['EUIwn']]], axis=1)))
# Out:
# The two DataFrames have the same index: True
# Observations in A: 10532
# Observations in B: 10532
# Observations in A join B: 12564
# Observations in A concat B: 10532
